# %% [markdown]
# # Trabalhando com Arquivos CSV
#
# Bem-vindo de volta! Vamos discutir como trabalhar com arquivos CSV em Python. Um arquivo com a extensão CSV é um arquivo de Valores Separados por Vírgula. Todos os arquivos CSV são arquivos de texto simples, contêm caracteres alfanuméricos e estruturam os dados contidos neles de forma tabular. Não confunda arquivos Excel com arquivos CSV, embora os arquivos CSV sejam formatados de maneira muito semelhante aos arquivos do Excel, eles não têm tipos de dados para seus valores, todos são strings sem fonte ou cor. Além disso, eles não têm planilhas da mesma forma que um arquivo do Excel. Python possui várias bibliotecas para trabalhar com arquivos do Excel, você pode conferi-las [aqui](http://www.python-excel.org/) e [aqui](https://www.xlwings.org/).
#
# Arquivos no formato CSV são geralmente usados para trocar dados, geralmente quando há uma grande quantidade de dados, entre diferentes aplicativos. Programas de banco de dados, software de análise e outras aplicações que armazenam grandes quantidades de informações (como contatos e dados de clientes) normalmente oferecem suporte ao formato CSV.
#
# Vamos explorar como podemos abrir um arquivo CSV com a biblioteca csv incorporada do Python.

# %% [markdown]
# ____
# ## Localização do Notebook + Criação de dados Fakes
#
# Execute **pwd** dentro de uma célula do caderno para descobrir onde seu caderno está localizado.

# %%
pwd
# Out:
# 'c:\\CDA\\CDA\\2. Criando Automações'

# %%
# !pip install faker
# Out:
# Requirement already satisfied: faker in c:\python312\lib\site-packages (23.1.0)
# Requirement already satisfied: python-dateutil>=2.4 in c:\users\henriquefrank\appdata\roaming\python\python312\site-packages (from faker) (2.8.2)
# Requirement already satisfied: six>=1.5 in c:\users\henriquefrank\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.4->faker) (1.16.0)

# %% [markdown]
# Você pode criar um arquivo CSV com os headers fornecidos e 2000 linhas de dados aleatórios. Aqui está um exemplo de como você pode fazer isso em Python:

# %%
import csv
import random
import faker

# Inicializar o gerador de dados falsos
fake = faker.Faker()

# Headers do arquivo CSV
headers = ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']

# %%
# Gerar 2000 linhas de dados aleatórios
data = []
for i in range(1, 2001):
    row = [i,
           fake.first_name(),
           fake.last_name(),
           fake.email(),
           random.choice(['Male', 'Female']),
           fake.ipv4(),
           fake.city()]
    data.append(row)

# %%
data
# Out:
# [[1,
#   'Jaime',
#   'Fowler',
#   'watkinsanthony@example.net',
#   'Male',
#   '129.94.178.90',
#   'Christopherberg'],
#  [2,
#   'John',
#   'Huffman',
#   'molinabryan@example.net',
#   'Male',
#   '24.66.51.187',
#   'Karlatown'],
#  [3,
#   'Alison',
#   'Pennington',
#   'sextonbrittany@example.net',
#   'Female',
#   '165.164.59.91',
#   'Theresachester'],
#  [4,
#   'Daniel',
#   'Barnett',
#   'james32@example.org',
#   'Female',
#   '15.136.148.175',
#   'South Jason'],
#  [5,
#   'Jenna',
#   'Miller',
#   'steven15@example.com',
#   'Female',
#   '205.16.74.147',
#   'North Karla'],
#  [6,
#   'Amber',
#   'Daniels',
#   'cooperautumn@example.org',
#   'Male',
#   '133.120.153.190',
#   'Beanhaven'],
#  [7,
#   'Janice',
#   'Watson',
#   'zhudson@example.com',
#   'Male',
#   '205.234.166.4',
#   'Lake Keith'],
#  [8,
#   'Howard',
#   'Smith',
#   'justinhenry@example.org',
#   'Male',
#   '42.222.35.150',
#   'Walkerstad'],
#  [9,
#   'Kevin',
#   'Rangel',
#   'kelly21@example.net',
#   'Male',
#   '157.232.238.144',
#   'East Kyle'],
#  [10,
#   'Denise',
#   'Boyd',
#   'nicholas82@example.com',
#   'Female',
#   '176.160.102.1',
#   'West Brandyfort'],
#  [11,
#   'Angela',
#   'Hernandez',
#   'anthonyrussell@example.com',
#   'Male',
#   '162.185.230.110',
#   'Port Brian'],
#  [12,
#   'Christine',
#   'Shaw',
#   'matthew49@example.net',
#   'Male',
#   '52.190.109.216',
#   'North Brandon'],
#  [13,
#   'Adam',
#   'Williams',
#   'millerchristopher@example.com',
#   'Female',
#   '8.214.104.101',
#   'West Brian'],
#  [14,
#   'Jessica',
#   'Mullen',
#   'amanda24@example.com',
#   'Female',
#   '140.160.57.60',
#   'Lake Gabrielside'],
#  [15,
#   'Sydney',
#   'Stone',
#   'thomasjuan@example.com',
#   'Male',
#   '210.42.90.112',
#   'Port Ebony'],
#  [16,
#   'Kenneth',
#   'Wilson',
#   'erik75@example.com',
#   'Female',
#   '9.23.152.156',
#   'Lake Michael'],
#  [17,
#   'Jessica',
#   'Gonzalez',
#   'zbrown@example.com',
#   'Female',
#   '174.30.14.14',
#   'Bethanymouth'],
#  [18,
#   'Briana',
#   'Cardenas',
#   'jessica66@example.org',
#   'Male',
#   '204.2.143.81',
#   'South Nicoleton'],
#  [19,
#   'Spencer',
#   'Osborne',
#   'sarabaker@example.org',
#   'Female',
#   '99.72.253.72',
#   'Jonathanton'],
#  [20,
#   'Benjamin',
#   'Alvarado',
#   'martinezblake@example.net',
#   'Female',
#   '81.239.160.222',
#   'Danielsberg'],
#  [21,
#   'Rachel',
#   'Nelson',
#   'glarsen@example.net',
#   'Male',
#   '141.170.166.155',
#   'West Michelle'],
#  [22,
#   'Vicki',
#   'Bush',
#   'brownwyatt@example.org',
#   'Female',
#   '198.205.86.175',
#   'South Kevin'],
#  [23,
#   'Steve',
#   'Peterson',
#   'jamesstevens@example.com',
#   'Female',
#   '165.122.80.65',
#   'West Brian'],
#  [24,
#   'Margaret',
#   'Collins',
#   'jonathanramsey@example.com',
#   'Female',
#   '88.92.33.3',
#   'Williamsport'],
#  [25,
#   'Alan',
#   'Lee',
#   'enguyen@example.com',
#   'Female',
#   '145.132.61.135',
#   'Delacruzfort'],
#  [26,
#   'Brendan',
#   'Rollins',
#   'petersenlauren@example.com',
#   'Male',
#   '151.218.248.110',
#   'New Anthony'],
#  [27,
#   'Zachary',
#   'Meyer',
#   'heather45@example.com',
#   'Female',
#   '102.50.179.62',
#   'West Mark'],
#  [28,
#   'Megan',
#   'Ward',
#   'angela11@example.com',
#   'Female',
#   '212.68.40.196',
#   'New Rickey'],
#  [29,
#   'Michelle',
#   'Jones',
#   'andrea21@example.org',
#   'Female',
#   '47.105.46.45',
#   'Port Brittanyfort'],
#  [30,
#   'Shelly',
#   'Brown',
#   'brianreynolds@example.net',
#   'Female',
#   '221.0.35.230',
#   'Hollandville'],
#  [31,
#   'Kimberly',
#   'Alvarez',
#   'cwelch@example.com',
#   'Male',
#   '178.177.132.100',
#   'Jacksonburgh'],
#  [32,
#   'Sarah',
#   'Villanueva',
#   'payneruth@example.org',
#   'Female',
#   '173.77.142.16',
#   'North Angela'],
#  [33,
#   'Amanda',
#   'Young',
#   'christopheraguilar@example.com',
#   'Male',
#   '214.151.48.68',
#   'Rhondastad'],
#  [34,
#   'Sabrina',
#   'Caldwell',
#   'trevor76@example.org',
#   'Female',
#   '51.204.247.172',
#   'Michaelbury'],
#  [35,
#   'William',
#   'Hicks',
#   'afox@example.net',
#   'Female',
#   '203.160.70.151',
#   'West Ashley'],
#  [36,
#   'Gregory',
#   'Mcintyre',
#   'jonesjason@example.org',
#   'Female',
#   '217.1.74.132',
#   'New Randy'],
#  [37,
#   'Kimberly',
#   'Carroll',
#   'gbauer@example.net',
#   'Male',
#   '162.6.142.219',
#   'Lake Pennyborough'],
#  [38,
#   'Regina',
#   'Clark',
#   'jordankyle@example.com',
#   'Male',
#   '205.133.211.176',
#   'Jamesview'],
#  [39,
#   'Matthew',
#   'Chandler',
#   'dennisrose@example.net',
#   'Male',
#   '51.131.229.43',
#   'New Anthony'],
#  [40,
#   'Andrew',
#   'Bray',
#   'rclark@example.com',
#   'Male',
#   '86.115.105.174',
#   'North Shawnport'],
#  [41,
#   'Patricia',
#   'Ramos',
#   'sandovaljustin@example.com',
#   'Female',
#   '15.127.92.190',
#   'Wallacehaven'],
#  [42,
#   'Jesse',
#   'Smith',
#   'ethornton@example.net',
#   'Female',
#   '134.86.141.130',
#   'Bradshawstad'],
#  [43,
#   'David',
#   'Mckee',
#   'grantwilliams@example.net',
#   'Female',
#   '102.206.126.238',
#   'Juantown'],
#  [44,
#   'Jessica',
#   'Lopez',
#   'amyjackson@example.org',
#   'Male',
#   '119.202.82.146',
#   'Kerryburgh'],
#  [45,
#   'Alicia',
#   'Yates',
#   'robertjames@example.net',
#   'Male',
#   '26.200.52.22',
#   'Melvinbury'],
#  [46,
#   'Jacqueline',
#   'Camacho',
#   'lisa27@example.net',
#   'Male',
#   '168.194.4.71',
#   'West Robert'],
#  [47,
#   'Christina',
#   'Turner',
#   'keithvaldez@example.com',
#   'Male',
#   '101.225.230.118',
#   'West James'],
#  [48,
#   'Gavin',
#   'Williams',
#   'sharon55@example.com',
#   'Female',
#   '131.222.247.163',
#   'Gardnermouth'],
#  [49,
#   'Jennifer',
#   'Morales',
#   'drewsexton@example.org',
#   'Male',
#   '53.27.126.229',
#   'Peterton'],
#  [50,
#   'Maria',
#   'Miller',
#   'royallen@example.net',
#   'Male',
#   '72.38.13.110',
#   'Jaychester'],
#  [51,
#   'Sarah',
#   'Graham',
#   'rodriguezbeth@example.org',
#   'Male',
#   '223.21.173.11',
#   'New Faithmouth'],
#  [52,
#   'Sara',
#   'White',
#   'acevedorichard@example.org',
#   'Female',
#   '117.183.211.175',
#   'West Paul'],
#  [53,
#   'Patrick',
#   'Marshall',
#   'john73@example.com',
#   'Male',
#   '216.1.82.185',
#   'Banksland'],
#  [54,
#   'Tammy',
#   'Wright',
#   'cwatson@example.net',
#   'Male',
#   '61.26.135.165',
#   'Toddchester'],
#  [55,
#   'Amanda',
#   'Chavez',
#   'fmatthews@example.com',
#   'Female',
#   '106.209.232.97',
#   'Wilsonhaven'],
#  [56,
#   'Nicole',
#   'Watson',
#   'cunninghamjessica@example.com',
#   'Male',
#   '116.211.48.210',
#   'New Josephberg'],
#  [57,
#   'Andrew',
#   'Robertson',
#   'ymora@example.net',
#   'Male',
#   '65.86.164.174',
#   'Garnermouth'],
#  [58,
#   'Bradley',
#   'Hughes',
#   'jamie55@example.com',
#   'Male',
#   '69.190.94.20',
#   'Austinhaven'],
#  [59,
#   'Jillian',
#   'Duncan',
#   'rubencopeland@example.org',
#   'Female',
#   '51.176.26.211',
#   'New Franktown'],
#  [60,
#   'Dale',
#   'Nichols',
#   'shelbyjenkins@example.org',
#   'Female',
#   '159.167.204.242',
#   'Lake Samanthashire'],
#  [61,
#   'Kaitlin',
#   'Cole',
#   'steven12@example.com',
#   'Male',
#   '96.243.52.235',
#   'East Jonathan'],
#  [62,
#   'Zachary',
#   'Medina',
#   'jamesmedina@example.net',
#   'Female',
#   '87.91.142.182',
#   'Deannamouth'],
#  [63,
#   'Toni',
#   'Moore',
#   'katelyn04@example.org',
#   'Female',
#   '33.17.215.202',
#   'North Nathanmouth'],
#  [64,
#   'Stephen',
#   'Lopez',
#   'amy49@example.org',
#   'Male',
#   '92.160.80.49',
#   'Lake Christine'],
#  [65,
#   'Jane',
#   'Ryan',
#   'lbates@example.com',
#   'Female',
#   '72.24.65.10',
#   'New Maryland'],
#  [66,
#   'Terrence',
#   'Rodriguez',
#   'sarahmoreno@example.org',
#   'Female',
#   '190.130.32.119',
#   'West Alexanderburgh'],
#  [67,
#   'Angela',
#   'Jones',
#   'tlester@example.com',
#   'Female',
#   '139.193.150.182',
#   'Berrytown'],
#  [68,
#   'John',
#   'Sanchez',
#   'lovestephanie@example.org',
#   'Male',
#   '59.117.177.2',
#   'West Theresa'],
#  [69,
#   'Nicholas',
#   'Thomas',
#   'schroederclinton@example.org',
#   'Male',
#   '114.16.56.100',
#   'North Nicoletown'],
#  [70,
#   'Mary',
#   'Winters',
#   'laura22@example.org',
#   'Female',
#   '15.81.9.164',
#   'East Brittanyberg'],
#  [71,
#   'Kari',
#   'Robbins',
#   'dustinmcgee@example.net',
#   'Female',
#   '164.6.64.94',
#   'Andrewside'],
#  [72,
#   'Daniel',
#   'Matthews',
#   'xpatel@example.com',
#   'Male',
#   '116.255.59.17',
#   'North Julie'],
#  [73,
#   'Jessica',
#   'Lee',
#   'jessicaprice@example.org',
#   'Male',
#   '207.117.172.240',
#   'Scottfurt'],
#  [74,
#   'Cory',
#   'Brown',
#   'zwright@example.org',
#   'Female',
#   '10.29.168.102',
#   'Gonzaleschester'],
#  [75,
#   'Shelly',
#   'Sanders',
#   'williamsnicole@example.net',
#   'Male',
#   '40.85.198.57',
#   'Hollystad'],
#  [76,
#   'Jennifer',
#   'Williams',
#   'david42@example.org',
#   'Female',
#   '82.57.176.245',
#   'Scottburgh'],
#  [77,
#   'Susan',
#   'Murphy',
#   'nguyenpaula@example.net',
#   'Female',
#   '19.27.99.26',
#   'East Allison'],
#  [78,
#   'Patricia',
#   'Mcdonald',
#   'brittany01@example.com',
#   'Female',
#   '208.181.181.248',
#   'Lake Brianside'],
#  [79,
#   'Joseph',
#   'Campbell',
#   'sarahwilliams@example.com',
#   'Female',
#   '152.153.137.79',
#   'Margaretport'],
#  [80,
#   'Jane',
#   'Rodriguez',
#   'brittany46@example.org',
#   'Female',
#   '124.80.132.215',
#   'Lake Lori'],
#  [81,
#   'Kaitlyn',
#   'Collins',
#   'jamesruth@example.org',
#   'Female',
#   '83.201.140.191',
#   'Butlershire'],
#  [82,
#   'Kelly',
#   'Freeman',
#   'misty14@example.net',
#   'Female',
#   '69.30.66.84',
#   'Garciaview'],
#  [83,
#   'Ryan',
#   'Gill',
#   'robinsonedward@example.com',
#   'Female',
#   '178.230.21.162',
#   'Port Phillip'],
#  [84,
#   'Kara',
#   'Clark',
#   'maryjohns@example.com',
#   'Female',
#   '140.109.173.110',
#   'North Morganborough'],
#  [85,
#   'Stephanie',
#   'Solis',
#   'pthomas@example.org',
#   'Female',
#   '164.148.222.17',
#   'East Josephshire'],
#  [86,
#   'Jason',
#   'Cohen',
#   'courtneybass@example.net',
#   'Female',
#   '70.241.229.221',
#   'Carolynchester'],
#  [87,
#   'Monica',
#   'Adkins',
#   'knightjoseph@example.net',
#   'Male',
#   '188.60.211.52',
#   'Lake Corey'],
#  [88,
#   'Cathy',
#   'Chaney',
#   'flynndalton@example.com',
#   'Female',
#   '46.195.148.69',
#   'New Nancy'],
#  [89,
#   'Cynthia',
#   'Stephens',
#   'danielbrown@example.org',
#   'Female',
#   '120.118.62.190',
#   'New Jennifertown'],
#  [90,
#   'George',
#   'Jimenez',
#   'zgoodman@example.net',
#   'Male',
#   '189.170.28.59',
#   'North Darryl'],
#  [91,
#   'Veronica',
#   'Brown',
#   'michelle23@example.net',
#   'Male',
#   '130.116.253.2',
#   'South Emilyhaven'],
#  [92,
#   'Jeffrey',
#   'Lane',
#   'kennethadams@example.org',
#   'Male',
#   '146.16.89.168',
#   'Lewisside'],
#  [93,
#   'Justin',
#   'Jones',
#   'briana93@example.com',
#   'Female',
#   '195.206.163.211',
#   'East Troystad'],
#  [94,
#   'Jasmine',
#   'Baker',
#   'victoriathomas@example.com',
#   'Female',
#   '220.191.91.23',
#   'New Lukechester'],
#  [95,
#   'Diana',
#   'Tyler',
#   'huffmanelizabeth@example.org',
#   'Male',
#   '53.189.23.51',
#   'Rebeccabury'],
#  [96,
#   'Edward',
#   'Ward',
#   'juarezlacey@example.net',
#   'Male',
#   '176.99.30.251',
#   'Maryborough'],
#  [97,
#   'Carl',
#   'Mason',
#   'hernandezjoanna@example.net',
#   'Male',
#   '84.71.166.236',
#   'Lake Dustin'],
#  [98,
#   'Anthony',
#   'Torres',
#   'hoffmanandrew@example.org',
#   'Male',
#   '50.189.246.195',
#   'New Nathanielton'],
#  [99,
#   'Calvin',
#   'Johnson',
#   'hwillis@example.org',
#   'Male',
#   '18.70.169.120',
#   'Cisnerosberg'],
#  [100,
#   'George',
#   'Hoffman',
#   'richardsonbrian@example.net',
#   'Female',
#   '203.110.128.88',
#   'Lopezville'],
#  [101,
#   'Allison',
#   'Burch',
#   'ggreene@example.com',
#   'Female',
#   '123.26.126.226',
#   'Reneeland'],
#  [102,
#   'Shane',
#   'Williams',
#   'vvargas@example.org',
#   'Male',
#   '53.190.10.184',
#   'Robinville'],
#  [103,
#   'Thomas',
#   'Jones',
#   'john92@example.org',
#   'Female',
#   '75.174.184.181',
#   'New Tanner'],
#  [104,
#   'Steven',
#   'Wells',
#   'ernestking@example.org',
#   'Male',
#   '142.59.161.106',
#   'Angelashire'],
#  [105,
#   'Ryan',
#   'White',
#   'matthewrodriguez@example.net',
#   'Female',
#   '23.32.27.206',
#   'Lisaside'],
#  [106,
#   'Caitlin',
#   'Yoder',
#   'hollymason@example.com',
#   'Female',
#   '159.45.22.221',
#   'West Bradley'],
#  [107,
#   'Christopher',
#   'Lee',
#   'randallhoffman@example.com',
#   'Female',
#   '43.168.175.103',
#   'Lindseystad'],
#  [108,
#   'Cassie',
#   'Berger',
#   'sgomez@example.com',
#   'Male',
#   '171.186.246.169',
#   'Lake Taylorfurt'],
#  [109,
#   'Brandon',
#   'Roach',
#   'kevin86@example.com',
#   'Male',
#   '196.107.159.116',
#   'Joelland'],
#  [110,
#   'David',
#   'Stone',
#   'kaneangelica@example.net',
#   'Male',
#   '203.183.109.247',
#   'Stacybury'],
#  [111,
#   'Michael',
#   'Wise',
#   'lawrence54@example.com',
#   'Female',
#   '12.11.100.63',
#   'Troyshire'],
#  [112,
#   'James',
#   'Lewis',
#   'martinmichael@example.net',
#   'Female',
#   '44.92.225.86',
#   'Lake Nicole'],
#  [113,
#   'Thomas',
#   'Rowland',
#   'nreid@example.net',
#   'Female',
#   '214.22.133.171',
#   'West Peterburgh'],
#  [114,
#   'Sean',
#   'Wolfe',
#   'qriley@example.org',
#   'Female',
#   '5.175.218.215',
#   'Loveview'],
#  [115,
#   'Kimberly',
#   'Archer',
#   'jennifer27@example.org',
#   'Female',
#   '198.220.177.191',
#   'Port Lisaside'],
#  [116,
#   'James',
#   'Madden',
#   'rodriguezkevin@example.org',
#   'Male',
#   '45.103.185.172',
#   'Montgomeryland'],
#  [117,
#   'Danielle',
#   'Williams',
#   'jacob48@example.com',
#   'Female',
#   '145.19.113.234',
#   'Dicksonfurt'],
#  [118,
#   'Emily',
#   'Navarro',
#   'carmenhernandez@example.org',
#   'Female',
#   '123.41.115.153',
#   'Taylormouth'],
#  [119,
#   'Robert',
#   'Taylor',
#   'smithjonathan@example.net',
#   'Male',
#   '178.19.105.244',
#   'Port Meganland'],
#  [120,
#   'David',
#   'Jackson',
#   'huntermark@example.com',
#   'Female',
#   '218.79.205.245',
#   'New Megan'],
#  [121,
#   'Justin',
#   'Clark',
#   'colemanarthur@example.net',
#   'Male',
#   '185.53.73.182',
#   'Port Samanthaland'],
#  [122,
#   'Jennifer',
#   'Green',
#   'carl91@example.org',
#   'Male',
#   '10.93.8.118',
#   'South Josephside'],
#  [123,
#   'Karina',
#   'Swanson',
#   'morriscandace@example.net',
#   'Female',
#   '32.127.205.238',
#   'Jenkinsberg'],
#  [124,
#   'Joshua',
#   'Boone',
#   'uhawkins@example.com',
#   'Female',
#   '74.146.132.242',
#   'New Brian'],
#  [125,
#   'Timothy',
#   'Mcdonald',
#   'rushhannah@example.com',
#   'Female',
#   '32.93.26.121',
#   'New Melissa'],
#  [126,
#   'Amy',
#   'Williams',
#   'youngaimee@example.net',
#   'Male',
#   '11.234.132.163',
#   'Morenohaven'],
#  [127,
#   'Kristi',
#   'Scott',
#   'clarkalexander@example.net',
#   'Female',
#   '123.241.135.235',
#   'Dustinmouth'],
#  [128,
#   'Charles',
#   'Newton',
#   'briggsantonio@example.net',
#   'Male',
#   '63.236.112.95',
#   'Taylorside'],
#  [129,
#   'John',
#   'Torres',
#   'brian23@example.net',
#   'Female',
#   '112.31.90.113',
#   'Lewisland'],
#  [130,
#   'Roger',
#   'Crawford',
#   'donna32@example.net',
#   'Female',
#   '188.173.154.194',
#   'North Debraborough'],
#  [131,
#   'Emily',
#   'Brown',
#   'michaelmoore@example.net',
#   'Female',
#   '106.251.20.244',
#   'Erinchester'],
#  [132,
#   'Bailey',
#   'Aguirre',
#   'ewilliams@example.org',
#   'Male',
#   '5.191.40.159',
#   'East Annettemouth'],
#  [133,
#   'Savannah',
#   'Sheppard',
#   'nelsonjasmine@example.com',
#   'Female',
#   '118.166.23.35',
#   'West Christopherside'],
#  [134,
#   'Joseph',
#   'Wagner',
#   'amberzimmerman@example.com',
#   'Female',
#   '105.249.107.170',
#   'Gomezton'],
#  [135,
#   'Virginia',
#   'Preston',
#   'lmartinez@example.com',
#   'Male',
#   '102.111.148.146',
#   'Natalieberg'],
#  [136,
#   'Denise',
#   'Thomas',
#   'nancy99@example.com',
#   'Female',
#   '101.161.231.80',
#   'Port Breannaside'],
#  [137,
#   'Brian',
#   'Hurley',
#   'samantha22@example.com',
#   'Male',
#   '21.231.149.211',
#   'Wilsonchester'],
#  [138,
#   'Cynthia',
#   'Johnson',
#   'penarichard@example.org',
#   'Male',
#   '24.157.67.33',
#   'Janeland'],
#  [139,
#   'Sylvia',
#   'Morales',
#   'edwardsmith@example.com',
#   'Male',
#   '88.128.82.58',
#   'Tarastad'],
#  [140,
#   'Michael',
#   'Miller',
#   'fhunter@example.org',
#   'Female',
#   '137.23.99.111',
#   'Alisonmouth'],
#  [141,
#   'Monique',
#   'Wilson',
#   'zholmes@example.com',
#   'Female',
#   '138.66.36.236',
#   'Cunninghamside'],
#  [142,
#   'Olivia',
#   'Williams',
#   'james59@example.net',
#   'Male',
#   '197.100.77.230',
#   'West John'],
#  [143,
#   'Terri',
#   'Castillo',
#   'matthewballard@example.com',
#   'Female',
#   '216.234.202.207',
#   'Cookbury'],
#  [144,
#   'Emily',
#   'Morgan',
#   'edward17@example.org',
#   'Female',
#   '49.85.184.111',
#   'Johnton'],
#  [145,
#   'Lisa',
#   'Blair',
#   'churchjonathon@example.net',
#   'Male',
#   '19.213.6.169',
#   'Lake Geoffreyhaven'],
#  [146,
#   'Norma',
#   'Gates',
#   'higginssamantha@example.org',
#   'Male',
#   '206.41.1.73',
#   'New Aaronfort'],
#  [147,
#   'Willie',
#   'Brown',
#   'daniel95@example.org',
#   'Female',
#   '150.102.51.229',
#   'Vazquezshire'],
#  [148,
#   'Antonio',
#   'Davidson',
#   'maria49@example.org',
#   'Female',
#   '206.253.98.187',
#   'Johnville'],
#  [149,
#   'Caroline',
#   'Woods',
#   'dterrell@example.net',
#   'Male',
#   '10.249.18.65',
#   'Tracyborough'],
#  [150,
#   'Gregory',
#   'Barrett',
#   'douglaspowers@example.net',
#   'Male',
#   '188.69.192.39',
#   'Mullinsland'],
#  [151,
#   'Lisa',
#   'Randolph',
#   'velazqueznicholas@example.org',
#   'Female',
#   '21.221.228.1',
#   'Wilsonmouth'],
#  [152,
#   'Wayne',
#   'Elliott',
#   'cheryl60@example.org',
#   'Male',
#   '74.100.212.172',
#   'South Susan'],
#  [153,
#   'Andrew',
#   'Holmes',
#   'jdiaz@example.net',
#   'Female',
#   '101.243.59.22',
#   'Powellburgh'],
#  [154,
#   'Brandon',
#   'Jenkins',
#   'mcbridejuan@example.net',
#   'Male',
#   '192.252.32.146',
#   'New Rachelberg'],
#  [155,
#   'Thomas',
#   'Garrett',
#   'angie74@example.org',
#   'Female',
#   '137.218.29.255',
#   'East Nicholas'],
#  [156,
#   'Lucas',
#   'Harris',
#   'dperez@example.net',
#   'Female',
#   '27.169.73.192',
#   'Patriciaview'],
#  [157,
#   'Ashley',
#   'Smith',
#   'brenda98@example.net',
#   'Male',
#   '54.32.9.166',
#   'Colonfurt'],
#  [158,
#   'Chad',
#   'Peterson',
#   'angela72@example.net',
#   'Female',
#   '97.35.199.136',
#   'New Susanhaven'],
#  [159,
#   'Anthony',
#   'Mcgee',
#   'elizabethcooper@example.net',
#   'Female',
#   '184.141.169.79',
#   'Smithport'],
#  [160,
#   'Kaitlin',
#   'Kemp',
#   'stephenroth@example.org',
#   'Female',
#   '83.92.231.200',
#   'Lynnshire'],
#  [161,
#   'Elizabeth',
#   'Mcbride',
#   'douglas64@example.com',
#   'Female',
#   '52.57.132.67',
#   'Philipmouth'],
#  [162,
#   'Jeremy',
#   'Frye',
#   'sarahwilson@example.com',
#   'Male',
#   '223.58.137.26',
#   'Lake Geraldbury'],
#  [163,
#   'Andrew',
#   'Moyer',
#   'jonathan38@example.net',
#   'Male',
#   '20.28.120.232',
#   'North Barbara'],
#  [164,
#   'William',
#   'Thompson',
#   'michael82@example.com',
#   'Female',
#   '52.166.16.1',
#   'Paulamouth'],
#  [165,
#   'Lauren',
#   'Perez',
#   'jamessaunders@example.com',
#   'Female',
#   '157.100.93.78',
#   'New Lauren'],
#  [166,
#   'David',
#   'Franklin',
#   'douglasking@example.org',
#   'Female',
#   '80.192.12.113',
#   'Port Kevin'],
#  [167,
#   'Ashley',
#   'Hughes',
#   'meganlewis@example.net',
#   'Male',
#   '160.146.94.181',
#   'Smithton'],
#  [168,
#   'James',
#   'Lyons',
#   'josephthomas@example.org',
#   'Male',
#   '151.182.23.174',
#   'Stoneburgh'],
#  [169,
#   'Nancy',
#   'Welch',
#   'riveradenise@example.com',
#   'Male',
#   '213.52.17.43',
#   'Stevensonside'],
#  [170,
#   'Michael',
#   'Baker',
#   'davisjoseph@example.org',
#   'Female',
#   '22.2.94.17',
#   'West Claudia'],
#  [171,
#   'Melissa',
#   'Young',
#   'evanswhitney@example.com',
#   'Female',
#   '138.101.24.237',
#   'Jensenshire'],
#  [172,
#   'Elizabeth',
#   'Caldwell',
#   'nelsontammy@example.org',
#   'Male',
#   '147.255.28.246',
#   'South Jacquelinemouth'],
#  [173,
#   'Amanda',
#   'Cherry',
#   'sarahwalton@example.com',
#   'Male',
#   '6.16.168.254',
#   'Scottbury'],
#  [174,
#   'Kevin',
#   'Sanchez',
#   'chase76@example.org',
#   'Female',
#   '94.242.152.66',
#   'Lake Christopher'],
#  [175,
#   'Larry',
#   'Hayes',
#   'dsanford@example.com',
#   'Male',
#   '83.100.48.155',
#   'Samuelfort'],
#  [176,
#   'John',
#   'Scott',
#   'richardjones@example.org',
#   'Male',
#   '70.169.169.215',
#   'New Melissachester'],
#  [177,
#   'John',
#   'Parker',
#   'jeffreytaylor@example.org',
#   'Female',
#   '1.62.179.231',
#   'Johnchester'],
#  [178,
#   'Carol',
#   'Morse',
#   'ejohnson@example.net',
#   'Male',
#   '178.119.65.163',
#   'Port Michaelfurt'],
#  [179,
#   'David',
#   'Goodman',
#   'jwhite@example.net',
#   'Female',
#   '8.89.138.201',
#   'East Betty'],
#  [180,
#   'Xavier',
#   'Huff',
#   'wigginsrhonda@example.com',
#   'Female',
#   '37.47.22.160',
#   'Lake Rebekah'],
#  [181,
#   'Stephen',
#   'Anderson',
#   'barkerolivia@example.com',
#   'Male',
#   '3.28.5.91',
#   'Josefort'],
#  [182,
#   'Brian',
#   'Smith',
#   'rickykaiser@example.org',
#   'Female',
#   '214.39.48.182',
#   'Jesseshire'],
#  [183,
#   'Corey',
#   'Conley',
#   'yjones@example.org',
#   'Male',
#   '120.14.19.142',
#   'Williamsside'],
#  [184,
#   'Brian',
#   'Gray',
#   'cassandraturner@example.net',
#   'Female',
#   '60.114.126.165',
#   'East Rebecca'],
#  [185,
#   'Kim',
#   'Strickland',
#   'datkinson@example.net',
#   'Female',
#   '214.233.92.243',
#   'West Zacharymouth'],
#  [186,
#   'Charles',
#   'Collins',
#   'chorton@example.com',
#   'Male',
#   '213.44.124.63',
#   'Robertburgh'],
#  [187,
#   'Roger',
#   'Webster',
#   'collinspatricia@example.com',
#   'Female',
#   '53.128.100.116',
#   'Richardfurt'],
#  [188,
#   'Madeline',
#   'Miller',
#   'alicialara@example.org',
#   'Female',
#   '173.63.131.215',
#   'Greenfurt'],
#  [189,
#   'John',
#   'Baldwin',
#   'hwilson@example.net',
#   'Female',
#   '187.205.121.162',
#   'Mcdonaldfort'],
#  [190,
#   'Misty',
#   'Moore',
#   'larry08@example.com',
#   'Male',
#   '131.210.227.102',
#   'Dunnview'],
#  [191,
#   'Carrie',
#   'Mosley',
#   'fwelch@example.com',
#   'Male',
#   '161.231.233.23',
#   'East Nicholas'],
#  [192,
#   'Joshua',
#   'Roberts',
#   'pearsonamy@example.com',
#   'Female',
#   '163.174.253.22',
#   'Danielhaven'],
#  [193,
#   'James',
#   'Fry',
#   'claudia31@example.org',
#   'Female',
#   '133.216.230.68',
#   'Deborahfort'],
#  [194,
#   'Theodore',
#   'Alvarado',
#   'kathryn97@example.com',
#   'Male',
#   '202.115.32.18',
#   'Lake Kara'],
#  [195,
#   'Jennifer',
#   'Arnold',
#   'courtney00@example.org',
#   'Male',
#   '153.176.199.162',
#   'West Marialand'],
#  [196,
#   'Margaret',
#   'Sweeney',
#   'brooksmiguel@example.org',
#   'Male',
#   '66.107.210.50',
#   'Lake Nicholasland'],
#  [197,
#   'Kimberly',
#   'Byrd',
#   'henry42@example.net',
#   'Female',
#   '179.233.50.189',
#   'Lake Juanview'],
#  [198,
#   'Alexander',
#   'Brown',
#   'aaronday@example.net',
#   'Male',
#   '89.11.80.201',
#   'Port Cassandratown'],
#  [199,
#   'Carolyn',
#   'Russell',
#   'shawnmiller@example.net',
#   'Male',
#   '135.102.155.28',
#   'Karenport'],
#  [200,
#   'Elizabeth',
#   'Price',
#   'michael97@example.com',
#   'Female',
#   '135.60.138.42',
#   'Mcdonaldmouth'],
#  [201,
#   'Diane',
#   'Marsh',
#   'mark70@example.net',
#   'Male',
#   '135.68.104.194',
#   'South Kayleeside'],
#  [202,
#   'Benjamin',
#   'Cook',
#   'dfoster@example.net',
#   'Female',
#   '129.54.82.70',
#   'Port Lauren'],
#  [203,
#   'Frank',
#   'King',
#   'ramirezanna@example.org',
#   'Male',
#   '166.112.114.130',
#   'Lake Sara'],
#  [204,
#   'Dylan',
#   'Martin',
#   'ericwhite@example.com',
#   'Male',
#   '117.105.222.235',
#   'East Kristiburgh'],
#  [205,
#   'Allison',
#   'Bailey',
#   'lauren57@example.org',
#   'Male',
#   '154.187.43.234',
#   'New Craigfort'],
#  [206,
#   'Jessica',
#   'Harris',
#   'blancharderin@example.org',
#   'Male',
#   '106.12.131.204',
#   'Lindseyland'],
#  [207,
#   'Melissa',
#   'Knight',
#   'michelle71@example.org',
#   'Female',
#   '133.149.69.15',
#   'Jillianburgh'],
#  [208,
#   'Kenneth',
#   'Robinson',
#   'unoble@example.net',
#   'Male',
#   '157.248.57.69',
#   'Lake Mark'],
#  [209,
#   'Nancy',
#   'Taylor',
#   'danielmurphy@example.com',
#   'Female',
#   '80.40.223.183',
#   'Troyborough'],
#  [210,
#   'Katherine',
#   'Williamson',
#   'ysimpson@example.net',
#   'Female',
#   '149.127.233.164',
#   'Lake Tony'],
#  [211,
#   'Lisa',
#   'Jones',
#   'linda12@example.org',
#   'Female',
#   '135.103.13.66',
#   'South Traviston'],
#  [212,
#   'Eileen',
#   'Dunn',
#   'singletontami@example.net',
#   'Female',
#   '215.119.254.199',
#   'South Feliciatown'],
#  [213,
#   'Jessica',
#   'Ramirez',
#   'holly66@example.net',
#   'Female',
#   '120.51.233.122',
#   'Justintown'],
#  [214,
#   'Sandra',
#   'Mcbride',
#   'leehiggins@example.com',
#   'Male',
#   '136.109.141.164',
#   'Rachelchester'],
#  [215,
#   'Scott',
#   'Gutierrez',
#   'michelle61@example.org',
#   'Male',
#   '97.151.152.42',
#   'Stacybury'],
#  [216,
#   'Stacey',
#   'Hughes',
#   'uobrien@example.org',
#   'Male',
#   '192.93.42.135',
#   'North Kim'],
#  [217,
#   'Scott',
#   'Martinez',
#   'kenneth89@example.net',
#   'Female',
#   '36.9.109.195',
#   'New Anthony'],
#  [218,
#   'Jonathan',
#   'Campbell',
#   'anthony32@example.org',
#   'Male',
#   '185.236.229.104',
#   'Murphyborough'],
#  [219,
#   'Katelyn',
#   'Williams',
#   'uscott@example.net',
#   'Male',
#   '49.41.53.119',
#   'North Edwardbury'],
#  [220,
#   'John',
#   'Wade',
#   'moorelarry@example.com',
#   'Male',
#   '106.234.250.230',
#   'South Tinaton'],
#  [221,
#   'Ronald',
#   'Decker',
#   'danaferguson@example.org',
#   'Male',
#   '94.223.21.32',
#   'New Brandonbury'],
#  [222,
#   'Teresa',
#   'Owens',
#   'christinedavis@example.com',
#   'Male',
#   '27.90.102.129',
#   'North Jacqueline'],
#  [223,
#   'Tim',
#   'Hamilton',
#   'russellstevens@example.com',
#   'Male',
#   '162.143.59.29',
#   'Blackwellmouth'],
#  [224,
#   'Zachary',
#   'Ross',
#   'ggarcia@example.net',
#   'Male',
#   '212.89.201.81',
#   'North Edward'],
#  [225,
#   'Nicole',
#   'Howell',
#   'steventaylor@example.net',
#   'Female',
#   '173.59.120.188',
#   'New Heidiville'],
#  [226,
#   'Amy',
#   'Stewart',
#   'ureyes@example.com',
#   'Female',
#   '217.169.45.241',
#   'Amandaton'],
#  [227,
#   'Kelly',
#   'Harris',
#   'ralph91@example.com',
#   'Male',
#   '9.24.21.76',
#   'Martinburgh'],
#  [228,
#   'Kimberly',
#   'Peterson',
#   'khernandez@example.org',
#   'Male',
#   '41.225.162.136',
#   'West Ryanchester'],
#  [229,
#   'Curtis',
#   'Lara',
#   'christinesmith@example.org',
#   'Female',
#   '170.36.166.18',
#   'Robertmouth'],
#  [230,
#   'Keith',
#   'Gonzales',
#   'heatherkoch@example.org',
#   'Male',
#   '126.82.66.207',
#   'New Erinland'],
#  [231,
#   'Lori',
#   'Russell',
#   'jeffreyrichards@example.net',
#   'Male',
#   '3.53.167.171',
#   'North Justin'],
#  [232,
#   'Christopher',
#   'Johnson',
#   'wilsonmary@example.com',
#   'Female',
#   '70.169.143.208',
#   'Port Angela'],
#  [233,
#   'Timothy',
#   'Williams',
#   'travismartin@example.net',
#   'Female',
#   '120.196.231.131',
#   'Kentshire'],
#  [234,
#   'Charles',
#   'Brewer',
#   'rebeccawest@example.net',
#   'Female',
#   '136.44.235.203',
#   'North Jeremy'],
#  [235,
#   'Stephen',
#   'Santos',
#   'lindseylopez@example.org',
#   'Female',
#   '72.189.224.188',
#   'Lake Jefferytown'],
#  [236,
#   'Anita',
#   'Campos',
#   'johnsontimothy@example.com',
#   'Female',
#   '95.38.74.50',
#   'Sanchezberg'],
#  [237,
#   'Jack',
#   'Lopez',
#   'athompson@example.com',
#   'Female',
#   '176.139.12.86',
#   'South Kevinfurt'],
#  [238,
#   'Crystal',
#   'Boone',
#   'byrdbrittney@example.com',
#   'Male',
#   '7.154.0.114',
#   'Michaelton'],
#  [239,
#   'Stephen',
#   'Sanchez',
#   'robert21@example.com',
#   'Male',
#   '111.9.157.250',
#   'Sandraburgh'],
#  [240,
#   'Maxwell',
#   'Wallace',
#   'susanwilliams@example.net',
#   'Male',
#   '42.100.188.66',
#   'North Holly'],
#  [241,
#   'Laura',
#   'West',
#   'hensleykristin@example.net',
#   'Female',
#   '49.85.210.108',
#   'Josephtown'],
#  [242,
#   'James',
#   'Thompson',
#   'nrice@example.com',
#   'Female',
#   '94.155.99.209',
#   'Michaelmouth'],
#  [243,
#   'Sarah',
#   'Raymond',
#   'aimee05@example.com',
#   'Female',
#   '29.43.22.153',
#   'Oliviamouth'],
#  [244,
#   'Brenda',
#   'Torres',
#   'webstermitchell@example.org',
#   'Female',
#   '112.175.250.195',
#   'Lake Amanda'],
#  [245,
#   'Tyler',
#   'Kane',
#   'michelleclark@example.org',
#   'Male',
#   '108.90.110.77',
#   'North Ashley'],
#  [246,
#   'Catherine',
#   'Cannon',
#   'fsmith@example.net',
#   'Male',
#   '18.123.182.43',
#   'New Williammouth'],
#  [247,
#   'Erika',
#   'Anderson',
#   'ashleyjohnson@example.net',
#   'Male',
#   '215.151.6.139',
#   'Wilkinsonview'],
#  [248,
#   'Misty',
#   'Cooper',
#   'samantha03@example.org',
#   'Female',
#   '60.23.197.251',
#   'Macdonaldberg'],
#  [249,
#   'Willie',
#   'Price',
#   'sarah49@example.org',
#   'Female',
#   '30.140.9.51',
#   'East Gregoryberg'],
#  [250,
#   'Justin',
#   'Macias',
#   'davidponce@example.org',
#   'Female',
#   '100.30.30.169',
#   'Adkinshaven'],
#  [251,
#   'Anthony',
#   'Ayala',
#   'thomas14@example.com',
#   'Female',
#   '58.27.223.113',
#   'Tiffanyhaven'],
#  [252,
#   'Jesse',
#   'Fitzgerald',
#   'sean46@example.net',
#   'Male',
#   '219.102.123.25',
#   'West Melissa'],
#  [253,
#   'Jordan',
#   'Park',
#   'thomas53@example.com',
#   'Male',
#   '219.130.10.238',
#   'Port Albert'],
#  [254,
#   'Karen',
#   'Brady',
#   'qramos@example.net',
#   'Female',
#   '16.29.173.200',
#   'Lake Charleneside'],
#  [255,
#   'Kevin',
#   'Martin',
#   'pbrooks@example.org',
#   'Female',
#   '6.131.201.50',
#   'Fowlerton'],
#  [256,
#   'Matthew',
#   'Riley',
#   'danielle80@example.net',
#   'Female',
#   '39.197.145.168',
#   'Johnsonport'],
#  [257,
#   'Antonio',
#   'Simpson',
#   'courtney37@example.com',
#   'Female',
#   '48.33.160.146',
#   'Alyssaland'],
#  [258,
#   'Derek',
#   'Peterson',
#   'millernancy@example.org',
#   'Male',
#   '16.189.136.57',
#   'Banksland'],
#  [259,
#   'Stephen',
#   'Zimmerman',
#   'chad63@example.org',
#   'Male',
#   '207.221.183.204',
#   'New Lisa'],
#  [260,
#   'Rebecca',
#   'Montoya',
#   'stevenrosales@example.net',
#   'Female',
#   '165.18.187.246',
#   'South Audrey'],
#  [261,
#   'Melissa',
#   'Evans',
#   'thomaselizabeth@example.net',
#   'Male',
#   '24.34.246.208',
#   'Brownstad'],
#  [262,
#   'Elizabeth',
#   'Walker',
#   'higginstimothy@example.net',
#   'Female',
#   '125.30.225.33',
#   'Michaelburgh'],
#  [263,
#   'Kayla',
#   'Hodge',
#   'aprilleonard@example.com',
#   'Female',
#   '88.224.145.121',
#   'South Ashleyshire'],
#  [264,
#   'Maria',
#   'Austin',
#   'glamb@example.org',
#   'Female',
#   '32.65.246.9',
#   'Laurenstad'],
#  [265,
#   'Joshua',
#   'Mueller',
#   'makayla61@example.net',
#   'Female',
#   '17.56.79.53',
#   'Ortizland'],
#  [266,
#   'Jennifer',
#   'Mcintyre',
#   'harriskevin@example.com',
#   'Male',
#   '180.141.204.246',
#   'Taylormouth'],
#  [267,
#   'Brenda',
#   'Shepard',
#   'daniel84@example.com',
#   'Female',
#   '4.111.127.156',
#   'Lake Michaelborough'],
#  [268,
#   'Devin',
#   'Clements',
#   'frances91@example.org',
#   'Female',
#   '30.157.100.193',
#   'West Joann'],
#  [269,
#   'Michael',
#   'Murphy',
#   'smithmark@example.org',
#   'Female',
#   '196.142.250.38',
#   'Geoffreyfort'],
#  [270,
#   'Ellen',
#   'Weber',
#   'steven71@example.org',
#   'Female',
#   '41.10.209.196',
#   'Angelachester'],
#  [271,
#   'Barry',
#   'Flowers',
#   'jamessanders@example.org',
#   'Female',
#   '188.195.191.0',
#   'South Samuelhaven'],
#  [272,
#   'James',
#   'Meadows',
#   'fdoyle@example.org',
#   'Female',
#   '59.255.23.128',
#   'Mannmouth'],
#  [273,
#   'Charles',
#   'Callahan',
#   'tyler50@example.org',
#   'Male',
#   '214.143.98.241',
#   'Lake Andreaborough'],
#  [274,
#   'John',
#   'Contreras',
#   'vincentnelson@example.com',
#   'Male',
#   '25.154.92.48',
#   'Julieton'],
#  [275,
#   'Anthony',
#   'Santiago',
#   'iwhite@example.net',
#   'Male',
#   '130.182.160.202',
#   'New Davidport'],
#  [276,
#   'Rebecca',
#   'Blackburn',
#   'anthonyweaver@example.com',
#   'Female',
#   '97.19.255.38',
#   'Silvaberg'],
#  [277,
#   'Kevin',
#   'Smith',
#   'rvargas@example.net',
#   'Male',
#   '119.242.103.51',
#   'North Clarencechester'],
#  [278,
#   'John',
#   'Vargas',
#   'ashleyhopkins@example.org',
#   'Female',
#   '18.120.73.231',
#   'Vargaston'],
#  [279,
#   'Morgan',
#   'Carlson',
#   'craigreed@example.net',
#   'Female',
#   '140.51.143.76',
#   'North Robert'],
#  [280,
#   'Michael',
#   'Blair',
#   'riverasamantha@example.org',
#   'Female',
#   '60.158.92.92',
#   'Blackburgh'],
#  [281,
#   'Christy',
#   'Perez',
#   'garnermackenzie@example.org',
#   'Female',
#   '181.57.213.88',
#   'Bautistaland'],
#  [282,
#   'Mitchell',
#   'Abbott',
#   'amyjordan@example.org',
#   'Female',
#   '178.139.214.29',
#   'New Suzanne'],
#  [283,
#   'Edward',
#   'Bowman',
#   'amanda25@example.org',
#   'Male',
#   '9.89.244.171',
#   'Coleville'],
#  [284,
#   'Michael',
#   'Morris',
#   'gonzalezmichael@example.net',
#   'Female',
#   '23.211.134.92',
#   'Davisfort'],
#  [285,
#   'Steven',
#   'Galloway',
#   'zgonzalez@example.com',
#   'Female',
#   '125.48.227.31',
#   'Lake Robertshire'],
#  [286,
#   'Katie',
#   'Cowan',
#   'michellecollins@example.com',
#   'Male',
#   '99.8.127.173',
#   'Gregorytown'],
#  [287,
#   'Dillon',
#   'Delgado',
#   'alejandramitchell@example.net',
#   'Female',
#   '19.218.169.77',
#   'North Jackson'],
#  [288,
#   'Spencer',
#   'Green',
#   'hooverdavid@example.net',
#   'Male',
#   '126.228.138.235',
#   'Pamelamouth'],
#  [289,
#   'Cheryl',
#   'Long',
#   'melissabaker@example.org',
#   'Female',
#   '97.116.123.141',
#   'Danielville'],
#  [290,
#   'Jean',
#   'Rogers',
#   'steven52@example.net',
#   'Female',
#   '122.109.132.0',
#   'Lake Jackie'],
#  [291,
#   'Jennifer',
#   'Norris',
#   'oshepard@example.org',
#   'Male',
#   '51.111.112.147',
#   'Abbottton'],
#  [292,
#   'Jean',
#   'King',
#   'christopher87@example.org',
#   'Male',
#   '169.143.76.164',
#   'Lunachester'],
#  [293,
#   'Erik',
#   'Clayton',
#   'pamela46@example.org',
#   'Female',
#   '167.50.53.8',
#   'Port Carla'],
#  [294,
#   'Samantha',
#   'Miller',
#   'markhill@example.com',
#   'Female',
#   '222.26.144.208',
#   'Reginaville'],
#  [295,
#   'Tami',
#   'Rivera',
#   'cmyers@example.com',
#   'Male',
#   '3.83.166.87',
#   'Moniquechester'],
#  [296,
#   'William',
#   'Griffin',
#   'david76@example.net',
#   'Female',
#   '203.225.139.114',
#   'New Rebecca'],
#  [297,
#   'Dustin',
#   'Grant',
#   'tgreen@example.org',
#   'Male',
#   '106.19.136.147',
#   'North Brittanytown'],
#  [298,
#   'John',
#   'Scott',
#   'cdavis@example.net',
#   'Male',
#   '131.120.195.88',
#   'Tammyhaven'],
#  [299,
#   'Annette',
#   'Roach',
#   'vancelisa@example.net',
#   'Female',
#   '154.95.28.234',
#   'Evansborough'],
#  [300,
#   'Stephanie',
#   'White',
#   'jaredadams@example.com',
#   'Female',
#   '190.75.28.159',
#   'Jamestown'],
#  [301,
#   'Amanda',
#   'Gonzalez',
#   'sullivanshane@example.org',
#   'Female',
#   '51.146.156.119',
#   'Kennedytown'],
#  [302,
#   'Brandon',
#   'Reed',
#   'valerieaguilar@example.com',
#   'Male',
#   '223.97.98.17',
#   'Port Jeffery'],
#  [303,
#   'Emily',
#   'Brown',
#   'christopheryoung@example.net',
#   'Female',
#   '173.102.226.57',
#   'Heatherborough'],
#  [304,
#   'Marcus',
#   'Richardson',
#   'kim28@example.com',
#   'Female',
#   '217.100.216.213',
#   'West Michael'],
#  [305,
#   'Robert',
#   'Mercer',
#   'bradleywilliams@example.net',
#   'Male',
#   '126.30.47.233',
#   'South Sarahtown'],
#  [306,
#   'Keith',
#   'Cook',
#   'tyronecarter@example.com',
#   'Female',
#   '113.82.78.159',
#   'Port Jasminechester'],
#  [307,
#   'Russell',
#   'Thompson',
#   'jonessarah@example.org',
#   'Male',
#   '104.150.21.3',
#   'Port Brian'],
#  [308,
#   'John',
#   'Smith',
#   'nsoto@example.org',
#   'Female',
#   '117.18.132.243',
#   'East Isaac'],
#  [309,
#   'James',
#   'Smith',
#   'taylormiller@example.com',
#   'Male',
#   '198.129.153.171',
#   'Hallmouth'],
#  [310,
#   'Lori',
#   'Austin',
#   'lisataylor@example.org',
#   'Male',
#   '34.200.0.50',
#   'Crystalmouth'],
#  [311,
#   'Cheryl',
#   'Bridges',
#   'connorking@example.net',
#   'Male',
#   '168.186.231.18',
#   'Hernandezfurt'],
#  [312,
#   'Lisa',
#   'Silva',
#   'dianaflynn@example.net',
#   'Female',
#   '75.26.66.124',
#   'South Louismouth'],
#  [313,
#   'Ashley',
#   'Valentine',
#   'joshua75@example.com',
#   'Male',
#   '91.218.80.35',
#   'East Michaeltown'],
#  [314,
#   'George',
#   'Hernandez',
#   'mathewmcdonald@example.org',
#   'Female',
#   '168.70.120.177',
#   'Alexanderbury'],
#  [315,
#   'Nicholas',
#   'Williams',
#   'swilcox@example.com',
#   'Female',
#   '10.145.80.77',
#   'Grahamstad'],
#  [316,
#   'Monica',
#   'Munoz',
#   'jtorres@example.org',
#   'Female',
#   '151.89.223.30',
#   'Nicholaschester'],
#  [317,
#   'Spencer',
#   'Clarke',
#   'lking@example.org',
#   'Female',
#   '108.109.170.222',
#   'West Michaelview'],
#  [318,
#   'Kevin',
#   'Hanson',
#   'amanda02@example.com',
#   'Female',
#   '205.94.155.29',
#   'New Lydiabury'],
#  [319,
#   'James',
#   'Moore',
#   'nelsonalexandria@example.com',
#   'Female',
#   '173.241.191.205',
#   'North Sharon'],
#  [320,
#   'Michael',
#   'Jimenez',
#   'joypeters@example.com',
#   'Female',
#   '142.131.75.224',
#   'New Davidmouth'],
#  [321,
#   'Diana',
#   'Mills',
#   'patrick68@example.net',
#   'Male',
#   '206.207.253.99',
#   'Torresfurt'],
#  [322,
#   'Tammy',
#   'Donaldson',
#   'rharrison@example.org',
#   'Female',
#   '48.185.123.76',
#   'South Brad'],
#  [323,
#   'Logan',
#   'Osborne',
#   'averycameron@example.net',
#   'Female',
#   '81.79.253.41',
#   'Evanstown'],
#  [324,
#   'Amanda',
#   'Davis',
#   'chanjose@example.net',
#   'Female',
#   '214.101.88.54',
#   'Port Laura'],
#  [325,
#   'Jennifer',
#   'Henderson',
#   'tsmith@example.com',
#   'Female',
#   '14.138.5.103',
#   'Liufort'],
#  [326,
#   'Lisa',
#   'Collins',
#   'johnsonariana@example.net',
#   'Male',
#   '165.43.175.43',
#   'North Timothyview'],
#  [327,
#   'Dana',
#   'Solis',
#   'myork@example.net',
#   'Female',
#   '42.226.82.63',
#   'Rossmouth'],
#  [328,
#   'Zachary',
#   'Simmons',
#   'zprice@example.net',
#   'Female',
#   '70.247.7.41',
#   'North Angelicahaven'],
#  [329,
#   'Hunter',
#   'Roberts',
#   'monica21@example.com',
#   'Male',
#   '181.162.145.127',
#   'East Todd'],
#  [330,
#   'James',
#   'Cook',
#   'sanchezmegan@example.org',
#   'Male',
#   '28.254.71.217',
#   'Perryview'],
#  [331,
#   'Gary',
#   'Lewis',
#   'nicholaswilliams@example.org',
#   'Female',
#   '77.199.71.218',
#   'Nicoleborough'],
#  [332,
#   'Savannah',
#   'Jones',
#   'fletcherlaura@example.net',
#   'Male',
#   '64.2.251.250',
#   'South Andrew'],
#  [333,
#   'Alyssa',
#   'Foster',
#   'jasonbrooks@example.org',
#   'Female',
#   '133.45.201.255',
#   'North Mary'],
#  [334,
#   'Tyler',
#   'Wilson',
#   'gonzalezedwin@example.net',
#   'Male',
#   '119.151.174.80',
#   'Sethmouth'],
#  [335,
#   'Dana',
#   'Carter',
#   'fwilson@example.org',
#   'Female',
#   '211.165.243.209',
#   'North Robertfurt'],
#  [336,
#   'Tiffany',
#   'Sims',
#   'vbrown@example.net',
#   'Male',
#   '156.97.8.71',
#   'Codyport'],
#  [337,
#   'Jessica',
#   'Cortez',
#   'dianegibson@example.com',
#   'Female',
#   '172.74.31.179',
#   'West Steven'],
#  [338,
#   'Phillip',
#   'Taylor',
#   'tina02@example.com',
#   'Female',
#   '4.143.28.80',
#   'New Jennifer'],
#  [339,
#   'Damon',
#   'Lee',
#   'jrogers@example.net',
#   'Male',
#   '148.134.170.15',
#   'Timothyfort'],
#  [340,
#   'Patricia',
#   'Bell',
#   'john54@example.org',
#   'Female',
#   '222.7.41.37',
#   'Aaronton'],
#  [341,
#   'Lauren',
#   'Taylor',
#   'brandy81@example.com',
#   'Male',
#   '201.227.102.156',
#   'Malloryberg'],
#  [342,
#   'Sydney',
#   'Sanchez',
#   'adamspaul@example.org',
#   'Male',
#   '159.238.239.249',
#   'New Lonnie'],
#  [343,
#   'James',
#   'Finley',
#   'clozano@example.net',
#   'Female',
#   '210.84.127.129',
#   'Castroville'],
#  [344,
#   'Morgan',
#   'Lopez',
#   'kyle51@example.org',
#   'Male',
#   '119.59.113.223',
#   'Michelefurt'],
#  [345,
#   'Laura',
#   'Parker',
#   'xsmith@example.org',
#   'Male',
#   '96.229.10.217',
#   'Lake Alexanderland'],
#  [346,
#   'Erik',
#   'Hoffman',
#   'helenlucero@example.com',
#   'Male',
#   '124.86.173.106',
#   'North Lisa'],
#  [347,
#   'Brandon',
#   'Ponce',
#   'kellyrangel@example.net',
#   'Female',
#   '214.96.21.164',
#   'Bryanstad'],
#  [348,
#   'Andrew',
#   'Smith',
#   'garciaaaron@example.org',
#   'Male',
#   '64.67.174.115',
#   'Port Evelyn'],
#  [349,
#   'Pamela',
#   'Bryant',
#   'jerrymaldonado@example.org',
#   'Female',
#   '40.155.112.246',
#   'Port Williamside'],
#  [350,
#   'Jessica',
#   'Duran',
#   'david91@example.org',
#   'Male',
#   '39.230.118.194',
#   'Nelsonside'],
#  [351,
#   'Ruth',
#   'Richardson',
#   'richardsjustin@example.net',
#   'Female',
#   '25.206.142.184',
#   'Port Amanda'],
#  [352,
#   'Danielle',
#   'Cherry',
#   'nlawrence@example.net',
#   'Male',
#   '192.79.107.43',
#   'North Jessica'],
#  [353,
#   'Joseph',
#   'Jones',
#   'jessebaker@example.org',
#   'Female',
#   '162.210.165.56',
#   'North Amandaberg'],
#  [354,
#   'Ethan',
#   'Walker',
#   'ashley31@example.net',
#   'Male',
#   '10.50.78.62',
#   'Donnafurt'],
#  [355,
#   'Katie',
#   'Henderson',
#   'kduncan@example.com',
#   'Female',
#   '183.46.161.107',
#   'Alexaville'],
#  [356,
#   'Sarah',
#   'Fletcher',
#   'patricia31@example.org',
#   'Male',
#   '56.70.216.24',
#   'New Ginaberg'],
#  [357,
#   'Mary',
#   'Kerr',
#   'udavidson@example.net',
#   'Male',
#   '101.110.38.44',
#   'North Alejandro'],
#  [358,
#   'Brandon',
#   'Lamb',
#   'amanda72@example.org',
#   'Female',
#   '80.78.197.162',
#   'Loriland'],
#  [359,
#   'Brianna',
#   'Ross',
#   'christinemoore@example.net',
#   'Female',
#   '174.133.95.218',
#   'North Dennis'],
#  [360,
#   'Michael',
#   'Meza',
#   'zgraves@example.com',
#   'Female',
#   '84.179.185.188',
#   'New Andreview'],
#  [361,
#   'Amy',
#   'Hooper',
#   'fergusonronnie@example.org',
#   'Male',
#   '162.58.1.8',
#   'Brooksstad'],
#  [362,
#   'Erika',
#   'Porter',
#   'wardalexis@example.org',
#   'Female',
#   '152.237.52.206',
#   'Rogerstad'],
#  [363,
#   'Mark',
#   'Hill',
#   'fowlerlauren@example.com',
#   'Male',
#   '1.252.78.155',
#   'Bondville'],
#  [364,
#   'David',
#   'Ross',
#   'jon00@example.net',
#   'Female',
#   '221.238.32.94',
#   'Craigmouth'],
#  [365,
#   'Michelle',
#   'Torres',
#   'greenmelanie@example.com',
#   'Female',
#   '142.255.55.83',
#   'Johnfurt'],
#  [366,
#   'Angela',
#   'Moore',
#   'emily34@example.net',
#   'Female',
#   '55.116.97.78',
#   'Dannybury'],
#  [367,
#   'Sheena',
#   'Turner',
#   'joseph50@example.com',
#   'Female',
#   '28.161.95.50',
#   'Christopherview'],
#  [368,
#   'Jessica',
#   'Russell',
#   'kcervantes@example.net',
#   'Male',
#   '21.72.179.24',
#   'North Stephen'],
#  [369,
#   'Matthew',
#   'Walker',
#   'halljeffery@example.net',
#   'Male',
#   '210.114.116.141',
#   'West Tonya'],
#  [370,
#   'Daniel',
#   'Curry',
#   'ulowe@example.org',
#   'Female',
#   '23.43.43.193',
#   'North Angela'],
#  [371,
#   'Karen',
#   'Dorsey',
#   'xelliott@example.net',
#   'Male',
#   '42.29.0.118',
#   'West Charlesport'],
#  [372,
#   'Daniel',
#   'Johnson',
#   'baldwindeborah@example.org',
#   'Male',
#   '63.28.44.205',
#   'Port David'],
#  [373,
#   'William',
#   'Graham',
#   'proctorsamuel@example.net',
#   'Female',
#   '94.160.158.49',
#   'South Sethburgh'],
#  [374,
#   'Leslie',
#   'Larson',
#   'jcollins@example.net',
#   'Female',
#   '202.101.212.46',
#   'Ruizfort'],
#  [375,
#   'Bryce',
#   'Shah',
#   'qhanna@example.net',
#   'Male',
#   '137.146.71.40',
#   'Bullockchester'],
#  [376,
#   'Christina',
#   'Fisher',
#   'margaret41@example.org',
#   'Female',
#   '60.124.165.74',
#   'Noahtown'],
#  [377,
#   'Heather',
#   'Williams',
#   'jessicahumphrey@example.net',
#   'Female',
#   '75.231.40.244',
#   'Taylorton'],
#  [378,
#   'Jessica',
#   'Brown',
#   'joneschristina@example.org',
#   'Female',
#   '216.188.181.228',
#   'Port Laurenview'],
#  [379,
#   'Courtney',
#   'King',
#   'michealallen@example.com',
#   'Male',
#   '87.56.207.158',
#   'New Timothy'],
#  [380,
#   'Connie',
#   'Smith',
#   'pmcneil@example.org',
#   'Female',
#   '27.80.223.83',
#   'New Maryside'],
#  [381,
#   'Cassandra',
#   'Gomez',
#   'ychapman@example.net',
#   'Male',
#   '172.224.205.155',
#   'North Ricky'],
#  [382,
#   'Dakota',
#   'Harmon',
#   'uchang@example.org',
#   'Male',
#   '210.224.66.96',
#   'South Cynthia'],
#  [383,
#   'Melinda',
#   'Hansen',
#   'travismartin@example.net',
#   'Male',
#   '197.91.65.138',
#   'New Marcus'],
#  [384,
#   'Anna',
#   'Lee',
#   'keithhudson@example.org',
#   'Female',
#   '123.254.80.187',
#   'North Latoya'],
#  [385,
#   'Jasmine',
#   'Thompson',
#   'patricia66@example.org',
#   'Male',
#   '192.252.81.39',
#   'South Cynthiatown'],
#  [386,
#   'Gina',
#   'Campbell',
#   'kellymcmahon@example.net',
#   'Male',
#   '212.53.32.202',
#   'Pollardview'],
#  [387,
#   'Timothy',
#   'Crawford',
#   'harrisonjohn@example.org',
#   'Male',
#   '199.62.80.214',
#   'West Gloria'],
#  [388,
#   'Thomas',
#   'Allen',
#   'john58@example.com',
#   'Female',
#   '145.84.16.204',
#   'South Eileen'],
#  [389,
#   'James',
#   'Johnson',
#   'jessetaylor@example.com',
#   'Male',
#   '54.216.69.30',
#   'West Luis'],
#  [390,
#   'Samantha',
#   'Zuniga',
#   'deleonjoshua@example.org',
#   'Female',
#   '11.8.47.116',
#   'Sabrinaberg'],
#  [391,
#   'Michelle',
#   'Williams',
#   'matthewsmith@example.org',
#   'Male',
#   '191.9.155.6',
#   'Flowersburgh'],
#  [392,
#   'Tammy',
#   'Stanton',
#   'sara19@example.org',
#   'Female',
#   '222.107.0.53',
#   'East Lauraborough'],
#  [393,
#   'Sarah',
#   'Patton',
#   'alexander54@example.net',
#   'Female',
#   '217.63.152.205',
#   'Wilsonborough'],
#  [394,
#   'Ashley',
#   'Hooper',
#   'jackson37@example.net',
#   'Male',
#   '20.215.71.104',
#   'New Lisamouth'],
#  [395,
#   'Joseph',
#   'Reed',
#   'lanebrian@example.com',
#   'Male',
#   '202.5.131.101',
#   'Nicholeton'],
#  [396,
#   'Martin',
#   'Watson',
#   'jonathan85@example.com',
#   'Male',
#   '39.3.18.162',
#   'Lopezland'],
#  [397,
#   'Matthew',
#   'Crosby',
#   'bschneider@example.net',
#   'Male',
#   '69.135.110.65',
#   'Michaelhaven'],
#  [398,
#   'Chelsea',
#   'Boyer',
#   'aramos@example.org',
#   'Male',
#   '90.155.58.182',
#   'North Kaitlinland'],
#  [399,
#   'Travis',
#   'Brown',
#   'michael67@example.com',
#   'Male',
#   '140.232.33.88',
#   'Jerrychester'],
#  [400,
#   'Anthony',
#   'Lopez',
#   'mejiakerri@example.com',
#   'Female',
#   '83.168.219.143',
#   'North Christopher'],
#  [401,
#   'Stanley',
#   'Rodriguez',
#   'whitemax@example.org',
#   'Female',
#   '66.216.237.16',
#   'South Robertchester'],
#  [402,
#   'Amanda',
#   'Dawson',
#   'xparker@example.net',
#   'Male',
#   '206.40.184.41',
#   'Lynchton'],
#  [403,
#   'Michael',
#   'Neal',
#   'sharon60@example.org',
#   'Male',
#   '113.159.41.116',
#   'Powellhaven'],
#  [404,
#   'Brittany',
#   'Hill',
#   'vburke@example.net',
#   'Male',
#   '30.130.90.71',
#   'Jessehaven'],
#  [405,
#   'Amanda',
#   'Ramirez',
#   'ingramlaura@example.net',
#   'Male',
#   '114.135.252.84',
#   'East Lori'],
#  [406,
#   'Kristen',
#   'Andrews',
#   'roberta94@example.com',
#   'Female',
#   '78.176.167.235',
#   'South Derekstad'],
#  [407,
#   'Adam',
#   'Barnett',
#   'martinjuan@example.net',
#   'Male',
#   '84.238.26.218',
#   'South Daniel'],
#  [408,
#   'Melissa',
#   'Osborne',
#   'elopez@example.org',
#   'Male',
#   '128.254.161.196',
#   'Ashleytown'],
#  [409,
#   'Joshua',
#   'Wilkerson',
#   'jameswarner@example.org',
#   'Female',
#   '202.172.211.197',
#   'East Randyhaven'],
#  [410,
#   'Brendan',
#   'Brooks',
#   'isabellalewis@example.com',
#   'Female',
#   '204.161.170.28',
#   'Lake David'],
#  [411,
#   'Sandra',
#   'Walsh',
#   'david29@example.org',
#   'Female',
#   '150.137.117.74',
#   'Mitchellmouth'],
#  [412,
#   'Laurie',
#   'Walker',
#   'petersmichael@example.net',
#   'Female',
#   '190.253.12.124',
#   'Johnsontown'],
#  [413,
#   'Richard',
#   'Holland',
#   'williamthompson@example.org',
#   'Male',
#   '145.118.38.196',
#   'Lake Angelabury'],
#  [414,
#   'Sabrina',
#   'Curtis',
#   'wwalker@example.net',
#   'Female',
#   '134.72.84.17',
#   'Port Charlesland'],
#  [415,
#   'Timothy',
#   'Espinoza',
#   'lynchrobert@example.org',
#   'Male',
#   '13.248.27.125',
#   'Robertsonhaven'],
#  [416,
#   'Christine',
#   'Joyce',
#   'jhorn@example.com',
#   'Male',
#   '29.210.236.252',
#   'Edwardport'],
#  [417,
#   'Lisa',
#   'Williams',
#   'vcastillo@example.org',
#   'Female',
#   '211.127.140.174',
#   'East Frederick'],
#  [418,
#   'Jacob',
#   'Smith',
#   'masonmiller@example.org',
#   'Male',
#   '79.6.109.155',
#   'Timothyton'],
#  [419,
#   'Kristine',
#   'Brown',
#   'gnelson@example.org',
#   'Female',
#   '187.81.123.214',
#   'Port Patrick'],
#  [420,
#   'Tara',
#   'Duarte',
#   'edwardallen@example.org',
#   'Female',
#   '4.77.71.200',
#   'New Nicole'],
#  [421,
#   'Brittany',
#   'Castillo',
#   'michaeldrake@example.org',
#   'Female',
#   '105.88.65.249',
#   'Beckyberg'],
#  [422,
#   'Virginia',
#   'Jennings',
#   'mullinsdarlene@example.org',
#   'Female',
#   '56.196.32.49',
#   'Lake Diana'],
#  [423,
#   'Lauren',
#   'Stein',
#   'qhall@example.org',
#   'Male',
#   '59.219.140.253',
#   'East Waltermouth'],
#  [424,
#   'Dustin',
#   'Taylor',
#   'hallchristopher@example.com',
#   'Female',
#   '164.225.13.10',
#   'Westside'],
#  [425,
#   'John',
#   'Benson',
#   'vbolton@example.org',
#   'Male',
#   '83.60.243.68',
#   'Ambermouth'],
#  [426,
#   'Jerry',
#   'Crane',
#   'ayalatheodore@example.org',
#   'Female',
#   '50.190.5.90',
#   'Allenburgh'],
#  [427,
#   'Christopher',
#   'Lloyd',
#   'johnny08@example.com',
#   'Male',
#   '164.210.0.85',
#   'Hooperstad'],
#  [428,
#   'Pamela',
#   'Obrien',
#   'bradfordbecky@example.org',
#   'Female',
#   '4.41.37.196',
#   'Port Gregory'],
#  [429,
#   'Julie',
#   'Dixon',
#   'jeremy96@example.net',
#   'Male',
#   '170.11.190.26',
#   'Bakerton'],
#  [430,
#   'Danny',
#   'Thomas',
#   'kevin02@example.org',
#   'Male',
#   '147.150.12.97',
#   'Boydtown'],
#  [431,
#   'Heidi',
#   'Chang',
#   'llowery@example.net',
#   'Female',
#   '217.95.93.170',
#   'New Lauren'],
#  [432,
#   'Alexis',
#   'Turner',
#   'sandovalsteven@example.org',
#   'Female',
#   '144.213.53.141',
#   'Julieborough'],
#  [433,
#   'Aaron',
#   'Mathews',
#   'carpenteryolanda@example.org',
#   'Female',
#   '107.112.39.123',
#   'North Paulafurt'],
#  [434,
#   'Casey',
#   'Lee',
#   'gnichols@example.com',
#   'Male',
#   '221.182.19.173',
#   'East Kellystad'],
#  [435,
#   'Joseph',
#   'Silva',
#   'paul65@example.net',
#   'Male',
#   '11.152.108.202',
#   'Tammieside'],
#  [436,
#   'Scott',
#   'Richard',
#   'grimescristina@example.net',
#   'Female',
#   '3.225.103.82',
#   'South Megan'],
#  [437,
#   'Debra',
#   'Bailey',
#   'xtaylor@example.net',
#   'Female',
#   '80.40.219.28',
#   'North Shelley'],
#  [438,
#   'Lisa',
#   'Harvey',
#   'hilljohn@example.net',
#   'Male',
#   '221.62.81.238',
#   'North Lorettamouth'],
#  [439,
#   'Nicholas',
#   'Jones',
#   'jamesfuller@example.com',
#   'Female',
#   '59.104.5.20',
#   'North Ericfurt'],
#  [440,
#   'Troy',
#   'Kelley',
#   'iwilson@example.org',
#   'Female',
#   '125.132.23.7',
#   'Randallhaven'],
#  [441,
#   'Robin',
#   'Blanchard',
#   'vtran@example.org',
#   'Female',
#   '106.76.114.139',
#   'Jacksonside'],
#  [442,
#   'Sarah',
#   'Carter',
#   'probinson@example.org',
#   'Male',
#   '76.88.62.86',
#   'South Aaron'],
#  [443,
#   'Marisa',
#   'Williams',
#   'johnstonjohn@example.com',
#   'Male',
#   '37.233.35.53',
#   'Lake Andrewmouth'],
#  [444,
#   'Julian',
#   'Bell',
#   'whiterobert@example.org',
#   'Male',
#   '133.182.172.171',
#   'Kimbury'],
#  [445,
#   'Christina',
#   'Gill',
# ...
#   'Male',
#   '157.222.247.25',
#   'Rebeccafort'],
#  [854,
#   'George',
#   'Lindsey',
#   'tranbrandon@example.com',
#   'Female',
#   '70.88.150.242',
#   'East Samuelfort'],
#  [855,
#   'Michael',
#   'White',
#   'danielbright@example.org',
#   'Male',
#   '223.193.201.161',
#   'East Robert'],
#  [856,
#   'Michael',
#   'Boone',
#   'mirandabrittany@example.com',
#   'Male',
#   '67.37.129.6',
#   'South Carrieville'],
#  [857,
#   'Lisa',
#   'Jordan',
#   'reginarojas@example.com',
#   'Male',
#   '137.180.184.10',
#   'New Jamesland'],
#  [858,
#   'Caitlyn',
#   'Hansen',
#   'nathan30@example.org',
#   'Male',
#   '86.193.108.220',
#   'Simpsonhaven'],
#  [859,
#   'Michael',
#   'Tanner',
#   'amykeith@example.com',
#   'Female',
#   '196.96.28.221',
#   'Jonathanstad'],
#  [860,
#   'Eric',
#   'Lawrence',
#   'lauren00@example.com',
#   'Male',
#   '132.212.9.222',
#   'Elizabethborough'],
#  [861,
#   'Olivia',
#   'Vasquez',
#   'williamneal@example.net',
#   'Male',
#   '154.4.52.60',
#   'Francoview'],
#  [862,
#   'Stephanie',
#   'Burke',
#   'qgregory@example.net',
#   'Male',
#   '10.109.92.59',
#   'New Amanda'],
#  [863,
#   'Jerome',
#   'Mccann',
#   'johnsondanielle@example.com',
#   'Male',
#   '163.155.109.71',
#   'West Brenda'],
#  [864,
#   'Gilbert',
#   'Odonnell',
#   'james37@example.net',
#   'Male',
#   '24.108.120.196',
#   'New Carlos'],
#  [865,
#   'Laura',
#   'Fitzgerald',
#   'james53@example.com',
#   'Female',
#   '70.83.233.29',
#   'Lake Melissa'],
#  [866,
#   'Crystal',
#   'Berry',
#   'lucaszachary@example.net',
#   'Male',
#   '58.27.184.82',
#   'New Grant'],
#  [867,
#   'James',
#   'Thompson',
#   'robert06@example.com',
#   'Male',
#   '154.144.14.150',
#   'West Sarahville'],
#  [868,
#   'William',
#   'Clark',
#   'gonzalezkevin@example.org',
#   'Male',
#   '179.55.181.221',
#   'Howardchester'],
#  [869,
#   'Amanda',
#   'Johnson',
#   'albertmartinez@example.org',
#   'Female',
#   '141.101.112.218',
#   'Taylorhaven'],
#  [870,
#   'Michelle',
#   'Thompson',
#   'denise13@example.net',
#   'Female',
#   '202.30.253.155',
#   'Franklinfurt'],
#  [871,
#   'Joanne',
#   'Hawkins',
#   'whartman@example.org',
#   'Female',
#   '192.153.191.36',
#   'Port Maryborough'],
#  [872,
#   'Courtney',
#   'Foster',
#   'alexander05@example.org',
#   'Female',
#   '145.11.80.183',
#   'Dennisland'],
#  [873,
#   'Anthony',
#   'Wallace',
#   'uwilson@example.org',
#   'Male',
#   '45.124.221.188',
#   'Port Brittany'],
#  [874,
#   'Jill',
#   'Bryant',
#   'everettcatherine@example.com',
#   'Male',
#   '128.205.199.119',
#   'East Brandy'],
#  [875,
#   'Allison',
#   'Tyler',
#   'zavalakendra@example.net',
#   'Female',
#   '223.237.53.94',
#   'Port Annette'],
#  [876,
#   'John',
#   'Ritter',
#   'elizabeth78@example.com',
#   'Female',
#   '150.163.5.193',
#   'Thompsonside'],
#  [877,
#   'Derek',
#   'Williams',
#   'adamhall@example.net',
#   'Male',
#   '191.103.74.55',
#   'Lake Coreyport'],
#  [878,
#   'Christopher',
#   'Carson',
#   'jason39@example.org',
#   'Male',
#   '90.119.5.109',
#   'Danaport'],
#  [879,
#   'Billy',
#   'Chavez',
#   'raylambert@example.com',
#   'Male',
#   '135.147.176.99',
#   'Brownchester'],
#  [880,
#   'Robert',
#   'Thomas',
#   'oroberts@example.com',
#   'Female',
#   '214.41.6.9',
#   'Lunaberg'],
#  [881,
#   'Matthew',
#   'Moreno',
#   'patrickerickson@example.org',
#   'Male',
#   '116.107.252.145',
#   'Jonesport'],
#  [882,
#   'Teresa',
#   'Le',
#   'rrose@example.org',
#   'Female',
#   '93.43.136.196',
#   'Joelton'],
#  [883,
#   'Tina',
#   'Phillips',
#   'jacksonjones@example.net',
#   'Male',
#   '78.111.36.240',
#   'Kimberlyport'],
#  [884,
#   'Brandon',
#   'Small',
#   'katherine26@example.net',
#   'Female',
#   '72.66.250.180',
#   'West Brianmouth'],
#  [885,
#   'Angela',
#   'Michael',
#   'rachelking@example.net',
#   'Male',
#   '105.86.35.211',
#   'Jameston'],
#  [886,
#   'Betty',
#   'Jones',
#   'jerrywashington@example.com',
#   'Male',
#   '194.102.81.155',
#   'Johnville'],
#  [887,
#   'Clifford',
#   'Torres',
#   'christinapatton@example.org',
#   'Male',
#   '216.225.38.237',
#   'Larryhaven'],
#  [888,
#   'James',
#   'Wood',
#   'crystalleblanc@example.net',
#   'Male',
#   '117.58.132.148',
#   'Calvintown'],
#  [889,
#   'Tina',
#   'Galloway',
#   'sherianderson@example.com',
#   'Female',
#   '78.115.83.46',
#   'South Cassandra'],
#  [890,
#   'Kelsey',
#   'Casey',
#   'michelleclayton@example.net',
#   'Female',
#   '206.200.239.90',
#   'West Angelafort'],
#  [891,
#   'Catherine',
#   'Smith',
#   'deanna48@example.net',
#   'Female',
#   '217.146.56.204',
#   'Mitchellville'],
#  [892,
#   'Sarah',
#   'Acosta',
#   'melissa22@example.org',
#   'Female',
#   '183.155.35.252',
#   'West Catherine'],
#  [893,
#   'Kristina',
#   'Smith',
#   'melissa46@example.net',
#   'Male',
#   '58.116.10.170',
#   'Lake Danielshire'],
#  [894,
#   'Theresa',
#   'Watson',
#   'williewall@example.net',
#   'Male',
#   '152.14.249.143',
#   'East Marilynview'],
#  [895,
#   'Jennifer',
#   'Mejia',
#   'paulamber@example.org',
#   'Male',
#   '133.43.52.98',
#   'Martinfurt'],
#  [896,
#   'Andrea',
#   'Waters',
#   'wthornton@example.org',
#   'Male',
#   '109.91.56.33',
#   'West Tammyborough'],
#  [897,
#   'Melinda',
#   'Rose',
#   'owhitehead@example.org',
#   'Female',
#   '59.98.0.31',
#   'Jimmystad'],
#  [898,
#   'Anthony',
#   'Ellis',
#   'jjohnson@example.net',
#   'Female',
#   '83.142.30.100',
#   'Lake Davidton'],
#  [899,
#   'Sean',
#   'Arroyo',
#   'clewis@example.org',
#   'Male',
#   '169.118.27.131',
#   'Johntown'],
#  [900,
#   'Anthony',
#   'Garcia',
#   'marksmith@example.com',
#   'Female',
#   '178.199.87.121',
#   'Port Nicholas'],
#  [901,
#   'Jonathan',
#   'Baker',
#   'david79@example.org',
#   'Male',
#   '83.202.83.36',
#   'Youngview'],
#  [902,
#   'Daniel',
#   'Johnson',
#   'thomaslewis@example.com',
#   'Female',
#   '84.157.102.198',
#   'South Scott'],
#  [903,
#   'Allison',
#   'Hall',
#   'suzannemarquez@example.com',
#   'Female',
#   '144.38.149.168',
#   'West Thomasshire'],
#  [904,
#   'Karen',
#   'Rodgers',
#   'jonathanburns@example.net',
#   'Female',
#   '114.70.169.230',
#   'Jenningsview'],
#  [905,
#   'Bonnie',
#   'Torres',
#   'cynthia64@example.org',
#   'Male',
#   '87.238.247.188',
#   'Katieborough'],
#  [906,
#   'Sandra',
#   'Arnold',
#   'xpeterson@example.net',
#   'Male',
#   '73.189.210.245',
#   'Lake Meganton'],
#  [907,
#   'Kevin',
#   'Carter',
#   'fbenson@example.org',
#   'Male',
#   '136.136.138.155',
#   'Dominguezmouth'],
#  [908,
#   'Micheal',
#   'Osborn',
#   'tlloyd@example.net',
#   'Female',
#   '50.130.138.102',
#   'Greenchester'],
#  [909,
#   'Xavier',
#   'Moore',
#   'kristenwood@example.com',
#   'Male',
#   '84.99.123.29',
#   'Feliciashire'],
#  [910,
#   'Ryan',
#   'Hawkins',
#   'kristen31@example.com',
#   'Female',
#   '180.104.5.181',
#   'New Cynthiaport'],
#  [911,
#   'Mary',
#   'Smith',
#   'chartman@example.com',
#   'Female',
#   '77.140.69.108',
#   'West Anthony'],
#  [912,
#   'Angela',
#   'Harrison',
#   'robertbender@example.org',
#   'Female',
#   '202.109.241.163',
#   'New Blakeside'],
#  [913,
#   'Amy',
#   'Burke',
#   'owenmelissa@example.org',
#   'Male',
#   '47.117.97.242',
#   'Lopezfurt'],
#  [914,
#   'John',
#   'Freeman',
#   'tamararichards@example.org',
#   'Male',
#   '196.68.6.68',
#   'Lake Jacobland'],
#  [915,
#   'Dwayne',
#   'Lynch',
#   'ehall@example.net',
#   'Male',
#   '4.195.141.176',
#   'Port Jonathan'],
#  [916,
#   'Jesus',
#   'Lee',
#   'jenkinstodd@example.org',
#   'Male',
#   '152.222.58.197',
#   'Tracyton'],
#  [917,
#   'Stacy',
#   'Ramsey',
#   'christensenann@example.org',
#   'Female',
#   '149.89.63.255',
#   'Cuevasburgh'],
#  [918,
#   'Jacob',
#   'Mason',
#   'stephanieramsey@example.org',
#   'Male',
#   '113.228.109.245',
#   'South Janet'],
#  [919,
#   'Andrew',
#   'Martinez',
#   'rwilliams@example.org',
#   'Female',
#   '22.10.38.32',
#   'Ingrambury'],
#  [920,
#   'Kelly',
#   'Harris',
#   'michealstewart@example.net',
#   'Female',
#   '152.199.206.172',
#   'Lake Kerryville'],
#  [921,
#   'Kelly',
#   'Jones',
#   'stephanie09@example.com',
#   'Female',
#   '20.209.99.98',
#   'Blackstad'],
#  [922,
#   'Joseph',
#   'Ibarra',
#   'justin03@example.org',
#   'Male',
#   '3.122.177.49',
#   'Port Sarah'],
#  [923,
#   'Craig',
#   'Smith',
#   'aromero@example.net',
#   'Male',
#   '195.80.56.248',
#   'Port Jennifer'],
#  [924,
#   'Arthur',
#   'Francis',
#   'lydia09@example.com',
#   'Male',
#   '76.160.121.24',
#   'Robertville'],
#  [925,
#   'Carl',
#   'Wiggins',
#   'davidrodriguez@example.org',
#   'Male',
#   '121.146.191.65',
#   'South Gabriel'],
#  [926,
#   'Melissa',
#   'Lowe',
#   'anna66@example.com',
#   'Female',
#   '42.114.18.119',
#   'Martinmouth'],
#  [927,
#   'Anthony',
#   'Cook',
#   'howardscott@example.org',
#   'Female',
#   '69.234.152.19',
#   'Lake Jessicaview'],
#  [928,
#   'Christopher',
#   'Lane',
#   'kim47@example.com',
#   'Female',
#   '101.198.75.64',
#   'Frymouth'],
#  [929,
#   'Monica',
#   'Sanchez',
#   'steven74@example.net',
#   'Female',
#   '204.133.68.47',
#   'Ayalahaven'],
#  [930,
#   'Vincent',
#   'Williams',
#   'bryannunez@example.net',
#   'Male',
#   '180.228.238.214',
#   'Saundersland'],
#  [931,
#   'Amanda',
#   'Fitzgerald',
#   'martindaniel@example.com',
#   'Male',
#   '42.238.229.183',
#   'North Carolynside'],
#  [932,
#   'Ashley',
#   'Stanley',
#   'cthompson@example.org',
#   'Male',
#   '71.126.180.242',
#   'Port Amberhaven'],
#  [933,
#   'Rebecca',
#   'Rodriguez',
#   'kristine16@example.net',
#   'Female',
#   '92.244.204.96',
#   'Emilyfurt'],
#  [934,
#   'Yvette',
#   'Myers',
#   'norma57@example.com',
#   'Female',
#   '45.28.33.6',
#   'North Jessica'],
#  [935,
#   'Keith',
#   'Williams',
#   'garypope@example.net',
#   'Female',
#   '175.207.38.248',
#   'Aguirreport'],
#  [936,
#   'Rebecca',
#   'Navarro',
#   'munoztammy@example.com',
#   'Male',
#   '133.24.48.234',
#   'Pagestad'],
#  [937,
#   'Angel',
#   'Porter',
#   'stephanie85@example.net',
#   'Female',
#   '107.138.43.245',
#   'Lake Davidtown'],
#  [938,
#   'Carla',
#   'Forbes',
#   'orobinson@example.com',
#   'Female',
#   '113.215.151.110',
#   'Wallacemouth'],
#  [939,
#   'Regina',
#   'Bowen',
#   'karenmccarthy@example.net',
#   'Male',
#   '144.41.112.52',
#   'Thompsonside'],
#  [940,
#   'Michelle',
#   'Johnson',
#   'sara82@example.com',
#   'Female',
#   '30.83.37.95',
#   'Lake Jeremy'],
#  [941,
#   'Kayla',
#   'Lynn',
#   'angel37@example.com',
#   'Male',
#   '63.251.92.62',
#   'Bishopmouth'],
#  [942,
#   'Cynthia',
#   'Allen',
#   'ugraham@example.com',
#   'Female',
#   '206.181.224.38',
#   'Jacksonbury'],
#  [943,
#   'James',
#   'Atkinson',
#   'jenniferjohnson@example.net',
#   'Female',
#   '93.68.244.51',
#   'Ryanshire'],
#  [944,
#   'Wendy',
#   'Maldonado',
#   'joseph62@example.org',
#   'Female',
#   '78.40.113.69',
#   'Johnsontown'],
#  [945,
#   'John',
#   'Barrett',
#   'alexanderbrandon@example.com',
#   'Male',
#   '214.131.244.70',
#   'West Bradley'],
#  [946,
#   'Michael',
#   'Hunter',
#   'jeremiahsmith@example.org',
#   'Female',
#   '67.175.71.31',
#   'Michaelburgh'],
#  [947,
#   'Jacqueline',
#   'Mccann',
#   'qthomas@example.com',
#   'Male',
#   '177.222.255.230',
#   'East Vincentmouth'],
#  [948,
#   'Virginia',
#   'Cox',
#   'patriciarocha@example.com',
#   'Female',
#   '167.124.203.104',
#   'Lake Kendrashire'],
#  [949,
#   'Timothy',
#   'Bryan',
#   'canderson@example.org',
#   'Male',
#   '173.212.24.53',
#   'Blankenshipmouth'],
#  [950,
#   'Robert',
#   'Lopez',
#   'rreynolds@example.com',
#   'Male',
#   '109.206.211.227',
#   'East Jack'],
#  [951,
#   'Lisa',
#   'Smith',
#   'mckeeashley@example.com',
#   'Male',
#   '26.219.157.118',
#   'Port Garrett'],
#  [952,
#   'Sarah',
#   'Wright',
#   'vjones@example.net',
#   'Female',
#   '216.126.73.2',
#   'Michaelville'],
#  [953,
#   'Jessica',
#   'Ramos',
#   'rodney14@example.com',
#   'Male',
#   '198.6.31.234',
#   'Terryfurt'],
#  [954,
#   'Kim',
#   'Young',
#   'louisrobinson@example.net',
#   'Female',
#   '50.103.17.201',
#   'Joshuamouth'],
#  [955,
#   'Gabriela',
#   'Graham',
#   'xgonzalez@example.net',
#   'Female',
#   '73.247.185.92',
#   'West Brandi'],
#  [956,
#   'Danielle',
#   'Cooke',
#   'baldwinjames@example.com',
#   'Female',
#   '109.135.138.196',
#   'West Scott'],
#  [957,
#   'James',
#   'Long',
#   'melaniethornton@example.net',
#   'Female',
#   '155.181.44.68',
#   'Madisonberg'],
#  [958,
#   'Miguel',
#   'Gallagher',
#   'umiranda@example.net',
#   'Female',
#   '164.39.110.184',
#   'New Kayla'],
#  [959,
#   'Thomas',
#   'Moyer',
#   'zsimmons@example.org',
#   'Male',
#   '110.180.124.184',
#   'West Austin'],
#  [960,
#   'Brian',
#   'Anderson',
#   'jonathanmiller@example.com',
#   'Female',
#   '55.192.192.235',
#   'Combsport'],
#  [961,
#   'Valerie',
#   'Watson',
#   'preston80@example.com',
#   'Female',
#   '82.55.77.80',
#   'Mooretown'],
#  [962,
#   'Maurice',
#   'Norton',
#   'kathleen83@example.org',
#   'Male',
#   '216.194.41.189',
#   'South Abigail'],
#  [963,
#   'Kyle',
#   'Brown',
#   'amberwright@example.com',
#   'Female',
#   '111.21.121.208',
#   'Williamsberg'],
#  [964,
#   'David',
#   'Welch',
#   'stacycarson@example.org',
#   'Female',
#   '41.217.66.7',
#   'Doyleville'],
#  [965,
#   'Kathryn',
#   'Sanders',
#   'davidhines@example.com',
#   'Male',
#   '64.170.174.101',
#   'Christinaland'],
#  [966,
#   'Kathryn',
#   'Marshall',
#   'egibson@example.org',
#   'Female',
#   '183.148.78.232',
#   'Lorifurt'],
#  [967,
#   'Deborah',
#   'Larson',
#   'donald74@example.com',
#   'Male',
#   '98.225.164.189',
#   'Paulaport'],
#  [968,
#   'Mark',
#   'Harvey',
#   'ashley21@example.com',
#   'Male',
#   '178.206.237.65',
#   'Carlsonborough'],
#  [969,
#   'Mike',
#   'Chan',
#   'reyesrobert@example.net',
#   'Male',
#   '56.190.80.115',
#   'South Christophermouth'],
#  [970,
#   'Christopher',
#   'Crawford',
#   'katherine48@example.com',
#   'Male',
#   '19.81.205.56',
#   'Davisville'],
#  [971,
#   'Thomas',
#   'Velasquez',
#   'gail24@example.net',
#   'Male',
#   '116.220.15.199',
#   'West Michaelborough'],
#  [972,
#   'Kara',
#   'Davis',
#   'valerie97@example.org',
#   'Female',
#   '29.103.176.54',
#   'North Bradleychester'],
#  [973,
#   'Christopher',
#   'Fields',
#   'marcusgillespie@example.net',
#   'Female',
#   '219.126.16.104',
#   'Amyville'],
#  [974,
#   'William',
#   'Foster',
#   'kingjulia@example.com',
#   'Male',
#   '58.102.95.50',
#   'Andrewborough'],
#  [975,
#   'Elizabeth',
#   'Coleman',
#   'gfowler@example.org',
#   'Female',
#   '109.26.52.193',
#   'Simmonsfort'],
#  [976,
#   'Gary',
#   'Jimenez',
#   'amandakaiser@example.org',
#   'Female',
#   '204.222.44.125',
#   'Lake Gabrielle'],
#  [977,
#   'James',
#   'Norton',
#   'aholloway@example.org',
#   'Male',
#   '134.155.244.135',
#   'Crystalville'],
#  [978,
#   'Yvette',
#   'Howard',
#   'rjones@example.net',
#   'Male',
#   '117.190.119.194',
#   'Lake Rodney'],
#  [979,
#   'John',
#   'Cook',
#   'henrybrian@example.org',
#   'Female',
#   '222.195.100.158',
#   'Johnmouth'],
#  [980,
#   'Brian',
#   'Stevens',
#   'walterstonya@example.net',
#   'Male',
#   '47.12.140.35',
#   'New Jessica'],
#  [981,
#   'Lee',
#   'Campbell',
#   'rodriguezscott@example.com',
#   'Female',
#   '70.80.234.66',
#   'Olsenberg'],
#  [982,
#   'Melanie',
#   'Castro',
#   'patrickjacobson@example.org',
#   'Female',
#   '134.17.253.113',
#   'Maryside'],
#  [983,
#   'Anthony',
#   'Herring',
#   'brownbarbara@example.org',
#   'Female',
#   '92.114.134.36',
#   'Jamesshire'],
#  [984,
#   'Ronald',
#   'Jones',
#   'mccartymark@example.com',
#   'Male',
#   '183.105.137.223',
#   'Port Kellyview'],
#  [985,
#   'Katherine',
#   'Murray',
#   'fcruz@example.net',
#   'Male',
#   '29.104.50.198',
#   'New Tony'],
#  [986,
#   'Christopher',
#   'Green',
#   'jadams@example.com',
#   'Female',
#   '162.80.3.23',
#   'East Richardmouth'],
#  [987,
#   'Bradley',
#   'Patton',
#   'michael48@example.com',
#   'Male',
#   '6.179.164.178',
#   'Barberport'],
#  [988,
#   'Kellie',
#   'Hernandez',
#   'avilamegan@example.org',
#   'Male',
#   '138.198.17.31',
#   'New Brittany'],
#  [989,
#   'Amanda',
#   'Powell',
#   'walkerkayla@example.org',
#   'Female',
#   '60.252.181.119',
#   'East Danielberg'],
#  [990,
#   'Leah',
#   'David',
#   'roachcrystal@example.net',
#   'Male',
#   '113.138.172.71',
#   'Douglasmouth'],
#  [991,
#   'John',
#   'Rivera',
#   'watsonamy@example.org',
#   'Female',
#   '123.221.69.129',
#   'Nataliefurt'],
#  [992,
#   'Heidi',
#   'Gonzalez',
#   'sbailey@example.net',
#   'Male',
#   '96.207.141.252',
#   'East Ethan'],
#  [993,
#   'David',
#   'Hernandez',
#   'marshallhailey@example.net',
#   'Female',
#   '87.139.93.38',
#   'South Jacob'],
#  [994,
#   'Anthony',
#   'Pham',
#   'matthew83@example.com',
#   'Male',
#   '179.214.247.64',
#   'Meyerfort'],
#  [995,
#   'Michael',
#   'Gordon',
#   'robertstevens@example.org',
#   'Male',
#   '39.33.245.11',
#   'Tonyland'],
#  [996,
#   'Aaron',
#   'Roth',
#   'emily12@example.org',
#   'Male',
#   '107.145.155.165',
#   'Lake Samantha'],
#  [997,
#   'Brandon',
#   'Nguyen',
#   'watsondawn@example.net',
#   'Male',
#   '170.82.242.197',
#   'North Ashley'],
#  [998,
#   'Anthony',
#   'Williams',
#   'michaeljackson@example.org',
#   'Male',
#   '18.112.81.70',
#   'New Edwardside'],
#  [999,
#   'Michael',
#   'Johnson',
#   'tmay@example.org',
#   'Female',
#   '132.56.99.188',
#   'Port Gabrielfort'],
#  [1000,
#   'Nathaniel',
#   'Woods',
#   'nicholas66@example.net',
#   'Male',
#   '97.172.95.52',
#   'Mclaughlinland'],
#  ...]

# %%
# Escrever os dados para um arquivo CSV
with open('dados.csv', mode='w', newline='') as file:
    writer = csv.writer(file)
    writer.writerow(headers)  # Escrever os headers
    writer.writerows(data)    # Escrever os dados

# %% [markdown]
# Neste exemplo:
# - Utilizamos a biblioteca `csv` para trabalhar com arquivos CSV.
# - Utilizamos a biblioteca `faker` para gerar dados falsos, como nomes, endereços de e-mail, IP e cidades.
# - Geramos 2000 linhas de dados aleatórios, cada uma com um ID, primeiro nome, sobrenome, e-mail, gênero, endereço IP e cidade.
# - Escrevemos os dados para um arquivo CSV chamado `dados.csv`, com os headers na primeira linha.

# %% [markdown]
# ____
# ## Lendo arquivos CSV

# %%
import csv

# %% [markdown]
# Ao passar o caminho do arquivo, certifique-se de incluir a extensão se houver uma. Você deve ser capaz de usar o recurso de autocompletar com a tecla Tab para o nome do arquivo. Se você não conseguir usar o autocompletar, é um bom indicador de que o arquivo não está na mesma localização do seu caderno. Você sempre pode digitar o caminho completo do arquivo (ele terá um formato semelhante à saída de **pwd**).

# %%
data = open('dados.csv')

# %%
data
# Out:
# <_io.TextIOWrapper name='dados.csv' mode='r' encoding='cp1252'>

# %% [markdown]
# ### Encoding
#
# Frequentemente, arquivos CSV podem conter caracteres que não podem ser interpretados com o Python padrão, como o símbolo **@**, ou mesmo caracteres estrangeiros. Vamos ver um exemplo desse tipo de erro ([isso é bastante comum, por isso é importante revisar](https://stackoverflow.com/questions/9233027/unicodedecodeerror-charmap-codec-cant-decode-byte-x-in-position-y-character)).

# %%
csv_data = csv.reader(data)

# %% [markdown]
# Converter para uma lista causará um erro, observe a linha **can't decode** no erro, isso indica que temos um problema de codificação!

# %%
data_lines = list(csv_data)

# %%
data_lines
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'],
#  ['1',
#   'Jaime',
#   'Fowler',
#   'watkinsanthony@example.net',
#   'Male',
#   '129.94.178.90',
#   'Christopherberg'],
#  ['2',
#   'John',
#   'Huffman',
#   'molinabryan@example.net',
#   'Male',
#   '24.66.51.187',
#   'Karlatown'],
#  ['3',
#   'Alison',
#   'Pennington',
#   'sextonbrittany@example.net',
#   'Female',
#   '165.164.59.91',
#   'Theresachester'],
#  ['4',
#   'Daniel',
#   'Barnett',
#   'james32@example.org',
#   'Female',
#   '15.136.148.175',
#   'South Jason'],
#  ['5',
#   'Jenna',
#   'Miller',
#   'steven15@example.com',
#   'Female',
#   '205.16.74.147',
#   'North Karla'],
#  ['6',
#   'Amber',
#   'Daniels',
#   'cooperautumn@example.org',
#   'Male',
#   '133.120.153.190',
#   'Beanhaven'],
#  ['7',
#   'Janice',
#   'Watson',
#   'zhudson@example.com',
#   'Male',
#   '205.234.166.4',
#   'Lake Keith'],
#  ['8',
#   'Howard',
#   'Smith',
#   'justinhenry@example.org',
#   'Male',
#   '42.222.35.150',
#   'Walkerstad'],
#  ['9',
#   'Kevin',
#   'Rangel',
#   'kelly21@example.net',
#   'Male',
#   '157.232.238.144',
#   'East Kyle'],
#  ['10',
#   'Denise',
#   'Boyd',
#   'nicholas82@example.com',
#   'Female',
#   '176.160.102.1',
#   'West Brandyfort'],
#  ['11',
#   'Angela',
#   'Hernandez',
#   'anthonyrussell@example.com',
#   'Male',
#   '162.185.230.110',
#   'Port Brian'],
#  ['12',
#   'Christine',
#   'Shaw',
#   'matthew49@example.net',
#   'Male',
#   '52.190.109.216',
#   'North Brandon'],
#  ['13',
#   'Adam',
#   'Williams',
#   'millerchristopher@example.com',
#   'Female',
#   '8.214.104.101',
#   'West Brian'],
#  ['14',
#   'Jessica',
#   'Mullen',
#   'amanda24@example.com',
#   'Female',
#   '140.160.57.60',
#   'Lake Gabrielside'],
#  ['15',
#   'Sydney',
#   'Stone',
#   'thomasjuan@example.com',
#   'Male',
#   '210.42.90.112',
#   'Port Ebony'],
#  ['16',
#   'Kenneth',
#   'Wilson',
#   'erik75@example.com',
#   'Female',
#   '9.23.152.156',
#   'Lake Michael'],
#  ['17',
#   'Jessica',
#   'Gonzalez',
#   'zbrown@example.com',
#   'Female',
#   '174.30.14.14',
#   'Bethanymouth'],
#  ['18',
#   'Briana',
#   'Cardenas',
#   'jessica66@example.org',
#   'Male',
#   '204.2.143.81',
#   'South Nicoleton'],
#  ['19',
#   'Spencer',
#   'Osborne',
#   'sarabaker@example.org',
#   'Female',
#   '99.72.253.72',
#   'Jonathanton'],
#  ['20',
#   'Benjamin',
#   'Alvarado',
#   'martinezblake@example.net',
#   'Female',
#   '81.239.160.222',
#   'Danielsberg'],
#  ['21',
#   'Rachel',
#   'Nelson',
#   'glarsen@example.net',
#   'Male',
#   '141.170.166.155',
#   'West Michelle'],
#  ['22',
#   'Vicki',
#   'Bush',
#   'brownwyatt@example.org',
#   'Female',
#   '198.205.86.175',
#   'South Kevin'],
#  ['23',
#   'Steve',
#   'Peterson',
#   'jamesstevens@example.com',
#   'Female',
#   '165.122.80.65',
#   'West Brian'],
#  ['24',
#   'Margaret',
#   'Collins',
#   'jonathanramsey@example.com',
#   'Female',
#   '88.92.33.3',
#   'Williamsport'],
#  ['25',
#   'Alan',
#   'Lee',
#   'enguyen@example.com',
#   'Female',
#   '145.132.61.135',
#   'Delacruzfort'],
#  ['26',
#   'Brendan',
#   'Rollins',
#   'petersenlauren@example.com',
#   'Male',
#   '151.218.248.110',
#   'New Anthony'],
#  ['27',
#   'Zachary',
#   'Meyer',
#   'heather45@example.com',
#   'Female',
#   '102.50.179.62',
#   'West Mark'],
#  ['28',
#   'Megan',
#   'Ward',
#   'angela11@example.com',
#   'Female',
#   '212.68.40.196',
#   'New Rickey'],
#  ['29',
#   'Michelle',
#   'Jones',
#   'andrea21@example.org',
#   'Female',
#   '47.105.46.45',
#   'Port Brittanyfort'],
#  ['30',
#   'Shelly',
#   'Brown',
#   'brianreynolds@example.net',
#   'Female',
#   '221.0.35.230',
#   'Hollandville'],
#  ['31',
#   'Kimberly',
#   'Alvarez',
#   'cwelch@example.com',
#   'Male',
#   '178.177.132.100',
#   'Jacksonburgh'],
#  ['32',
#   'Sarah',
#   'Villanueva',
#   'payneruth@example.org',
#   'Female',
#   '173.77.142.16',
#   'North Angela'],
#  ['33',
#   'Amanda',
#   'Young',
#   'christopheraguilar@example.com',
#   'Male',
#   '214.151.48.68',
#   'Rhondastad'],
#  ['34',
#   'Sabrina',
#   'Caldwell',
#   'trevor76@example.org',
#   'Female',
#   '51.204.247.172',
#   'Michaelbury'],
#  ['35',
#   'William',
#   'Hicks',
#   'afox@example.net',
#   'Female',
#   '203.160.70.151',
#   'West Ashley'],
#  ['36',
#   'Gregory',
#   'Mcintyre',
#   'jonesjason@example.org',
#   'Female',
#   '217.1.74.132',
#   'New Randy'],
#  ['37',
#   'Kimberly',
#   'Carroll',
#   'gbauer@example.net',
#   'Male',
#   '162.6.142.219',
#   'Lake Pennyborough'],
#  ['38',
#   'Regina',
#   'Clark',
#   'jordankyle@example.com',
#   'Male',
#   '205.133.211.176',
#   'Jamesview'],
#  ['39',
#   'Matthew',
#   'Chandler',
#   'dennisrose@example.net',
#   'Male',
#   '51.131.229.43',
#   'New Anthony'],
#  ['40',
#   'Andrew',
#   'Bray',
#   'rclark@example.com',
#   'Male',
#   '86.115.105.174',
#   'North Shawnport'],
#  ['41',
#   'Patricia',
#   'Ramos',
#   'sandovaljustin@example.com',
#   'Female',
#   '15.127.92.190',
#   'Wallacehaven'],
#  ['42',
#   'Jesse',
#   'Smith',
#   'ethornton@example.net',
#   'Female',
#   '134.86.141.130',
#   'Bradshawstad'],
#  ['43',
#   'David',
#   'Mckee',
#   'grantwilliams@example.net',
#   'Female',
#   '102.206.126.238',
#   'Juantown'],
#  ['44',
#   'Jessica',
#   'Lopez',
#   'amyjackson@example.org',
#   'Male',
#   '119.202.82.146',
#   'Kerryburgh'],
#  ['45',
#   'Alicia',
#   'Yates',
#   'robertjames@example.net',
#   'Male',
#   '26.200.52.22',
#   'Melvinbury'],
#  ['46',
#   'Jacqueline',
#   'Camacho',
#   'lisa27@example.net',
#   'Male',
#   '168.194.4.71',
#   'West Robert'],
#  ['47',
#   'Christina',
#   'Turner',
#   'keithvaldez@example.com',
#   'Male',
#   '101.225.230.118',
#   'West James'],
#  ['48',
#   'Gavin',
#   'Williams',
#   'sharon55@example.com',
#   'Female',
#   '131.222.247.163',
#   'Gardnermouth'],
#  ['49',
#   'Jennifer',
#   'Morales',
#   'drewsexton@example.org',
#   'Male',
#   '53.27.126.229',
#   'Peterton'],
#  ['50',
#   'Maria',
#   'Miller',
#   'royallen@example.net',
#   'Male',
#   '72.38.13.110',
#   'Jaychester'],
#  ['51',
#   'Sarah',
#   'Graham',
#   'rodriguezbeth@example.org',
#   'Male',
#   '223.21.173.11',
#   'New Faithmouth'],
#  ['52',
#   'Sara',
#   'White',
#   'acevedorichard@example.org',
#   'Female',
#   '117.183.211.175',
#   'West Paul'],
#  ['53',
#   'Patrick',
#   'Marshall',
#   'john73@example.com',
#   'Male',
#   '216.1.82.185',
#   'Banksland'],
#  ['54',
#   'Tammy',
#   'Wright',
#   'cwatson@example.net',
#   'Male',
#   '61.26.135.165',
#   'Toddchester'],
#  ['55',
#   'Amanda',
#   'Chavez',
#   'fmatthews@example.com',
#   'Female',
#   '106.209.232.97',
#   'Wilsonhaven'],
#  ['56',
#   'Nicole',
#   'Watson',
#   'cunninghamjessica@example.com',
#   'Male',
#   '116.211.48.210',
#   'New Josephberg'],
#  ['57',
#   'Andrew',
#   'Robertson',
#   'ymora@example.net',
#   'Male',
#   '65.86.164.174',
#   'Garnermouth'],
#  ['58',
#   'Bradley',
#   'Hughes',
#   'jamie55@example.com',
#   'Male',
#   '69.190.94.20',
#   'Austinhaven'],
#  ['59',
#   'Jillian',
#   'Duncan',
#   'rubencopeland@example.org',
#   'Female',
#   '51.176.26.211',
#   'New Franktown'],
#  ['60',
#   'Dale',
#   'Nichols',
#   'shelbyjenkins@example.org',
#   'Female',
#   '159.167.204.242',
#   'Lake Samanthashire'],
#  ['61',
#   'Kaitlin',
#   'Cole',
#   'steven12@example.com',
#   'Male',
#   '96.243.52.235',
#   'East Jonathan'],
#  ['62',
#   'Zachary',
#   'Medina',
#   'jamesmedina@example.net',
#   'Female',
#   '87.91.142.182',
#   'Deannamouth'],
#  ['63',
#   'Toni',
#   'Moore',
#   'katelyn04@example.org',
#   'Female',
#   '33.17.215.202',
#   'North Nathanmouth'],
#  ['64',
#   'Stephen',
#   'Lopez',
#   'amy49@example.org',
#   'Male',
#   '92.160.80.49',
#   'Lake Christine'],
#  ['65',
#   'Jane',
#   'Ryan',
#   'lbates@example.com',
#   'Female',
#   '72.24.65.10',
#   'New Maryland'],
#  ['66',
#   'Terrence',
#   'Rodriguez',
#   'sarahmoreno@example.org',
#   'Female',
#   '190.130.32.119',
#   'West Alexanderburgh'],
#  ['67',
#   'Angela',
#   'Jones',
#   'tlester@example.com',
#   'Female',
#   '139.193.150.182',
#   'Berrytown'],
#  ['68',
#   'John',
#   'Sanchez',
#   'lovestephanie@example.org',
#   'Male',
#   '59.117.177.2',
#   'West Theresa'],
#  ['69',
#   'Nicholas',
#   'Thomas',
#   'schroederclinton@example.org',
#   'Male',
#   '114.16.56.100',
#   'North Nicoletown'],
#  ['70',
#   'Mary',
#   'Winters',
#   'laura22@example.org',
#   'Female',
#   '15.81.9.164',
#   'East Brittanyberg'],
#  ['71',
#   'Kari',
#   'Robbins',
#   'dustinmcgee@example.net',
#   'Female',
#   '164.6.64.94',
#   'Andrewside'],
#  ['72',
#   'Daniel',
#   'Matthews',
#   'xpatel@example.com',
#   'Male',
#   '116.255.59.17',
#   'North Julie'],
#  ['73',
#   'Jessica',
#   'Lee',
#   'jessicaprice@example.org',
#   'Male',
#   '207.117.172.240',
#   'Scottfurt'],
#  ['74',
#   'Cory',
#   'Brown',
#   'zwright@example.org',
#   'Female',
#   '10.29.168.102',
#   'Gonzaleschester'],
#  ['75',
#   'Shelly',
#   'Sanders',
#   'williamsnicole@example.net',
#   'Male',
#   '40.85.198.57',
#   'Hollystad'],
#  ['76',
#   'Jennifer',
#   'Williams',
#   'david42@example.org',
#   'Female',
#   '82.57.176.245',
#   'Scottburgh'],
#  ['77',
#   'Susan',
#   'Murphy',
#   'nguyenpaula@example.net',
#   'Female',
#   '19.27.99.26',
#   'East Allison'],
#  ['78',
#   'Patricia',
#   'Mcdonald',
#   'brittany01@example.com',
#   'Female',
#   '208.181.181.248',
#   'Lake Brianside'],
#  ['79',
#   'Joseph',
#   'Campbell',
#   'sarahwilliams@example.com',
#   'Female',
#   '152.153.137.79',
#   'Margaretport'],
#  ['80',
#   'Jane',
#   'Rodriguez',
#   'brittany46@example.org',
#   'Female',
#   '124.80.132.215',
#   'Lake Lori'],
#  ['81',
#   'Kaitlyn',
#   'Collins',
#   'jamesruth@example.org',
#   'Female',
#   '83.201.140.191',
#   'Butlershire'],
#  ['82',
#   'Kelly',
#   'Freeman',
#   'misty14@example.net',
#   'Female',
#   '69.30.66.84',
#   'Garciaview'],
#  ['83',
#   'Ryan',
#   'Gill',
#   'robinsonedward@example.com',
#   'Female',
#   '178.230.21.162',
#   'Port Phillip'],
#  ['84',
#   'Kara',
#   'Clark',
#   'maryjohns@example.com',
#   'Female',
#   '140.109.173.110',
#   'North Morganborough'],
#  ['85',
#   'Stephanie',
#   'Solis',
#   'pthomas@example.org',
#   'Female',
#   '164.148.222.17',
#   'East Josephshire'],
#  ['86',
#   'Jason',
#   'Cohen',
#   'courtneybass@example.net',
#   'Female',
#   '70.241.229.221',
#   'Carolynchester'],
#  ['87',
#   'Monica',
#   'Adkins',
#   'knightjoseph@example.net',
#   'Male',
#   '188.60.211.52',
#   'Lake Corey'],
#  ['88',
#   'Cathy',
#   'Chaney',
#   'flynndalton@example.com',
#   'Female',
#   '46.195.148.69',
#   'New Nancy'],
#  ['89',
#   'Cynthia',
#   'Stephens',
#   'danielbrown@example.org',
#   'Female',
#   '120.118.62.190',
#   'New Jennifertown'],
#  ['90',
#   'George',
#   'Jimenez',
#   'zgoodman@example.net',
#   'Male',
#   '189.170.28.59',
#   'North Darryl'],
#  ['91',
#   'Veronica',
#   'Brown',
#   'michelle23@example.net',
#   'Male',
#   '130.116.253.2',
#   'South Emilyhaven'],
#  ['92',
#   'Jeffrey',
#   'Lane',
#   'kennethadams@example.org',
#   'Male',
#   '146.16.89.168',
#   'Lewisside'],
#  ['93',
#   'Justin',
#   'Jones',
#   'briana93@example.com',
#   'Female',
#   '195.206.163.211',
#   'East Troystad'],
#  ['94',
#   'Jasmine',
#   'Baker',
#   'victoriathomas@example.com',
#   'Female',
#   '220.191.91.23',
#   'New Lukechester'],
#  ['95',
#   'Diana',
#   'Tyler',
#   'huffmanelizabeth@example.org',
#   'Male',
#   '53.189.23.51',
#   'Rebeccabury'],
#  ['96',
#   'Edward',
#   'Ward',
#   'juarezlacey@example.net',
#   'Male',
#   '176.99.30.251',
#   'Maryborough'],
#  ['97',
#   'Carl',
#   'Mason',
#   'hernandezjoanna@example.net',
#   'Male',
#   '84.71.166.236',
#   'Lake Dustin'],
#  ['98',
#   'Anthony',
#   'Torres',
#   'hoffmanandrew@example.org',
#   'Male',
#   '50.189.246.195',
#   'New Nathanielton'],
#  ['99',
#   'Calvin',
#   'Johnson',
#   'hwillis@example.org',
#   'Male',
#   '18.70.169.120',
#   'Cisnerosberg'],
#  ['100',
#   'George',
#   'Hoffman',
#   'richardsonbrian@example.net',
#   'Female',
#   '203.110.128.88',
#   'Lopezville'],
#  ['101',
#   'Allison',
#   'Burch',
#   'ggreene@example.com',
#   'Female',
#   '123.26.126.226',
#   'Reneeland'],
#  ['102',
#   'Shane',
#   'Williams',
#   'vvargas@example.org',
#   'Male',
#   '53.190.10.184',
#   'Robinville'],
#  ['103',
#   'Thomas',
#   'Jones',
#   'john92@example.org',
#   'Female',
#   '75.174.184.181',
#   'New Tanner'],
#  ['104',
#   'Steven',
#   'Wells',
#   'ernestking@example.org',
#   'Male',
#   '142.59.161.106',
#   'Angelashire'],
#  ['105',
#   'Ryan',
#   'White',
#   'matthewrodriguez@example.net',
#   'Female',
#   '23.32.27.206',
#   'Lisaside'],
#  ['106',
#   'Caitlin',
#   'Yoder',
#   'hollymason@example.com',
#   'Female',
#   '159.45.22.221',
#   'West Bradley'],
#  ['107',
#   'Christopher',
#   'Lee',
#   'randallhoffman@example.com',
#   'Female',
#   '43.168.175.103',
#   'Lindseystad'],
#  ['108',
#   'Cassie',
#   'Berger',
#   'sgomez@example.com',
#   'Male',
#   '171.186.246.169',
#   'Lake Taylorfurt'],
#  ['109',
#   'Brandon',
#   'Roach',
#   'kevin86@example.com',
#   'Male',
#   '196.107.159.116',
#   'Joelland'],
#  ['110',
#   'David',
#   'Stone',
#   'kaneangelica@example.net',
#   'Male',
#   '203.183.109.247',
#   'Stacybury'],
#  ['111',
#   'Michael',
#   'Wise',
#   'lawrence54@example.com',
#   'Female',
#   '12.11.100.63',
#   'Troyshire'],
#  ['112',
#   'James',
#   'Lewis',
#   'martinmichael@example.net',
#   'Female',
#   '44.92.225.86',
#   'Lake Nicole'],
#  ['113',
#   'Thomas',
#   'Rowland',
#   'nreid@example.net',
#   'Female',
#   '214.22.133.171',
#   'West Peterburgh'],
#  ['114',
#   'Sean',
#   'Wolfe',
#   'qriley@example.org',
#   'Female',
#   '5.175.218.215',
#   'Loveview'],
#  ['115',
#   'Kimberly',
#   'Archer',
#   'jennifer27@example.org',
#   'Female',
#   '198.220.177.191',
#   'Port Lisaside'],
#  ['116',
#   'James',
#   'Madden',
#   'rodriguezkevin@example.org',
#   'Male',
#   '45.103.185.172',
#   'Montgomeryland'],
#  ['117',
#   'Danielle',
#   'Williams',
#   'jacob48@example.com',
#   'Female',
#   '145.19.113.234',
#   'Dicksonfurt'],
#  ['118',
#   'Emily',
#   'Navarro',
#   'carmenhernandez@example.org',
#   'Female',
#   '123.41.115.153',
#   'Taylormouth'],
#  ['119',
#   'Robert',
#   'Taylor',
#   'smithjonathan@example.net',
#   'Male',
#   '178.19.105.244',
#   'Port Meganland'],
#  ['120',
#   'David',
#   'Jackson',
#   'huntermark@example.com',
#   'Female',
#   '218.79.205.245',
#   'New Megan'],
#  ['121',
#   'Justin',
#   'Clark',
#   'colemanarthur@example.net',
#   'Male',
#   '185.53.73.182',
#   'Port Samanthaland'],
#  ['122',
#   'Jennifer',
#   'Green',
#   'carl91@example.org',
#   'Male',
#   '10.93.8.118',
#   'South Josephside'],
#  ['123',
#   'Karina',
#   'Swanson',
#   'morriscandace@example.net',
#   'Female',
#   '32.127.205.238',
#   'Jenkinsberg'],
#  ['124',
#   'Joshua',
#   'Boone',
#   'uhawkins@example.com',
#   'Female',
#   '74.146.132.242',
#   'New Brian'],
#  ['125',
#   'Timothy',
#   'Mcdonald',
#   'rushhannah@example.com',
#   'Female',
#   '32.93.26.121',
#   'New Melissa'],
#  ['126',
#   'Amy',
#   'Williams',
#   'youngaimee@example.net',
#   'Male',
#   '11.234.132.163',
#   'Morenohaven'],
#  ['127',
#   'Kristi',
#   'Scott',
#   'clarkalexander@example.net',
#   'Female',
#   '123.241.135.235',
#   'Dustinmouth'],
#  ['128',
#   'Charles',
#   'Newton',
#   'briggsantonio@example.net',
#   'Male',
#   '63.236.112.95',
#   'Taylorside'],
#  ['129',
#   'John',
#   'Torres',
#   'brian23@example.net',
#   'Female',
#   '112.31.90.113',
#   'Lewisland'],
#  ['130',
#   'Roger',
#   'Crawford',
#   'donna32@example.net',
#   'Female',
#   '188.173.154.194',
#   'North Debraborough'],
#  ['131',
#   'Emily',
#   'Brown',
#   'michaelmoore@example.net',
#   'Female',
#   '106.251.20.244',
#   'Erinchester'],
#  ['132',
#   'Bailey',
#   'Aguirre',
#   'ewilliams@example.org',
#   'Male',
#   '5.191.40.159',
#   'East Annettemouth'],
#  ['133',
#   'Savannah',
#   'Sheppard',
#   'nelsonjasmine@example.com',
#   'Female',
#   '118.166.23.35',
#   'West Christopherside'],
#  ['134',
#   'Joseph',
#   'Wagner',
#   'amberzimmerman@example.com',
#   'Female',
#   '105.249.107.170',
#   'Gomezton'],
#  ['135',
#   'Virginia',
#   'Preston',
#   'lmartinez@example.com',
#   'Male',
#   '102.111.148.146',
#   'Natalieberg'],
#  ['136',
#   'Denise',
#   'Thomas',
#   'nancy99@example.com',
#   'Female',
#   '101.161.231.80',
#   'Port Breannaside'],
#  ['137',
#   'Brian',
#   'Hurley',
#   'samantha22@example.com',
#   'Male',
#   '21.231.149.211',
#   'Wilsonchester'],
#  ['138',
#   'Cynthia',
#   'Johnson',
#   'penarichard@example.org',
#   'Male',
#   '24.157.67.33',
#   'Janeland'],
#  ['139',
#   'Sylvia',
#   'Morales',
#   'edwardsmith@example.com',
#   'Male',
#   '88.128.82.58',
#   'Tarastad'],
#  ['140',
#   'Michael',
#   'Miller',
#   'fhunter@example.org',
#   'Female',
#   '137.23.99.111',
#   'Alisonmouth'],
#  ['141',
#   'Monique',
#   'Wilson',
#   'zholmes@example.com',
#   'Female',
#   '138.66.36.236',
#   'Cunninghamside'],
#  ['142',
#   'Olivia',
#   'Williams',
#   'james59@example.net',
#   'Male',
#   '197.100.77.230',
#   'West John'],
#  ['143',
#   'Terri',
#   'Castillo',
#   'matthewballard@example.com',
#   'Female',
#   '216.234.202.207',
#   'Cookbury'],
#  ['144',
#   'Emily',
#   'Morgan',
#   'edward17@example.org',
#   'Female',
#   '49.85.184.111',
#   'Johnton'],
#  ['145',
#   'Lisa',
#   'Blair',
#   'churchjonathon@example.net',
#   'Male',
#   '19.213.6.169',
#   'Lake Geoffreyhaven'],
#  ['146',
#   'Norma',
#   'Gates',
#   'higginssamantha@example.org',
#   'Male',
#   '206.41.1.73',
#   'New Aaronfort'],
#  ['147',
#   'Willie',
#   'Brown',
#   'daniel95@example.org',
#   'Female',
#   '150.102.51.229',
#   'Vazquezshire'],
#  ['148',
#   'Antonio',
#   'Davidson',
#   'maria49@example.org',
#   'Female',
#   '206.253.98.187',
#   'Johnville'],
#  ['149',
#   'Caroline',
#   'Woods',
#   'dterrell@example.net',
#   'Male',
#   '10.249.18.65',
#   'Tracyborough'],
#  ['150',
#   'Gregory',
#   'Barrett',
#   'douglaspowers@example.net',
#   'Male',
#   '188.69.192.39',
#   'Mullinsland'],
#  ['151',
#   'Lisa',
#   'Randolph',
#   'velazqueznicholas@example.org',
#   'Female',
#   '21.221.228.1',
#   'Wilsonmouth'],
#  ['152',
#   'Wayne',
#   'Elliott',
#   'cheryl60@example.org',
#   'Male',
#   '74.100.212.172',
#   'South Susan'],
#  ['153',
#   'Andrew',
#   'Holmes',
#   'jdiaz@example.net',
#   'Female',
#   '101.243.59.22',
#   'Powellburgh'],
#  ['154',
#   'Brandon',
#   'Jenkins',
#   'mcbridejuan@example.net',
#   'Male',
#   '192.252.32.146',
#   'New Rachelberg'],
#  ['155',
#   'Thomas',
#   'Garrett',
#   'angie74@example.org',
#   'Female',
#   '137.218.29.255',
#   'East Nicholas'],
#  ['156',
#   'Lucas',
#   'Harris',
#   'dperez@example.net',
#   'Female',
#   '27.169.73.192',
#   'Patriciaview'],
#  ['157',
#   'Ashley',
#   'Smith',
#   'brenda98@example.net',
#   'Male',
#   '54.32.9.166',
#   'Colonfurt'],
#  ['158',
#   'Chad',
#   'Peterson',
#   'angela72@example.net',
#   'Female',
#   '97.35.199.136',
#   'New Susanhaven'],
#  ['159',
#   'Anthony',
#   'Mcgee',
#   'elizabethcooper@example.net',
#   'Female',
#   '184.141.169.79',
#   'Smithport'],
#  ['160',
#   'Kaitlin',
#   'Kemp',
#   'stephenroth@example.org',
#   'Female',
#   '83.92.231.200',
#   'Lynnshire'],
#  ['161',
#   'Elizabeth',
#   'Mcbride',
#   'douglas64@example.com',
#   'Female',
#   '52.57.132.67',
#   'Philipmouth'],
#  ['162',
#   'Jeremy',
#   'Frye',
#   'sarahwilson@example.com',
#   'Male',
#   '223.58.137.26',
#   'Lake Geraldbury'],
#  ['163',
#   'Andrew',
#   'Moyer',
#   'jonathan38@example.net',
#   'Male',
#   '20.28.120.232',
#   'North Barbara'],
#  ['164',
#   'William',
#   'Thompson',
#   'michael82@example.com',
#   'Female',
#   '52.166.16.1',
#   'Paulamouth'],
#  ['165',
#   'Lauren',
#   'Perez',
#   'jamessaunders@example.com',
#   'Female',
#   '157.100.93.78',
#   'New Lauren'],
#  ['166',
#   'David',
#   'Franklin',
#   'douglasking@example.org',
#   'Female',
#   '80.192.12.113',
#   'Port Kevin'],
#  ['167',
#   'Ashley',
#   'Hughes',
#   'meganlewis@example.net',
#   'Male',
#   '160.146.94.181',
#   'Smithton'],
#  ['168',
#   'James',
#   'Lyons',
#   'josephthomas@example.org',
#   'Male',
#   '151.182.23.174',
#   'Stoneburgh'],
#  ['169',
#   'Nancy',
#   'Welch',
#   'riveradenise@example.com',
#   'Male',
#   '213.52.17.43',
#   'Stevensonside'],
#  ['170',
#   'Michael',
#   'Baker',
#   'davisjoseph@example.org',
#   'Female',
#   '22.2.94.17',
#   'West Claudia'],
#  ['171',
#   'Melissa',
#   'Young',
#   'evanswhitney@example.com',
#   'Female',
#   '138.101.24.237',
#   'Jensenshire'],
#  ['172',
#   'Elizabeth',
#   'Caldwell',
#   'nelsontammy@example.org',
#   'Male',
#   '147.255.28.246',
#   'South Jacquelinemouth'],
#  ['173',
#   'Amanda',
#   'Cherry',
#   'sarahwalton@example.com',
#   'Male',
#   '6.16.168.254',
#   'Scottbury'],
#  ['174',
#   'Kevin',
#   'Sanchez',
#   'chase76@example.org',
#   'Female',
#   '94.242.152.66',
#   'Lake Christopher'],
#  ['175',
#   'Larry',
#   'Hayes',
#   'dsanford@example.com',
#   'Male',
#   '83.100.48.155',
#   'Samuelfort'],
#  ['176',
#   'John',
#   'Scott',
#   'richardjones@example.org',
#   'Male',
#   '70.169.169.215',
#   'New Melissachester'],
#  ['177',
#   'John',
#   'Parker',
#   'jeffreytaylor@example.org',
#   'Female',
#   '1.62.179.231',
#   'Johnchester'],
#  ['178',
#   'Carol',
#   'Morse',
#   'ejohnson@example.net',
#   'Male',
#   '178.119.65.163',
#   'Port Michaelfurt'],
#  ['179',
#   'David',
#   'Goodman',
#   'jwhite@example.net',
#   'Female',
#   '8.89.138.201',
#   'East Betty'],
#  ['180',
#   'Xavier',
#   'Huff',
#   'wigginsrhonda@example.com',
#   'Female',
#   '37.47.22.160',
#   'Lake Rebekah'],
#  ['181',
#   'Stephen',
#   'Anderson',
#   'barkerolivia@example.com',
#   'Male',
#   '3.28.5.91',
#   'Josefort'],
#  ['182',
#   'Brian',
#   'Smith',
#   'rickykaiser@example.org',
#   'Female',
#   '214.39.48.182',
#   'Jesseshire'],
#  ['183',
#   'Corey',
#   'Conley',
#   'yjones@example.org',
#   'Male',
#   '120.14.19.142',
#   'Williamsside'],
#  ['184',
#   'Brian',
#   'Gray',
#   'cassandraturner@example.net',
#   'Female',
#   '60.114.126.165',
#   'East Rebecca'],
#  ['185',
#   'Kim',
#   'Strickland',
#   'datkinson@example.net',
#   'Female',
#   '214.233.92.243',
#   'West Zacharymouth'],
#  ['186',
#   'Charles',
#   'Collins',
#   'chorton@example.com',
#   'Male',
#   '213.44.124.63',
#   'Robertburgh'],
#  ['187',
#   'Roger',
#   'Webster',
#   'collinspatricia@example.com',
#   'Female',
#   '53.128.100.116',
#   'Richardfurt'],
#  ['188',
#   'Madeline',
#   'Miller',
#   'alicialara@example.org',
#   'Female',
#   '173.63.131.215',
#   'Greenfurt'],
#  ['189',
#   'John',
#   'Baldwin',
#   'hwilson@example.net',
#   'Female',
#   '187.205.121.162',
#   'Mcdonaldfort'],
#  ['190',
#   'Misty',
#   'Moore',
#   'larry08@example.com',
#   'Male',
#   '131.210.227.102',
#   'Dunnview'],
#  ['191',
#   'Carrie',
#   'Mosley',
#   'fwelch@example.com',
#   'Male',
#   '161.231.233.23',
#   'East Nicholas'],
#  ['192',
#   'Joshua',
#   'Roberts',
#   'pearsonamy@example.com',
#   'Female',
#   '163.174.253.22',
#   'Danielhaven'],
#  ['193',
#   'James',
#   'Fry',
#   'claudia31@example.org',
#   'Female',
#   '133.216.230.68',
#   'Deborahfort'],
#  ['194',
#   'Theodore',
#   'Alvarado',
#   'kathryn97@example.com',
#   'Male',
#   '202.115.32.18',
#   'Lake Kara'],
#  ['195',
#   'Jennifer',
#   'Arnold',
#   'courtney00@example.org',
#   'Male',
#   '153.176.199.162',
#   'West Marialand'],
#  ['196',
#   'Margaret',
#   'Sweeney',
#   'brooksmiguel@example.org',
#   'Male',
#   '66.107.210.50',
#   'Lake Nicholasland'],
#  ['197',
#   'Kimberly',
#   'Byrd',
#   'henry42@example.net',
#   'Female',
#   '179.233.50.189',
#   'Lake Juanview'],
#  ['198',
#   'Alexander',
#   'Brown',
#   'aaronday@example.net',
#   'Male',
#   '89.11.80.201',
#   'Port Cassandratown'],
#  ['199',
#   'Carolyn',
#   'Russell',
#   'shawnmiller@example.net',
#   'Male',
#   '135.102.155.28',
#   'Karenport'],
#  ['200',
#   'Elizabeth',
#   'Price',
#   'michael97@example.com',
#   'Female',
#   '135.60.138.42',
#   'Mcdonaldmouth'],
#  ['201',
#   'Diane',
#   'Marsh',
#   'mark70@example.net',
#   'Male',
#   '135.68.104.194',
#   'South Kayleeside'],
#  ['202',
#   'Benjamin',
#   'Cook',
#   'dfoster@example.net',
#   'Female',
#   '129.54.82.70',
#   'Port Lauren'],
#  ['203',
#   'Frank',
#   'King',
#   'ramirezanna@example.org',
#   'Male',
#   '166.112.114.130',
#   'Lake Sara'],
#  ['204',
#   'Dylan',
#   'Martin',
#   'ericwhite@example.com',
#   'Male',
#   '117.105.222.235',
#   'East Kristiburgh'],
#  ['205',
#   'Allison',
#   'Bailey',
#   'lauren57@example.org',
#   'Male',
#   '154.187.43.234',
#   'New Craigfort'],
#  ['206',
#   'Jessica',
#   'Harris',
#   'blancharderin@example.org',
#   'Male',
#   '106.12.131.204',
#   'Lindseyland'],
#  ['207',
#   'Melissa',
#   'Knight',
#   'michelle71@example.org',
#   'Female',
#   '133.149.69.15',
#   'Jillianburgh'],
#  ['208',
#   'Kenneth',
#   'Robinson',
#   'unoble@example.net',
#   'Male',
#   '157.248.57.69',
#   'Lake Mark'],
#  ['209',
#   'Nancy',
#   'Taylor',
#   'danielmurphy@example.com',
#   'Female',
#   '80.40.223.183',
#   'Troyborough'],
#  ['210',
#   'Katherine',
#   'Williamson',
#   'ysimpson@example.net',
#   'Female',
#   '149.127.233.164',
#   'Lake Tony'],
#  ['211',
#   'Lisa',
#   'Jones',
#   'linda12@example.org',
#   'Female',
#   '135.103.13.66',
#   'South Traviston'],
#  ['212',
#   'Eileen',
#   'Dunn',
#   'singletontami@example.net',
#   'Female',
#   '215.119.254.199',
#   'South Feliciatown'],
#  ['213',
#   'Jessica',
#   'Ramirez',
#   'holly66@example.net',
#   'Female',
#   '120.51.233.122',
#   'Justintown'],
#  ['214',
#   'Sandra',
#   'Mcbride',
#   'leehiggins@example.com',
#   'Male',
#   '136.109.141.164',
#   'Rachelchester'],
#  ['215',
#   'Scott',
#   'Gutierrez',
#   'michelle61@example.org',
#   'Male',
#   '97.151.152.42',
#   'Stacybury'],
#  ['216',
#   'Stacey',
#   'Hughes',
#   'uobrien@example.org',
#   'Male',
#   '192.93.42.135',
#   'North Kim'],
#  ['217',
#   'Scott',
#   'Martinez',
#   'kenneth89@example.net',
#   'Female',
#   '36.9.109.195',
#   'New Anthony'],
#  ['218',
#   'Jonathan',
#   'Campbell',
#   'anthony32@example.org',
#   'Male',
#   '185.236.229.104',
#   'Murphyborough'],
#  ['219',
#   'Katelyn',
#   'Williams',
#   'uscott@example.net',
#   'Male',
#   '49.41.53.119',
#   'North Edwardbury'],
#  ['220',
#   'John',
#   'Wade',
#   'moorelarry@example.com',
#   'Male',
#   '106.234.250.230',
#   'South Tinaton'],
#  ['221',
#   'Ronald',
#   'Decker',
#   'danaferguson@example.org',
#   'Male',
#   '94.223.21.32',
#   'New Brandonbury'],
#  ['222',
#   'Teresa',
#   'Owens',
#   'christinedavis@example.com',
#   'Male',
#   '27.90.102.129',
#   'North Jacqueline'],
#  ['223',
#   'Tim',
#   'Hamilton',
#   'russellstevens@example.com',
#   'Male',
#   '162.143.59.29',
#   'Blackwellmouth'],
#  ['224',
#   'Zachary',
#   'Ross',
#   'ggarcia@example.net',
#   'Male',
#   '212.89.201.81',
#   'North Edward'],
#  ['225',
#   'Nicole',
#   'Howell',
#   'steventaylor@example.net',
#   'Female',
#   '173.59.120.188',
#   'New Heidiville'],
#  ['226',
#   'Amy',
#   'Stewart',
#   'ureyes@example.com',
#   'Female',
#   '217.169.45.241',
#   'Amandaton'],
#  ['227',
#   'Kelly',
#   'Harris',
#   'ralph91@example.com',
#   'Male',
#   '9.24.21.76',
#   'Martinburgh'],
#  ['228',
#   'Kimberly',
#   'Peterson',
#   'khernandez@example.org',
#   'Male',
#   '41.225.162.136',
#   'West Ryanchester'],
#  ['229',
#   'Curtis',
#   'Lara',
#   'christinesmith@example.org',
#   'Female',
#   '170.36.166.18',
#   'Robertmouth'],
#  ['230',
#   'Keith',
#   'Gonzales',
#   'heatherkoch@example.org',
#   'Male',
#   '126.82.66.207',
#   'New Erinland'],
#  ['231',
#   'Lori',
#   'Russell',
#   'jeffreyrichards@example.net',
#   'Male',
#   '3.53.167.171',
#   'North Justin'],
#  ['232',
#   'Christopher',
#   'Johnson',
#   'wilsonmary@example.com',
#   'Female',
#   '70.169.143.208',
#   'Port Angela'],
#  ['233',
#   'Timothy',
#   'Williams',
#   'travismartin@example.net',
#   'Female',
#   '120.196.231.131',
#   'Kentshire'],
#  ['234',
#   'Charles',
#   'Brewer',
#   'rebeccawest@example.net',
#   'Female',
#   '136.44.235.203',
#   'North Jeremy'],
#  ['235',
#   'Stephen',
#   'Santos',
#   'lindseylopez@example.org',
#   'Female',
#   '72.189.224.188',
#   'Lake Jefferytown'],
#  ['236',
#   'Anita',
#   'Campos',
#   'johnsontimothy@example.com',
#   'Female',
#   '95.38.74.50',
#   'Sanchezberg'],
#  ['237',
#   'Jack',
#   'Lopez',
#   'athompson@example.com',
#   'Female',
#   '176.139.12.86',
#   'South Kevinfurt'],
#  ['238',
#   'Crystal',
#   'Boone',
#   'byrdbrittney@example.com',
#   'Male',
#   '7.154.0.114',
#   'Michaelton'],
#  ['239',
#   'Stephen',
#   'Sanchez',
#   'robert21@example.com',
#   'Male',
#   '111.9.157.250',
#   'Sandraburgh'],
#  ['240',
#   'Maxwell',
#   'Wallace',
#   'susanwilliams@example.net',
#   'Male',
#   '42.100.188.66',
#   'North Holly'],
#  ['241',
#   'Laura',
#   'West',
#   'hensleykristin@example.net',
#   'Female',
#   '49.85.210.108',
#   'Josephtown'],
#  ['242',
#   'James',
#   'Thompson',
#   'nrice@example.com',
#   'Female',
#   '94.155.99.209',
#   'Michaelmouth'],
#  ['243',
#   'Sarah',
#   'Raymond',
#   'aimee05@example.com',
#   'Female',
#   '29.43.22.153',
#   'Oliviamouth'],
#  ['244',
#   'Brenda',
#   'Torres',
#   'webstermitchell@example.org',
#   'Female',
#   '112.175.250.195',
#   'Lake Amanda'],
#  ['245',
#   'Tyler',
#   'Kane',
#   'michelleclark@example.org',
#   'Male',
#   '108.90.110.77',
#   'North Ashley'],
#  ['246',
#   'Catherine',
#   'Cannon',
#   'fsmith@example.net',
#   'Male',
#   '18.123.182.43',
#   'New Williammouth'],
#  ['247',
#   'Erika',
#   'Anderson',
#   'ashleyjohnson@example.net',
#   'Male',
#   '215.151.6.139',
#   'Wilkinsonview'],
#  ['248',
#   'Misty',
#   'Cooper',
#   'samantha03@example.org',
#   'Female',
#   '60.23.197.251',
#   'Macdonaldberg'],
#  ['249',
#   'Willie',
#   'Price',
#   'sarah49@example.org',
#   'Female',
#   '30.140.9.51',
#   'East Gregoryberg'],
#  ['250',
#   'Justin',
#   'Macias',
#   'davidponce@example.org',
#   'Female',
#   '100.30.30.169',
#   'Adkinshaven'],
#  ['251',
#   'Anthony',
#   'Ayala',
#   'thomas14@example.com',
#   'Female',
#   '58.27.223.113',
#   'Tiffanyhaven'],
#  ['252',
#   'Jesse',
#   'Fitzgerald',
#   'sean46@example.net',
#   'Male',
#   '219.102.123.25',
#   'West Melissa'],
#  ['253',
#   'Jordan',
#   'Park',
#   'thomas53@example.com',
#   'Male',
#   '219.130.10.238',
#   'Port Albert'],
#  ['254',
#   'Karen',
#   'Brady',
#   'qramos@example.net',
#   'Female',
#   '16.29.173.200',
#   'Lake Charleneside'],
#  ['255',
#   'Kevin',
#   'Martin',
#   'pbrooks@example.org',
#   'Female',
#   '6.131.201.50',
#   'Fowlerton'],
#  ['256',
#   'Matthew',
#   'Riley',
#   'danielle80@example.net',
#   'Female',
#   '39.197.145.168',
#   'Johnsonport'],
#  ['257',
#   'Antonio',
#   'Simpson',
#   'courtney37@example.com',
#   'Female',
#   '48.33.160.146',
#   'Alyssaland'],
#  ['258',
#   'Derek',
#   'Peterson',
#   'millernancy@example.org',
#   'Male',
#   '16.189.136.57',
#   'Banksland'],
#  ['259',
#   'Stephen',
#   'Zimmerman',
#   'chad63@example.org',
#   'Male',
#   '207.221.183.204',
#   'New Lisa'],
#  ['260',
#   'Rebecca',
#   'Montoya',
#   'stevenrosales@example.net',
#   'Female',
#   '165.18.187.246',
#   'South Audrey'],
#  ['261',
#   'Melissa',
#   'Evans',
#   'thomaselizabeth@example.net',
#   'Male',
#   '24.34.246.208',
#   'Brownstad'],
#  ['262',
#   'Elizabeth',
#   'Walker',
#   'higginstimothy@example.net',
#   'Female',
#   '125.30.225.33',
#   'Michaelburgh'],
#  ['263',
#   'Kayla',
#   'Hodge',
#   'aprilleonard@example.com',
#   'Female',
#   '88.224.145.121',
#   'South Ashleyshire'],
#  ['264',
#   'Maria',
#   'Austin',
#   'glamb@example.org',
#   'Female',
#   '32.65.246.9',
#   'Laurenstad'],
#  ['265',
#   'Joshua',
#   'Mueller',
#   'makayla61@example.net',
#   'Female',
#   '17.56.79.53',
#   'Ortizland'],
#  ['266',
#   'Jennifer',
#   'Mcintyre',
#   'harriskevin@example.com',
#   'Male',
#   '180.141.204.246',
#   'Taylormouth'],
#  ['267',
#   'Brenda',
#   'Shepard',
#   'daniel84@example.com',
#   'Female',
#   '4.111.127.156',
#   'Lake Michaelborough'],
#  ['268',
#   'Devin',
#   'Clements',
#   'frances91@example.org',
#   'Female',
#   '30.157.100.193',
#   'West Joann'],
#  ['269',
#   'Michael',
#   'Murphy',
#   'smithmark@example.org',
#   'Female',
#   '196.142.250.38',
#   'Geoffreyfort'],
#  ['270',
#   'Ellen',
#   'Weber',
#   'steven71@example.org',
#   'Female',
#   '41.10.209.196',
#   'Angelachester'],
#  ['271',
#   'Barry',
#   'Flowers',
#   'jamessanders@example.org',
#   'Female',
#   '188.195.191.0',
#   'South Samuelhaven'],
#  ['272',
#   'James',
#   'Meadows',
#   'fdoyle@example.org',
#   'Female',
#   '59.255.23.128',
#   'Mannmouth'],
#  ['273',
#   'Charles',
#   'Callahan',
#   'tyler50@example.org',
#   'Male',
#   '214.143.98.241',
#   'Lake Andreaborough'],
#  ['274',
#   'John',
#   'Contreras',
#   'vincentnelson@example.com',
#   'Male',
#   '25.154.92.48',
#   'Julieton'],
#  ['275',
#   'Anthony',
#   'Santiago',
#   'iwhite@example.net',
#   'Male',
#   '130.182.160.202',
#   'New Davidport'],
#  ['276',
#   'Rebecca',
#   'Blackburn',
#   'anthonyweaver@example.com',
#   'Female',
#   '97.19.255.38',
#   'Silvaberg'],
#  ['277',
#   'Kevin',
#   'Smith',
#   'rvargas@example.net',
#   'Male',
#   '119.242.103.51',
#   'North Clarencechester'],
#  ['278',
#   'John',
#   'Vargas',
#   'ashleyhopkins@example.org',
#   'Female',
#   '18.120.73.231',
#   'Vargaston'],
#  ['279',
#   'Morgan',
#   'Carlson',
#   'craigreed@example.net',
#   'Female',
#   '140.51.143.76',
#   'North Robert'],
#  ['280',
#   'Michael',
#   'Blair',
#   'riverasamantha@example.org',
#   'Female',
#   '60.158.92.92',
#   'Blackburgh'],
#  ['281',
#   'Christy',
#   'Perez',
#   'garnermackenzie@example.org',
#   'Female',
#   '181.57.213.88',
#   'Bautistaland'],
#  ['282',
#   'Mitchell',
#   'Abbott',
#   'amyjordan@example.org',
#   'Female',
#   '178.139.214.29',
#   'New Suzanne'],
#  ['283',
#   'Edward',
#   'Bowman',
#   'amanda25@example.org',
#   'Male',
#   '9.89.244.171',
#   'Coleville'],
#  ['284',
#   'Michael',
#   'Morris',
#   'gonzalezmichael@example.net',
#   'Female',
#   '23.211.134.92',
#   'Davisfort'],
#  ['285',
#   'Steven',
#   'Galloway',
#   'zgonzalez@example.com',
#   'Female',
#   '125.48.227.31',
#   'Lake Robertshire'],
#  ['286',
#   'Katie',
#   'Cowan',
#   'michellecollins@example.com',
#   'Male',
#   '99.8.127.173',
#   'Gregorytown'],
#  ['287',
#   'Dillon',
#   'Delgado',
#   'alejandramitchell@example.net',
#   'Female',
#   '19.218.169.77',
#   'North Jackson'],
#  ['288',
#   'Spencer',
#   'Green',
#   'hooverdavid@example.net',
#   'Male',
#   '126.228.138.235',
#   'Pamelamouth'],
#  ['289',
#   'Cheryl',
#   'Long',
#   'melissabaker@example.org',
#   'Female',
#   '97.116.123.141',
#   'Danielville'],
#  ['290',
#   'Jean',
#   'Rogers',
#   'steven52@example.net',
#   'Female',
#   '122.109.132.0',
#   'Lake Jackie'],
#  ['291',
#   'Jennifer',
#   'Norris',
#   'oshepard@example.org',
#   'Male',
#   '51.111.112.147',
#   'Abbottton'],
#  ['292',
#   'Jean',
#   'King',
#   'christopher87@example.org',
#   'Male',
#   '169.143.76.164',
#   'Lunachester'],
#  ['293',
#   'Erik',
#   'Clayton',
#   'pamela46@example.org',
#   'Female',
#   '167.50.53.8',
#   'Port Carla'],
#  ['294',
#   'Samantha',
#   'Miller',
#   'markhill@example.com',
#   'Female',
#   '222.26.144.208',
#   'Reginaville'],
#  ['295',
#   'Tami',
#   'Rivera',
#   'cmyers@example.com',
#   'Male',
#   '3.83.166.87',
#   'Moniquechester'],
#  ['296',
#   'William',
#   'Griffin',
#   'david76@example.net',
#   'Female',
#   '203.225.139.114',
#   'New Rebecca'],
#  ['297',
#   'Dustin',
#   'Grant',
#   'tgreen@example.org',
#   'Male',
#   '106.19.136.147',
#   'North Brittanytown'],
#  ['298',
#   'John',
#   'Scott',
#   'cdavis@example.net',
#   'Male',
#   '131.120.195.88',
#   'Tammyhaven'],
#  ['299',
#   'Annette',
#   'Roach',
#   'vancelisa@example.net',
#   'Female',
#   '154.95.28.234',
#   'Evansborough'],
#  ['300',
#   'Stephanie',
#   'White',
#   'jaredadams@example.com',
#   'Female',
#   '190.75.28.159',
#   'Jamestown'],
#  ['301',
#   'Amanda',
#   'Gonzalez',
#   'sullivanshane@example.org',
#   'Female',
#   '51.146.156.119',
#   'Kennedytown'],
#  ['302',
#   'Brandon',
#   'Reed',
#   'valerieaguilar@example.com',
#   'Male',
#   '223.97.98.17',
#   'Port Jeffery'],
#  ['303',
#   'Emily',
#   'Brown',
#   'christopheryoung@example.net',
#   'Female',
#   '173.102.226.57',
#   'Heatherborough'],
#  ['304',
#   'Marcus',
#   'Richardson',
#   'kim28@example.com',
#   'Female',
#   '217.100.216.213',
#   'West Michael'],
#  ['305',
#   'Robert',
#   'Mercer',
#   'bradleywilliams@example.net',
#   'Male',
#   '126.30.47.233',
#   'South Sarahtown'],
#  ['306',
#   'Keith',
#   'Cook',
#   'tyronecarter@example.com',
#   'Female',
#   '113.82.78.159',
#   'Port Jasminechester'],
#  ['307',
#   'Russell',
#   'Thompson',
#   'jonessarah@example.org',
#   'Male',
#   '104.150.21.3',
#   'Port Brian'],
#  ['308',
#   'John',
#   'Smith',
#   'nsoto@example.org',
#   'Female',
#   '117.18.132.243',
#   'East Isaac'],
#  ['309',
#   'James',
#   'Smith',
#   'taylormiller@example.com',
#   'Male',
#   '198.129.153.171',
#   'Hallmouth'],
#  ['310',
#   'Lori',
#   'Austin',
#   'lisataylor@example.org',
#   'Male',
#   '34.200.0.50',
#   'Crystalmouth'],
#  ['311',
#   'Cheryl',
#   'Bridges',
#   'connorking@example.net',
#   'Male',
#   '168.186.231.18',
#   'Hernandezfurt'],
#  ['312',
#   'Lisa',
#   'Silva',
#   'dianaflynn@example.net',
#   'Female',
#   '75.26.66.124',
#   'South Louismouth'],
#  ['313',
#   'Ashley',
#   'Valentine',
#   'joshua75@example.com',
#   'Male',
#   '91.218.80.35',
#   'East Michaeltown'],
#  ['314',
#   'George',
#   'Hernandez',
#   'mathewmcdonald@example.org',
#   'Female',
#   '168.70.120.177',
#   'Alexanderbury'],
#  ['315',
#   'Nicholas',
#   'Williams',
#   'swilcox@example.com',
#   'Female',
#   '10.145.80.77',
#   'Grahamstad'],
#  ['316',
#   'Monica',
#   'Munoz',
#   'jtorres@example.org',
#   'Female',
#   '151.89.223.30',
#   'Nicholaschester'],
#  ['317',
#   'Spencer',
#   'Clarke',
#   'lking@example.org',
#   'Female',
#   '108.109.170.222',
#   'West Michaelview'],
#  ['318',
#   'Kevin',
#   'Hanson',
#   'amanda02@example.com',
#   'Female',
#   '205.94.155.29',
#   'New Lydiabury'],
#  ['319',
#   'James',
#   'Moore',
#   'nelsonalexandria@example.com',
#   'Female',
#   '173.241.191.205',
#   'North Sharon'],
#  ['320',
#   'Michael',
#   'Jimenez',
#   'joypeters@example.com',
#   'Female',
#   '142.131.75.224',
#   'New Davidmouth'],
#  ['321',
#   'Diana',
#   'Mills',
#   'patrick68@example.net',
#   'Male',
#   '206.207.253.99',
#   'Torresfurt'],
#  ['322',
#   'Tammy',
#   'Donaldson',
#   'rharrison@example.org',
#   'Female',
#   '48.185.123.76',
#   'South Brad'],
#  ['323',
#   'Logan',
#   'Osborne',
#   'averycameron@example.net',
#   'Female',
#   '81.79.253.41',
#   'Evanstown'],
#  ['324',
#   'Amanda',
#   'Davis',
#   'chanjose@example.net',
#   'Female',
#   '214.101.88.54',
#   'Port Laura'],
#  ['325',
#   'Jennifer',
#   'Henderson',
#   'tsmith@example.com',
#   'Female',
#   '14.138.5.103',
#   'Liufort'],
#  ['326',
#   'Lisa',
#   'Collins',
#   'johnsonariana@example.net',
#   'Male',
#   '165.43.175.43',
#   'North Timothyview'],
#  ['327',
#   'Dana',
#   'Solis',
#   'myork@example.net',
#   'Female',
#   '42.226.82.63',
#   'Rossmouth'],
#  ['328',
#   'Zachary',
#   'Simmons',
#   'zprice@example.net',
#   'Female',
#   '70.247.7.41',
#   'North Angelicahaven'],
#  ['329',
#   'Hunter',
#   'Roberts',
#   'monica21@example.com',
#   'Male',
#   '181.162.145.127',
#   'East Todd'],
#  ['330',
#   'James',
#   'Cook',
#   'sanchezmegan@example.org',
#   'Male',
#   '28.254.71.217',
#   'Perryview'],
#  ['331',
#   'Gary',
#   'Lewis',
#   'nicholaswilliams@example.org',
#   'Female',
#   '77.199.71.218',
#   'Nicoleborough'],
#  ['332',
#   'Savannah',
#   'Jones',
#   'fletcherlaura@example.net',
#   'Male',
#   '64.2.251.250',
#   'South Andrew'],
#  ['333',
#   'Alyssa',
#   'Foster',
#   'jasonbrooks@example.org',
#   'Female',
#   '133.45.201.255',
#   'North Mary'],
#  ['334',
#   'Tyler',
#   'Wilson',
#   'gonzalezedwin@example.net',
#   'Male',
#   '119.151.174.80',
#   'Sethmouth'],
#  ['335',
#   'Dana',
#   'Carter',
#   'fwilson@example.org',
#   'Female',
#   '211.165.243.209',
#   'North Robertfurt'],
#  ['336',
#   'Tiffany',
#   'Sims',
#   'vbrown@example.net',
#   'Male',
#   '156.97.8.71',
#   'Codyport'],
#  ['337',
#   'Jessica',
#   'Cortez',
#   'dianegibson@example.com',
#   'Female',
#   '172.74.31.179',
#   'West Steven'],
#  ['338',
#   'Phillip',
#   'Taylor',
#   'tina02@example.com',
#   'Female',
#   '4.143.28.80',
#   'New Jennifer'],
#  ['339',
#   'Damon',
#   'Lee',
#   'jrogers@example.net',
#   'Male',
#   '148.134.170.15',
#   'Timothyfort'],
#  ['340',
#   'Patricia',
#   'Bell',
#   'john54@example.org',
#   'Female',
#   '222.7.41.37',
#   'Aaronton'],
#  ['341',
#   'Lauren',
#   'Taylor',
#   'brandy81@example.com',
#   'Male',
#   '201.227.102.156',
#   'Malloryberg'],
#  ['342',
#   'Sydney',
#   'Sanchez',
#   'adamspaul@example.org',
#   'Male',
#   '159.238.239.249',
#   'New Lonnie'],
#  ['343',
#   'James',
#   'Finley',
#   'clozano@example.net',
#   'Female',
#   '210.84.127.129',
#   'Castroville'],
#  ['344',
#   'Morgan',
#   'Lopez',
#   'kyle51@example.org',
#   'Male',
#   '119.59.113.223',
#   'Michelefurt'],
#  ['345',
#   'Laura',
#   'Parker',
#   'xsmith@example.org',
#   'Male',
#   '96.229.10.217',
#   'Lake Alexanderland'],
#  ['346',
#   'Erik',
#   'Hoffman',
#   'helenlucero@example.com',
#   'Male',
#   '124.86.173.106',
#   'North Lisa'],
#  ['347',
#   'Brandon',
#   'Ponce',
#   'kellyrangel@example.net',
#   'Female',
#   '214.96.21.164',
#   'Bryanstad'],
#  ['348',
#   'Andrew',
#   'Smith',
#   'garciaaaron@example.org',
#   'Male',
#   '64.67.174.115',
#   'Port Evelyn'],
#  ['349',
#   'Pamela',
#   'Bryant',
#   'jerrymaldonado@example.org',
#   'Female',
#   '40.155.112.246',
#   'Port Williamside'],
#  ['350',
#   'Jessica',
#   'Duran',
#   'david91@example.org',
#   'Male',
#   '39.230.118.194',
#   'Nelsonside'],
#  ['351',
#   'Ruth',
#   'Richardson',
#   'richardsjustin@example.net',
#   'Female',
#   '25.206.142.184',
#   'Port Amanda'],
#  ['352',
#   'Danielle',
#   'Cherry',
#   'nlawrence@example.net',
#   'Male',
#   '192.79.107.43',
#   'North Jessica'],
#  ['353',
#   'Joseph',
#   'Jones',
#   'jessebaker@example.org',
#   'Female',
#   '162.210.165.56',
#   'North Amandaberg'],
#  ['354',
#   'Ethan',
#   'Walker',
#   'ashley31@example.net',
#   'Male',
#   '10.50.78.62',
#   'Donnafurt'],
#  ['355',
#   'Katie',
#   'Henderson',
#   'kduncan@example.com',
#   'Female',
#   '183.46.161.107',
#   'Alexaville'],
#  ['356',
#   'Sarah',
#   'Fletcher',
#   'patricia31@example.org',
#   'Male',
#   '56.70.216.24',
#   'New Ginaberg'],
#  ['357',
#   'Mary',
#   'Kerr',
#   'udavidson@example.net',
#   'Male',
#   '101.110.38.44',
#   'North Alejandro'],
#  ['358',
#   'Brandon',
#   'Lamb',
#   'amanda72@example.org',
#   'Female',
#   '80.78.197.162',
#   'Loriland'],
#  ['359',
#   'Brianna',
#   'Ross',
#   'christinemoore@example.net',
#   'Female',
#   '174.133.95.218',
#   'North Dennis'],
#  ['360',
#   'Michael',
#   'Meza',
#   'zgraves@example.com',
#   'Female',
#   '84.179.185.188',
#   'New Andreview'],
#  ['361',
#   'Amy',
#   'Hooper',
#   'fergusonronnie@example.org',
#   'Male',
#   '162.58.1.8',
#   'Brooksstad'],
#  ['362',
#   'Erika',
#   'Porter',
#   'wardalexis@example.org',
#   'Female',
#   '152.237.52.206',
#   'Rogerstad'],
#  ['363',
#   'Mark',
#   'Hill',
#   'fowlerlauren@example.com',
#   'Male',
#   '1.252.78.155',
#   'Bondville'],
#  ['364',
#   'David',
#   'Ross',
#   'jon00@example.net',
#   'Female',
#   '221.238.32.94',
#   'Craigmouth'],
#  ['365',
#   'Michelle',
#   'Torres',
#   'greenmelanie@example.com',
#   'Female',
#   '142.255.55.83',
#   'Johnfurt'],
#  ['366',
#   'Angela',
#   'Moore',
#   'emily34@example.net',
#   'Female',
#   '55.116.97.78',
#   'Dannybury'],
#  ['367',
#   'Sheena',
#   'Turner',
#   'joseph50@example.com',
#   'Female',
#   '28.161.95.50',
#   'Christopherview'],
#  ['368',
#   'Jessica',
#   'Russell',
#   'kcervantes@example.net',
#   'Male',
#   '21.72.179.24',
#   'North Stephen'],
#  ['369',
#   'Matthew',
#   'Walker',
#   'halljeffery@example.net',
#   'Male',
#   '210.114.116.141',
#   'West Tonya'],
#  ['370',
#   'Daniel',
#   'Curry',
#   'ulowe@example.org',
#   'Female',
#   '23.43.43.193',
#   'North Angela'],
#  ['371',
#   'Karen',
#   'Dorsey',
#   'xelliott@example.net',
#   'Male',
#   '42.29.0.118',
#   'West Charlesport'],
#  ['372',
#   'Daniel',
#   'Johnson',
#   'baldwindeborah@example.org',
#   'Male',
#   '63.28.44.205',
#   'Port David'],
#  ['373',
#   'William',
#   'Graham',
#   'proctorsamuel@example.net',
#   'Female',
#   '94.160.158.49',
#   'South Sethburgh'],
#  ['374',
#   'Leslie',
#   'Larson',
#   'jcollins@example.net',
#   'Female',
#   '202.101.212.46',
#   'Ruizfort'],
#  ['375',
#   'Bryce',
#   'Shah',
#   'qhanna@example.net',
#   'Male',
#   '137.146.71.40',
#   'Bullockchester'],
#  ['376',
#   'Christina',
#   'Fisher',
#   'margaret41@example.org',
#   'Female',
#   '60.124.165.74',
#   'Noahtown'],
#  ['377',
#   'Heather',
#   'Williams',
#   'jessicahumphrey@example.net',
#   'Female',
#   '75.231.40.244',
#   'Taylorton'],
#  ['378',
#   'Jessica',
#   'Brown',
#   'joneschristina@example.org',
#   'Female',
#   '216.188.181.228',
#   'Port Laurenview'],
#  ['379',
#   'Courtney',
#   'King',
#   'michealallen@example.com',
#   'Male',
#   '87.56.207.158',
#   'New Timothy'],
#  ['380',
#   'Connie',
#   'Smith',
#   'pmcneil@example.org',
#   'Female',
#   '27.80.223.83',
#   'New Maryside'],
#  ['381',
#   'Cassandra',
#   'Gomez',
#   'ychapman@example.net',
#   'Male',
#   '172.224.205.155',
#   'North Ricky'],
#  ['382',
#   'Dakota',
#   'Harmon',
#   'uchang@example.org',
#   'Male',
#   '210.224.66.96',
#   'South Cynthia'],
#  ['383',
#   'Melinda',
#   'Hansen',
#   'travismartin@example.net',
#   'Male',
#   '197.91.65.138',
#   'New Marcus'],
#  ['384',
#   'Anna',
#   'Lee',
#   'keithhudson@example.org',
#   'Female',
#   '123.254.80.187',
#   'North Latoya'],
#  ['385',
#   'Jasmine',
#   'Thompson',
#   'patricia66@example.org',
#   'Male',
#   '192.252.81.39',
#   'South Cynthiatown'],
#  ['386',
#   'Gina',
#   'Campbell',
#   'kellymcmahon@example.net',
#   'Male',
#   '212.53.32.202',
#   'Pollardview'],
#  ['387',
#   'Timothy',
#   'Crawford',
#   'harrisonjohn@example.org',
#   'Male',
#   '199.62.80.214',
#   'West Gloria'],
#  ['388',
#   'Thomas',
#   'Allen',
#   'john58@example.com',
#   'Female',
#   '145.84.16.204',
#   'South Eileen'],
#  ['389',
#   'James',
#   'Johnson',
#   'jessetaylor@example.com',
#   'Male',
#   '54.216.69.30',
#   'West Luis'],
#  ['390',
#   'Samantha',
#   'Zuniga',
#   'deleonjoshua@example.org',
#   'Female',
#   '11.8.47.116',
#   'Sabrinaberg'],
#  ['391',
#   'Michelle',
#   'Williams',
#   'matthewsmith@example.org',
#   'Male',
#   '191.9.155.6',
#   'Flowersburgh'],
#  ['392',
#   'Tammy',
#   'Stanton',
#   'sara19@example.org',
#   'Female',
#   '222.107.0.53',
#   'East Lauraborough'],
#  ['393',
#   'Sarah',
#   'Patton',
#   'alexander54@example.net',
#   'Female',
#   '217.63.152.205',
#   'Wilsonborough'],
#  ['394',
#   'Ashley',
#   'Hooper',
#   'jackson37@example.net',
#   'Male',
#   '20.215.71.104',
#   'New Lisamouth'],
#  ['395',
#   'Joseph',
#   'Reed',
#   'lanebrian@example.com',
#   'Male',
#   '202.5.131.101',
#   'Nicholeton'],
#  ['396',
#   'Martin',
#   'Watson',
#   'jonathan85@example.com',
#   'Male',
#   '39.3.18.162',
#   'Lopezland'],
#  ['397',
#   'Matthew',
#   'Crosby',
#   'bschneider@example.net',
#   'Male',
#   '69.135.110.65',
#   'Michaelhaven'],
#  ['398',
#   'Chelsea',
#   'Boyer',
#   'aramos@example.org',
#   'Male',
#   '90.155.58.182',
#   'North Kaitlinland'],
#  ['399',
#   'Travis',
#   'Brown',
#   'michael67@example.com',
#   'Male',
#   '140.232.33.88',
#   'Jerrychester'],
#  ['400',
#   'Anthony',
#   'Lopez',
#   'mejiakerri@example.com',
#   'Female',
#   '83.168.219.143',
#   'North Christopher'],
#  ['401',
#   'Stanley',
#   'Rodriguez',
#   'whitemax@example.org',
#   'Female',
#   '66.216.237.16',
#   'South Robertchester'],
#  ['402',
#   'Amanda',
#   'Dawson',
#   'xparker@example.net',
#   'Male',
#   '206.40.184.41',
#   'Lynchton'],
#  ['403',
#   'Michael',
#   'Neal',
#   'sharon60@example.org',
#   'Male',
#   '113.159.41.116',
#   'Powellhaven'],
#  ['404',
#   'Brittany',
#   'Hill',
#   'vburke@example.net',
#   'Male',
#   '30.130.90.71',
#   'Jessehaven'],
#  ['405',
#   'Amanda',
#   'Ramirez',
#   'ingramlaura@example.net',
#   'Male',
#   '114.135.252.84',
#   'East Lori'],
#  ['406',
#   'Kristen',
#   'Andrews',
#   'roberta94@example.com',
#   'Female',
#   '78.176.167.235',
#   'South Derekstad'],
#  ['407',
#   'Adam',
#   'Barnett',
#   'martinjuan@example.net',
#   'Male',
#   '84.238.26.218',
#   'South Daniel'],
#  ['408',
#   'Melissa',
#   'Osborne',
#   'elopez@example.org',
#   'Male',
#   '128.254.161.196',
#   'Ashleytown'],
#  ['409',
#   'Joshua',
#   'Wilkerson',
#   'jameswarner@example.org',
#   'Female',
#   '202.172.211.197',
#   'East Randyhaven'],
#  ['410',
#   'Brendan',
#   'Brooks',
#   'isabellalewis@example.com',
#   'Female',
#   '204.161.170.28',
#   'Lake David'],
#  ['411',
#   'Sandra',
#   'Walsh',
#   'david29@example.org',
#   'Female',
#   '150.137.117.74',
#   'Mitchellmouth'],
#  ['412',
#   'Laurie',
#   'Walker',
#   'petersmichael@example.net',
#   'Female',
#   '190.253.12.124',
#   'Johnsontown'],
#  ['413',
#   'Richard',
#   'Holland',
#   'williamthompson@example.org',
#   'Male',
#   '145.118.38.196',
#   'Lake Angelabury'],
#  ['414',
#   'Sabrina',
#   'Curtis',
#   'wwalker@example.net',
#   'Female',
#   '134.72.84.17',
#   'Port Charlesland'],
#  ['415',
#   'Timothy',
#   'Espinoza',
#   'lynchrobert@example.org',
#   'Male',
#   '13.248.27.125',
#   'Robertsonhaven'],
#  ['416',
#   'Christine',
#   'Joyce',
#   'jhorn@example.com',
#   'Male',
#   '29.210.236.252',
#   'Edwardport'],
#  ['417',
#   'Lisa',
#   'Williams',
#   'vcastillo@example.org',
#   'Female',
#   '211.127.140.174',
#   'East Frederick'],
#  ['418',
#   'Jacob',
#   'Smith',
#   'masonmiller@example.org',
#   'Male',
#   '79.6.109.155',
#   'Timothyton'],
#  ['419',
#   'Kristine',
#   'Brown',
#   'gnelson@example.org',
#   'Female',
#   '187.81.123.214',
#   'Port Patrick'],
#  ['420',
#   'Tara',
#   'Duarte',
#   'edwardallen@example.org',
#   'Female',
#   '4.77.71.200',
#   'New Nicole'],
#  ['421',
#   'Brittany',
#   'Castillo',
#   'michaeldrake@example.org',
#   'Female',
#   '105.88.65.249',
#   'Beckyberg'],
#  ['422',
#   'Virginia',
#   'Jennings',
#   'mullinsdarlene@example.org',
#   'Female',
#   '56.196.32.49',
#   'Lake Diana'],
#  ['423',
#   'Lauren',
#   'Stein',
#   'qhall@example.org',
#   'Male',
#   '59.219.140.253',
#   'East Waltermouth'],
#  ['424',
#   'Dustin',
#   'Taylor',
#   'hallchristopher@example.com',
#   'Female',
#   '164.225.13.10',
#   'Westside'],
#  ['425',
#   'John',
#   'Benson',
#   'vbolton@example.org',
#   'Male',
#   '83.60.243.68',
#   'Ambermouth'],
#  ['426',
#   'Jerry',
#   'Crane',
#   'ayalatheodore@example.org',
#   'Female',
#   '50.190.5.90',
#   'Allenburgh'],
#  ['427',
#   'Christopher',
#   'Lloyd',
#   'johnny08@example.com',
#   'Male',
#   '164.210.0.85',
#   'Hooperstad'],
#  ['428',
#   'Pamela',
#   'Obrien',
#   'bradfordbecky@example.org',
#   'Female',
#   '4.41.37.196',
#   'Port Gregory'],
#  ['429',
#   'Julie',
#   'Dixon',
#   'jeremy96@example.net',
#   'Male',
#   '170.11.190.26',
#   'Bakerton'],
#  ['430',
#   'Danny',
#   'Thomas',
#   'kevin02@example.org',
#   'Male',
#   '147.150.12.97',
#   'Boydtown'],
#  ['431',
#   'Heidi',
#   'Chang',
#   'llowery@example.net',
#   'Female',
#   '217.95.93.170',
#   'New Lauren'],
#  ['432',
#   'Alexis',
#   'Turner',
#   'sandovalsteven@example.org',
#   'Female',
#   '144.213.53.141',
#   'Julieborough'],
#  ['433',
#   'Aaron',
#   'Mathews',
#   'carpenteryolanda@example.org',
#   'Female',
#   '107.112.39.123',
#   'North Paulafurt'],
#  ['434',
#   'Casey',
#   'Lee',
#   'gnichols@example.com',
#   'Male',
#   '221.182.19.173',
#   'East Kellystad'],
#  ['435',
#   'Joseph',
#   'Silva',
#   'paul65@example.net',
#   'Male',
#   '11.152.108.202',
#   'Tammieside'],
#  ['436',
#   'Scott',
#   'Richard',
#   'grimescristina@example.net',
# ...
#   'White',
#   'danielbright@example.org',
#   'Male',
#   '223.193.201.161',
#   'East Robert'],
#  ['856',
#   'Michael',
#   'Boone',
#   'mirandabrittany@example.com',
#   'Male',
#   '67.37.129.6',
#   'South Carrieville'],
#  ['857',
#   'Lisa',
#   'Jordan',
#   'reginarojas@example.com',
#   'Male',
#   '137.180.184.10',
#   'New Jamesland'],
#  ['858',
#   'Caitlyn',
#   'Hansen',
#   'nathan30@example.org',
#   'Male',
#   '86.193.108.220',
#   'Simpsonhaven'],
#  ['859',
#   'Michael',
#   'Tanner',
#   'amykeith@example.com',
#   'Female',
#   '196.96.28.221',
#   'Jonathanstad'],
#  ['860',
#   'Eric',
#   'Lawrence',
#   'lauren00@example.com',
#   'Male',
#   '132.212.9.222',
#   'Elizabethborough'],
#  ['861',
#   'Olivia',
#   'Vasquez',
#   'williamneal@example.net',
#   'Male',
#   '154.4.52.60',
#   'Francoview'],
#  ['862',
#   'Stephanie',
#   'Burke',
#   'qgregory@example.net',
#   'Male',
#   '10.109.92.59',
#   'New Amanda'],
#  ['863',
#   'Jerome',
#   'Mccann',
#   'johnsondanielle@example.com',
#   'Male',
#   '163.155.109.71',
#   'West Brenda'],
#  ['864',
#   'Gilbert',
#   'Odonnell',
#   'james37@example.net',
#   'Male',
#   '24.108.120.196',
#   'New Carlos'],
#  ['865',
#   'Laura',
#   'Fitzgerald',
#   'james53@example.com',
#   'Female',
#   '70.83.233.29',
#   'Lake Melissa'],
#  ['866',
#   'Crystal',
#   'Berry',
#   'lucaszachary@example.net',
#   'Male',
#   '58.27.184.82',
#   'New Grant'],
#  ['867',
#   'James',
#   'Thompson',
#   'robert06@example.com',
#   'Male',
#   '154.144.14.150',
#   'West Sarahville'],
#  ['868',
#   'William',
#   'Clark',
#   'gonzalezkevin@example.org',
#   'Male',
#   '179.55.181.221',
#   'Howardchester'],
#  ['869',
#   'Amanda',
#   'Johnson',
#   'albertmartinez@example.org',
#   'Female',
#   '141.101.112.218',
#   'Taylorhaven'],
#  ['870',
#   'Michelle',
#   'Thompson',
#   'denise13@example.net',
#   'Female',
#   '202.30.253.155',
#   'Franklinfurt'],
#  ['871',
#   'Joanne',
#   'Hawkins',
#   'whartman@example.org',
#   'Female',
#   '192.153.191.36',
#   'Port Maryborough'],
#  ['872',
#   'Courtney',
#   'Foster',
#   'alexander05@example.org',
#   'Female',
#   '145.11.80.183',
#   'Dennisland'],
#  ['873',
#   'Anthony',
#   'Wallace',
#   'uwilson@example.org',
#   'Male',
#   '45.124.221.188',
#   'Port Brittany'],
#  ['874',
#   'Jill',
#   'Bryant',
#   'everettcatherine@example.com',
#   'Male',
#   '128.205.199.119',
#   'East Brandy'],
#  ['875',
#   'Allison',
#   'Tyler',
#   'zavalakendra@example.net',
#   'Female',
#   '223.237.53.94',
#   'Port Annette'],
#  ['876',
#   'John',
#   'Ritter',
#   'elizabeth78@example.com',
#   'Female',
#   '150.163.5.193',
#   'Thompsonside'],
#  ['877',
#   'Derek',
#   'Williams',
#   'adamhall@example.net',
#   'Male',
#   '191.103.74.55',
#   'Lake Coreyport'],
#  ['878',
#   'Christopher',
#   'Carson',
#   'jason39@example.org',
#   'Male',
#   '90.119.5.109',
#   'Danaport'],
#  ['879',
#   'Billy',
#   'Chavez',
#   'raylambert@example.com',
#   'Male',
#   '135.147.176.99',
#   'Brownchester'],
#  ['880',
#   'Robert',
#   'Thomas',
#   'oroberts@example.com',
#   'Female',
#   '214.41.6.9',
#   'Lunaberg'],
#  ['881',
#   'Matthew',
#   'Moreno',
#   'patrickerickson@example.org',
#   'Male',
#   '116.107.252.145',
#   'Jonesport'],
#  ['882',
#   'Teresa',
#   'Le',
#   'rrose@example.org',
#   'Female',
#   '93.43.136.196',
#   'Joelton'],
#  ['883',
#   'Tina',
#   'Phillips',
#   'jacksonjones@example.net',
#   'Male',
#   '78.111.36.240',
#   'Kimberlyport'],
#  ['884',
#   'Brandon',
#   'Small',
#   'katherine26@example.net',
#   'Female',
#   '72.66.250.180',
#   'West Brianmouth'],
#  ['885',
#   'Angela',
#   'Michael',
#   'rachelking@example.net',
#   'Male',
#   '105.86.35.211',
#   'Jameston'],
#  ['886',
#   'Betty',
#   'Jones',
#   'jerrywashington@example.com',
#   'Male',
#   '194.102.81.155',
#   'Johnville'],
#  ['887',
#   'Clifford',
#   'Torres',
#   'christinapatton@example.org',
#   'Male',
#   '216.225.38.237',
#   'Larryhaven'],
#  ['888',
#   'James',
#   'Wood',
#   'crystalleblanc@example.net',
#   'Male',
#   '117.58.132.148',
#   'Calvintown'],
#  ['889',
#   'Tina',
#   'Galloway',
#   'sherianderson@example.com',
#   'Female',
#   '78.115.83.46',
#   'South Cassandra'],
#  ['890',
#   'Kelsey',
#   'Casey',
#   'michelleclayton@example.net',
#   'Female',
#   '206.200.239.90',
#   'West Angelafort'],
#  ['891',
#   'Catherine',
#   'Smith',
#   'deanna48@example.net',
#   'Female',
#   '217.146.56.204',
#   'Mitchellville'],
#  ['892',
#   'Sarah',
#   'Acosta',
#   'melissa22@example.org',
#   'Female',
#   '183.155.35.252',
#   'West Catherine'],
#  ['893',
#   'Kristina',
#   'Smith',
#   'melissa46@example.net',
#   'Male',
#   '58.116.10.170',
#   'Lake Danielshire'],
#  ['894',
#   'Theresa',
#   'Watson',
#   'williewall@example.net',
#   'Male',
#   '152.14.249.143',
#   'East Marilynview'],
#  ['895',
#   'Jennifer',
#   'Mejia',
#   'paulamber@example.org',
#   'Male',
#   '133.43.52.98',
#   'Martinfurt'],
#  ['896',
#   'Andrea',
#   'Waters',
#   'wthornton@example.org',
#   'Male',
#   '109.91.56.33',
#   'West Tammyborough'],
#  ['897',
#   'Melinda',
#   'Rose',
#   'owhitehead@example.org',
#   'Female',
#   '59.98.0.31',
#   'Jimmystad'],
#  ['898',
#   'Anthony',
#   'Ellis',
#   'jjohnson@example.net',
#   'Female',
#   '83.142.30.100',
#   'Lake Davidton'],
#  ['899',
#   'Sean',
#   'Arroyo',
#   'clewis@example.org',
#   'Male',
#   '169.118.27.131',
#   'Johntown'],
#  ['900',
#   'Anthony',
#   'Garcia',
#   'marksmith@example.com',
#   'Female',
#   '178.199.87.121',
#   'Port Nicholas'],
#  ['901',
#   'Jonathan',
#   'Baker',
#   'david79@example.org',
#   'Male',
#   '83.202.83.36',
#   'Youngview'],
#  ['902',
#   'Daniel',
#   'Johnson',
#   'thomaslewis@example.com',
#   'Female',
#   '84.157.102.198',
#   'South Scott'],
#  ['903',
#   'Allison',
#   'Hall',
#   'suzannemarquez@example.com',
#   'Female',
#   '144.38.149.168',
#   'West Thomasshire'],
#  ['904',
#   'Karen',
#   'Rodgers',
#   'jonathanburns@example.net',
#   'Female',
#   '114.70.169.230',
#   'Jenningsview'],
#  ['905',
#   'Bonnie',
#   'Torres',
#   'cynthia64@example.org',
#   'Male',
#   '87.238.247.188',
#   'Katieborough'],
#  ['906',
#   'Sandra',
#   'Arnold',
#   'xpeterson@example.net',
#   'Male',
#   '73.189.210.245',
#   'Lake Meganton'],
#  ['907',
#   'Kevin',
#   'Carter',
#   'fbenson@example.org',
#   'Male',
#   '136.136.138.155',
#   'Dominguezmouth'],
#  ['908',
#   'Micheal',
#   'Osborn',
#   'tlloyd@example.net',
#   'Female',
#   '50.130.138.102',
#   'Greenchester'],
#  ['909',
#   'Xavier',
#   'Moore',
#   'kristenwood@example.com',
#   'Male',
#   '84.99.123.29',
#   'Feliciashire'],
#  ['910',
#   'Ryan',
#   'Hawkins',
#   'kristen31@example.com',
#   'Female',
#   '180.104.5.181',
#   'New Cynthiaport'],
#  ['911',
#   'Mary',
#   'Smith',
#   'chartman@example.com',
#   'Female',
#   '77.140.69.108',
#   'West Anthony'],
#  ['912',
#   'Angela',
#   'Harrison',
#   'robertbender@example.org',
#   'Female',
#   '202.109.241.163',
#   'New Blakeside'],
#  ['913',
#   'Amy',
#   'Burke',
#   'owenmelissa@example.org',
#   'Male',
#   '47.117.97.242',
#   'Lopezfurt'],
#  ['914',
#   'John',
#   'Freeman',
#   'tamararichards@example.org',
#   'Male',
#   '196.68.6.68',
#   'Lake Jacobland'],
#  ['915',
#   'Dwayne',
#   'Lynch',
#   'ehall@example.net',
#   'Male',
#   '4.195.141.176',
#   'Port Jonathan'],
#  ['916',
#   'Jesus',
#   'Lee',
#   'jenkinstodd@example.org',
#   'Male',
#   '152.222.58.197',
#   'Tracyton'],
#  ['917',
#   'Stacy',
#   'Ramsey',
#   'christensenann@example.org',
#   'Female',
#   '149.89.63.255',
#   'Cuevasburgh'],
#  ['918',
#   'Jacob',
#   'Mason',
#   'stephanieramsey@example.org',
#   'Male',
#   '113.228.109.245',
#   'South Janet'],
#  ['919',
#   'Andrew',
#   'Martinez',
#   'rwilliams@example.org',
#   'Female',
#   '22.10.38.32',
#   'Ingrambury'],
#  ['920',
#   'Kelly',
#   'Harris',
#   'michealstewart@example.net',
#   'Female',
#   '152.199.206.172',
#   'Lake Kerryville'],
#  ['921',
#   'Kelly',
#   'Jones',
#   'stephanie09@example.com',
#   'Female',
#   '20.209.99.98',
#   'Blackstad'],
#  ['922',
#   'Joseph',
#   'Ibarra',
#   'justin03@example.org',
#   'Male',
#   '3.122.177.49',
#   'Port Sarah'],
#  ['923',
#   'Craig',
#   'Smith',
#   'aromero@example.net',
#   'Male',
#   '195.80.56.248',
#   'Port Jennifer'],
#  ['924',
#   'Arthur',
#   'Francis',
#   'lydia09@example.com',
#   'Male',
#   '76.160.121.24',
#   'Robertville'],
#  ['925',
#   'Carl',
#   'Wiggins',
#   'davidrodriguez@example.org',
#   'Male',
#   '121.146.191.65',
#   'South Gabriel'],
#  ['926',
#   'Melissa',
#   'Lowe',
#   'anna66@example.com',
#   'Female',
#   '42.114.18.119',
#   'Martinmouth'],
#  ['927',
#   'Anthony',
#   'Cook',
#   'howardscott@example.org',
#   'Female',
#   '69.234.152.19',
#   'Lake Jessicaview'],
#  ['928',
#   'Christopher',
#   'Lane',
#   'kim47@example.com',
#   'Female',
#   '101.198.75.64',
#   'Frymouth'],
#  ['929',
#   'Monica',
#   'Sanchez',
#   'steven74@example.net',
#   'Female',
#   '204.133.68.47',
#   'Ayalahaven'],
#  ['930',
#   'Vincent',
#   'Williams',
#   'bryannunez@example.net',
#   'Male',
#   '180.228.238.214',
#   'Saundersland'],
#  ['931',
#   'Amanda',
#   'Fitzgerald',
#   'martindaniel@example.com',
#   'Male',
#   '42.238.229.183',
#   'North Carolynside'],
#  ['932',
#   'Ashley',
#   'Stanley',
#   'cthompson@example.org',
#   'Male',
#   '71.126.180.242',
#   'Port Amberhaven'],
#  ['933',
#   'Rebecca',
#   'Rodriguez',
#   'kristine16@example.net',
#   'Female',
#   '92.244.204.96',
#   'Emilyfurt'],
#  ['934',
#   'Yvette',
#   'Myers',
#   'norma57@example.com',
#   'Female',
#   '45.28.33.6',
#   'North Jessica'],
#  ['935',
#   'Keith',
#   'Williams',
#   'garypope@example.net',
#   'Female',
#   '175.207.38.248',
#   'Aguirreport'],
#  ['936',
#   'Rebecca',
#   'Navarro',
#   'munoztammy@example.com',
#   'Male',
#   '133.24.48.234',
#   'Pagestad'],
#  ['937',
#   'Angel',
#   'Porter',
#   'stephanie85@example.net',
#   'Female',
#   '107.138.43.245',
#   'Lake Davidtown'],
#  ['938',
#   'Carla',
#   'Forbes',
#   'orobinson@example.com',
#   'Female',
#   '113.215.151.110',
#   'Wallacemouth'],
#  ['939',
#   'Regina',
#   'Bowen',
#   'karenmccarthy@example.net',
#   'Male',
#   '144.41.112.52',
#   'Thompsonside'],
#  ['940',
#   'Michelle',
#   'Johnson',
#   'sara82@example.com',
#   'Female',
#   '30.83.37.95',
#   'Lake Jeremy'],
#  ['941',
#   'Kayla',
#   'Lynn',
#   'angel37@example.com',
#   'Male',
#   '63.251.92.62',
#   'Bishopmouth'],
#  ['942',
#   'Cynthia',
#   'Allen',
#   'ugraham@example.com',
#   'Female',
#   '206.181.224.38',
#   'Jacksonbury'],
#  ['943',
#   'James',
#   'Atkinson',
#   'jenniferjohnson@example.net',
#   'Female',
#   '93.68.244.51',
#   'Ryanshire'],
#  ['944',
#   'Wendy',
#   'Maldonado',
#   'joseph62@example.org',
#   'Female',
#   '78.40.113.69',
#   'Johnsontown'],
#  ['945',
#   'John',
#   'Barrett',
#   'alexanderbrandon@example.com',
#   'Male',
#   '214.131.244.70',
#   'West Bradley'],
#  ['946',
#   'Michael',
#   'Hunter',
#   'jeremiahsmith@example.org',
#   'Female',
#   '67.175.71.31',
#   'Michaelburgh'],
#  ['947',
#   'Jacqueline',
#   'Mccann',
#   'qthomas@example.com',
#   'Male',
#   '177.222.255.230',
#   'East Vincentmouth'],
#  ['948',
#   'Virginia',
#   'Cox',
#   'patriciarocha@example.com',
#   'Female',
#   '167.124.203.104',
#   'Lake Kendrashire'],
#  ['949',
#   'Timothy',
#   'Bryan',
#   'canderson@example.org',
#   'Male',
#   '173.212.24.53',
#   'Blankenshipmouth'],
#  ['950',
#   'Robert',
#   'Lopez',
#   'rreynolds@example.com',
#   'Male',
#   '109.206.211.227',
#   'East Jack'],
#  ['951',
#   'Lisa',
#   'Smith',
#   'mckeeashley@example.com',
#   'Male',
#   '26.219.157.118',
#   'Port Garrett'],
#  ['952',
#   'Sarah',
#   'Wright',
#   'vjones@example.net',
#   'Female',
#   '216.126.73.2',
#   'Michaelville'],
#  ['953',
#   'Jessica',
#   'Ramos',
#   'rodney14@example.com',
#   'Male',
#   '198.6.31.234',
#   'Terryfurt'],
#  ['954',
#   'Kim',
#   'Young',
#   'louisrobinson@example.net',
#   'Female',
#   '50.103.17.201',
#   'Joshuamouth'],
#  ['955',
#   'Gabriela',
#   'Graham',
#   'xgonzalez@example.net',
#   'Female',
#   '73.247.185.92',
#   'West Brandi'],
#  ['956',
#   'Danielle',
#   'Cooke',
#   'baldwinjames@example.com',
#   'Female',
#   '109.135.138.196',
#   'West Scott'],
#  ['957',
#   'James',
#   'Long',
#   'melaniethornton@example.net',
#   'Female',
#   '155.181.44.68',
#   'Madisonberg'],
#  ['958',
#   'Miguel',
#   'Gallagher',
#   'umiranda@example.net',
#   'Female',
#   '164.39.110.184',
#   'New Kayla'],
#  ['959',
#   'Thomas',
#   'Moyer',
#   'zsimmons@example.org',
#   'Male',
#   '110.180.124.184',
#   'West Austin'],
#  ['960',
#   'Brian',
#   'Anderson',
#   'jonathanmiller@example.com',
#   'Female',
#   '55.192.192.235',
#   'Combsport'],
#  ['961',
#   'Valerie',
#   'Watson',
#   'preston80@example.com',
#   'Female',
#   '82.55.77.80',
#   'Mooretown'],
#  ['962',
#   'Maurice',
#   'Norton',
#   'kathleen83@example.org',
#   'Male',
#   '216.194.41.189',
#   'South Abigail'],
#  ['963',
#   'Kyle',
#   'Brown',
#   'amberwright@example.com',
#   'Female',
#   '111.21.121.208',
#   'Williamsberg'],
#  ['964',
#   'David',
#   'Welch',
#   'stacycarson@example.org',
#   'Female',
#   '41.217.66.7',
#   'Doyleville'],
#  ['965',
#   'Kathryn',
#   'Sanders',
#   'davidhines@example.com',
#   'Male',
#   '64.170.174.101',
#   'Christinaland'],
#  ['966',
#   'Kathryn',
#   'Marshall',
#   'egibson@example.org',
#   'Female',
#   '183.148.78.232',
#   'Lorifurt'],
#  ['967',
#   'Deborah',
#   'Larson',
#   'donald74@example.com',
#   'Male',
#   '98.225.164.189',
#   'Paulaport'],
#  ['968',
#   'Mark',
#   'Harvey',
#   'ashley21@example.com',
#   'Male',
#   '178.206.237.65',
#   'Carlsonborough'],
#  ['969',
#   'Mike',
#   'Chan',
#   'reyesrobert@example.net',
#   'Male',
#   '56.190.80.115',
#   'South Christophermouth'],
#  ['970',
#   'Christopher',
#   'Crawford',
#   'katherine48@example.com',
#   'Male',
#   '19.81.205.56',
#   'Davisville'],
#  ['971',
#   'Thomas',
#   'Velasquez',
#   'gail24@example.net',
#   'Male',
#   '116.220.15.199',
#   'West Michaelborough'],
#  ['972',
#   'Kara',
#   'Davis',
#   'valerie97@example.org',
#   'Female',
#   '29.103.176.54',
#   'North Bradleychester'],
#  ['973',
#   'Christopher',
#   'Fields',
#   'marcusgillespie@example.net',
#   'Female',
#   '219.126.16.104',
#   'Amyville'],
#  ['974',
#   'William',
#   'Foster',
#   'kingjulia@example.com',
#   'Male',
#   '58.102.95.50',
#   'Andrewborough'],
#  ['975',
#   'Elizabeth',
#   'Coleman',
#   'gfowler@example.org',
#   'Female',
#   '109.26.52.193',
#   'Simmonsfort'],
#  ['976',
#   'Gary',
#   'Jimenez',
#   'amandakaiser@example.org',
#   'Female',
#   '204.222.44.125',
#   'Lake Gabrielle'],
#  ['977',
#   'James',
#   'Norton',
#   'aholloway@example.org',
#   'Male',
#   '134.155.244.135',
#   'Crystalville'],
#  ['978',
#   'Yvette',
#   'Howard',
#   'rjones@example.net',
#   'Male',
#   '117.190.119.194',
#   'Lake Rodney'],
#  ['979',
#   'John',
#   'Cook',
#   'henrybrian@example.org',
#   'Female',
#   '222.195.100.158',
#   'Johnmouth'],
#  ['980',
#   'Brian',
#   'Stevens',
#   'walterstonya@example.net',
#   'Male',
#   '47.12.140.35',
#   'New Jessica'],
#  ['981',
#   'Lee',
#   'Campbell',
#   'rodriguezscott@example.com',
#   'Female',
#   '70.80.234.66',
#   'Olsenberg'],
#  ['982',
#   'Melanie',
#   'Castro',
#   'patrickjacobson@example.org',
#   'Female',
#   '134.17.253.113',
#   'Maryside'],
#  ['983',
#   'Anthony',
#   'Herring',
#   'brownbarbara@example.org',
#   'Female',
#   '92.114.134.36',
#   'Jamesshire'],
#  ['984',
#   'Ronald',
#   'Jones',
#   'mccartymark@example.com',
#   'Male',
#   '183.105.137.223',
#   'Port Kellyview'],
#  ['985',
#   'Katherine',
#   'Murray',
#   'fcruz@example.net',
#   'Male',
#   '29.104.50.198',
#   'New Tony'],
#  ['986',
#   'Christopher',
#   'Green',
#   'jadams@example.com',
#   'Female',
#   '162.80.3.23',
#   'East Richardmouth'],
#  ['987',
#   'Bradley',
#   'Patton',
#   'michael48@example.com',
#   'Male',
#   '6.179.164.178',
#   'Barberport'],
#  ['988',
#   'Kellie',
#   'Hernandez',
#   'avilamegan@example.org',
#   'Male',
#   '138.198.17.31',
#   'New Brittany'],
#  ['989',
#   'Amanda',
#   'Powell',
#   'walkerkayla@example.org',
#   'Female',
#   '60.252.181.119',
#   'East Danielberg'],
#  ['990',
#   'Leah',
#   'David',
#   'roachcrystal@example.net',
#   'Male',
#   '113.138.172.71',
#   'Douglasmouth'],
#  ['991',
#   'John',
#   'Rivera',
#   'watsonamy@example.org',
#   'Female',
#   '123.221.69.129',
#   'Nataliefurt'],
#  ['992',
#   'Heidi',
#   'Gonzalez',
#   'sbailey@example.net',
#   'Male',
#   '96.207.141.252',
#   'East Ethan'],
#  ['993',
#   'David',
#   'Hernandez',
#   'marshallhailey@example.net',
#   'Female',
#   '87.139.93.38',
#   'South Jacob'],
#  ['994',
#   'Anthony',
#   'Pham',
#   'matthew83@example.com',
#   'Male',
#   '179.214.247.64',
#   'Meyerfort'],
#  ['995',
#   'Michael',
#   'Gordon',
#   'robertstevens@example.org',
#   'Male',
#   '39.33.245.11',
#   'Tonyland'],
#  ['996',
#   'Aaron',
#   'Roth',
#   'emily12@example.org',
#   'Male',
#   '107.145.155.165',
#   'Lake Samantha'],
#  ['997',
#   'Brandon',
#   'Nguyen',
#   'watsondawn@example.net',
#   'Male',
#   '170.82.242.197',
#   'North Ashley'],
#  ['998',
#   'Anthony',
#   'Williams',
#   'michaeljackson@example.org',
#   'Male',
#   '18.112.81.70',
#   'New Edwardside'],
#  ['999',
#   'Michael',
#   'Johnson',
#   'tmay@example.org',
#   'Female',
#   '132.56.99.188',
#   'Port Gabrielfort'],
#  ...]

# %% [markdown]
# Let's not try reading it with a "utf-8" encoding.

# %%
data = open('dados.csv',encoding="utf-8")
csv_data = csv.reader(data)
data_lines = list(csv_data)

# %%
import pandas as pd

df = pd.read_csv('dados.csv')

# %%
df.to_csv('dados-pd.csv')

# %%
df.head(20)
# Out:
#     id first_name   last_name                          email  gender  \
# 0    1      Jaime      Fowler     watkinsanthony@example.net    Male
# 1    2       John     Huffman        molinabryan@example.net    Male
# 2    3     Alison  Pennington     sextonbrittany@example.net  Female
# 3    4     Daniel     Barnett            james32@example.org  Female
# 4    5      Jenna      Miller           steven15@example.com  Female
# 5    6      Amber     Daniels       cooperautumn@example.org    Male
# 6    7     Janice      Watson            zhudson@example.com    Male
# 7    8     Howard       Smith        justinhenry@example.org    Male
# 8    9      Kevin      Rangel            kelly21@example.net    Male
# 9   10     Denise        Boyd         nicholas82@example.com  Female
# 10  11     Angela   Hernandez     anthonyrussell@example.com    Male
# 11  12  Christine        Shaw          matthew49@example.net    Male
# 12  13       Adam    Williams  millerchristopher@example.com  Female
# 13  14    Jessica      Mullen           amanda24@example.com  Female
# 14  15     Sydney       Stone         thomasjuan@example.com    Male
# 15  16    Kenneth      Wilson             erik75@example.com  Female
# 16  17    Jessica    Gonzalez             zbrown@example.com  Female
# 17  18     Briana    Cardenas          jessica66@example.org    Male
# 18  19    Spencer     Osborne          sarabaker@example.org  Female
# 19  20   Benjamin    Alvarado      martinezblake@example.net  Female
#
#          ip_address              city
# 0     129.94.178.90   Christopherberg
# 1      24.66.51.187         Karlatown
# 2     165.164.59.91    Theresachester
# 3    15.136.148.175       South Jason
# 4     205.16.74.147       North Karla
# 5   133.120.153.190         Beanhaven
# 6     205.234.166.4        Lake Keith
# 7     42.222.35.150        Walkerstad
# 8   157.232.238.144         East Kyle
# 9     176.160.102.1   West Brandyfort
# 10  162.185.230.110        Port Brian
# 11   52.190.109.216     North Brandon
# 12    8.214.104.101        West Brian
# 13    140.160.57.60  Lake Gabrielside
# 14    210.42.90.112        Port Ebony
# 15     9.23.152.156      Lake Michael
# 16     174.30.14.14      Bethanymouth
# 17     204.2.143.81   South Nicoleton
# 18     99.72.253.72       Jonathanton
# 19   81.239.160.222       Danielsberg

# %%
# Parece que funcionou!
data_lines[:3]
# Out:
# [['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city'],
#  ['1',
#   'Jaime',
#   'Fowler',
#   'watkinsanthony@example.net',
#   'Male',
#   '129.94.178.90',
#   'Christopherberg'],
#  ['2',
#   'John',
#   'Huffman',
#   'molinabryan@example.net',
#   'Male',
#   '24.66.51.187',
#   'Karlatown']]

# %% [markdown]
# Nota: O primeiro item da lista é a linha do cabeçalho, isso contém as informações sobre o que cada coluna representa. Vamos formatar nosso print um pouco:

# %%
for line in data_lines[:5]:
    print(line)
# Out:
# ['id', 'first_name', 'last_name', 'email', 'gender', 'ip_address', 'city']
# ['1', 'Jaime', 'Fowler', 'watkinsanthony@example.net', 'Male', '129.94.178.90', 'Christopherberg']
# ['2', 'John', 'Huffman', 'molinabryan@example.net', 'Male', '24.66.51.187', 'Karlatown']
# ['3', 'Alison', 'Pennington', 'sextonbrittany@example.net', 'Female', '165.164.59.91', 'Theresachester']
# ['4', 'Daniel', 'Barnett', 'james32@example.org', 'Female', '15.136.148.175', 'South Jason']

# %%
len(data_lines)
# Out:
# 2001

# %%
all_emails = []
for line in data_lines[1:15]:
    all_emails.append(line[3])

# %%
print(all_emails)
# Out:
# ['lindali@example.com', 'joshua47@example.com', 'laneemily@example.org', 'palmerkristin@example.net', 'juliagates@example.org', 'brianwarren@example.org', 'brett77@example.org', 'david61@example.net', 'williamarnold@example.net', 'stacy27@example.org', 'obrienpatrick@example.net', 'emilyallen@example.net', 'martinmackenzie@example.org', 'irose@example.org']

# %% [markdown]
# E se quiséssemos uma lista de nomes completos?

# %%
full_names = []

for line in data_lines[1:15]:
    full_names.append(line[1]+' '+line[2])

# %%
full_names
# Out:
# ['Nicholas Contreras',
#  'Anthony Bell',
#  'Victoria Stewart',
#  'Mark Cunningham',
#  'Charles Rodriguez',
#  'Matthew Wall',
#  'Joshua Bennett',
#  'Leroy Hooper',
#  'Patricia Ross',
#  'Anthony Johnson',
#  'Mark Banks',
#  'Alan Booker',
#  'Emily Wheeler',
#  'Rachel Fowler']

# %% [markdown]
# ### Arquivo Novo
# Também podemos escrever arquivos CSV, seja novos ou adicionando a arquivos existentes.

# %%
# newline controla como as novas linhas são definidas
# Pode ser None, '', '\n', '\r', e '\r\n'.
file_to_output = open('to_save_file.csv','w',newline='')

# %%
csv_writer = csv.writer(file_to_output,delimiter=',')

# %%
csv_writer.writerow(['a','b','c'])
# Out:
# 7

# %%
csv_writer.writerows([['1','2','3'],['4','5','6']])

# %%
file_to_output.close()

# %% [markdown]
# ____
# ### Arquivo existente

# %%
f = open('to_save_file.csv','a',newline='')

# %%
csv_writer = csv.writer(f)

# %%
csv_writer.writerow(['new','new','new'])
# Out:
# 13

# %%
f.close()

# %% [markdown]
#  ## Criando arquivos em excel e tratando com Pandas
#
#  Certifique-se de que você tenha a biblioteca pandas instalada em seu ambiente antes de executar este código:

# %%
# !pip install pandas
# !pip install openpyxl
# Out:
# Requirement already satisfied: pandas in c:\python312\lib\site-packages (2.1.4)
# Requirement already satisfied: numpy<2,>=1.26.0 in c:\python312\lib\site-packages (from pandas) (1.26.2)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\henriquefrank\appdata\roaming\python\python312\site-packages (from pandas) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\python312\lib\site-packages (from pandas) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in c:\python312\lib\site-packages (from pandas) (2023.3)
# Requirement already satisfied: six>=1.5 in c:\users\henriquefrank\appdata\roaming\python\python312\site-packages (from python-dateutil>=2.8.2->pandas) (1.16.0)
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip
# Collecting openpyxl
#   Downloading openpyxl-3.1.2-py2.py3-none-any.whl (249 kB)
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ---------------------------------------- 0.0/250.0 kB ? eta -:--:--
#      ------------------ ------------------- 122.9/250.0 kB 7.5 MB/s eta 0:00:01
#      -------------------------------------- 250.0/250.0 kB 5.1 MB/s eta 0:00:00
# Collecting et-xmlfile (from openpyxl)
#   Downloading et_xmlfile-1.1.0-py3-none-any.whl (4.7 kB)
# Installing collected packages: et-xmlfile, openpyxl
# Successfully installed et-xmlfile-1.1.0 openpyxl-3.1.2
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd

# Crie um DataFrame com alguns dados
data = {'Nome': ['João', 'Maria', 'Carlos', 'Ana'],
        'Idade': [25, 30, 22, 28],
        'Cidade': ['São Paulo', 'Rio de Janeiro', 'Belo Horizonte', 'Porto Alegre']}

df = pd.DataFrame(data)

# Especifique o nome do arquivo Excel que você deseja criar
nome_arquivo = 'dados_pessoas.xlsx'

# Salve o DataFrame no arquivo Excel
df.to_excel(nome_arquivo, index=False)

print(f'Arquivo Excel "{nome_arquivo}" criado com sucesso.')
# Out:
# Arquivo Excel "dados_pessoas.xlsx" criado com sucesso.

# %% [markdown]
# Neste código, estamos criando um DataFrame usando a biblioteca pandas e, em seguida, usando o método to_excel() para salvar os dados em um arquivo Excel com o nome "dados.xlsx". Certifique-se de que o arquivo "dados.xlsx" será criado no diretório em que seu script está sendo executado.
#
# Depois de executar o código, você deve encontrar o arquivo Excel no mesmo diretório em que o script foi executado.

# %% [markdown]
# Certamente! Vou mostrar como você pode realizar um tratamento simples dos dados no DataFrame usando a biblioteca pandas. Neste exemplo, faremos o seguinte:
#
# Calcular a média das idades.
# Encontrar a pessoa mais velha.
# Classificar o DataFrame por idade em ordem decrescente.
# Aqui está o código:

# %%
# 1. Calcular a média das idades
media_idades = df['Idade'].mean()
print(f'Média das idades: {media_idades} anos')
# Out:
# Média das idades: 26.25 anos

# %%
# 2. Encontrar a pessoa mais velha
pessoa_mais_velha = df[df['Idade'] == df['Idade'].max()]
print(f'Pessoa mais velha:\n{pessoa_mais_velha}')
# Out:
# Pessoa mais velha:
#     Nome  Idade          Cidade
# 1  Maria     30  Rio de Janeiro

# %%
# 3. Classificar o DataFrame por idade em ordem decrescente
df_ordenado = df.sort_values(by='Idade', ascending=False)
print('DataFrame ordenado por idade em ordem decrescente:')
print(df_ordenado)
# Out:
# DataFrame ordenado por idade em ordem decrescente:
#      Nome  Idade          Cidade
# 1   Maria     30  Rio de Janeiro
# 3     Ana     28    Porto Alegre
# 0    João     25       São Paulo
# 2  Carlos     22  Belo Horizonte
